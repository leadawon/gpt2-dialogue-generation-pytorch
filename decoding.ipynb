# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
 # !python --version
# Out:
# Python 3.9.16

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch/
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 101.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 KB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 82.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 62.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 106.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 17.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## test

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel, get_polynomial_decay_schedule_with_warmup

# %%
print("Loading the tokenizer...")
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
special_tokens = {
    'bos_token': "<bos>",
    'additional_special_tokens': ["<sp1>", "<sp2>"]
}
eos_token = tokenizer.eos_token
num_new_tokens = tokenizer.add_special_tokens(special_tokens)
# Out:
# Loading the tokenizer...
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %%
#my input_ids
output_ids = [50257, 50258,   464, 10834,  3667,   326,   484,   460,   466,  1542,
          4574,    12,  4739,   257,  5664,    11,  9022,   262, 24783,  7228,
          5340,    13, 50259, 10995,     0, 50258,  1026,   338,  2562,    13,
          1002,   345,   466,  5517, 10908,    11,   921,   460,   787,   340,
            11, 14190,    13, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
         50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
         50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
         50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
         50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
         50256, 50256, 50256, 50256, 50256]
print(len(output_ids))
print(tokenizer.decode(output_ids))
# Out:
# 95
# <bos> <sp1> The speaker claims that they can do 30 push-ups a minute, Which the listener finds impossible. <sp2> Yeah! <sp1> It's easy. If you do exercise everyday, You can make it, Too.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>

# %%
# mylabel
output_ids = [ -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  1026,   338,  2562,    13,
          1002,   345,   466,  5517, 10908,    11,   921,   460,   787,   340,
            11, 14190,    13, 50256,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
          -100,  -100,  -100,  -100,  -100]
print(len(output_ids))
#print(tokenizer.decode(output_ids))
# Out:
# 95

# %%
# default input 1
output_ids =[50257, 50258, 17250,    11,   314,  1101, 15257,    11,   314,   655,
          3888,   287,  1306,  3420,    13, 50259,  5812,    11, 15902, 15257,
            11,  7911,   319,   287,    13,   314,  1101, 16685,    13, 18460,
           284,  1826,   345,    13, 50258, 35284,   284,  1826,   345,  1165,
            13, 50259, 17353,   345,   588,  1223,   284,  4144,    30,   314,
          1053,  1392,  8887,   290,   617, 30777, 13135,    13, 50256]
print(len(output_ids))

print(tokenizer.decode(output_ids))
# Out:
# 59
# <bos> <sp1> Hi, I'm Lucas, I just moved in next door. <sp2> Oh, Hi Lucas, Come on in. I'm Barbara. Nice to meet you. <sp1> Nice to meet you too. <sp2> Would you like something to drink? I've got tea and some grape juice.<|endoftext|>

# %%
# default label 1
output_ids = [50257, 50258, 29284, 481, 1037, 10490, 804, 379, 617, 7962, 26890, 2691, 13, 10490, 318, 1719, 617, 5876, 4917, 281, 7962, 13, 10490, 460, 1037, 10490, 284, 804, 329, 281, 7962, 2691, 13, 1375, 481, 1037, 607, 284, 1064, 281, 7962, 319, 262, 4455, 13, 10490, 481, 635, 1037, 10490, 351, 2045, 329, 257, 1693, 13, 50259, 19457, 13, 1867, 1611, 286, 7962, 389, 345, 2045, 329, 30, 50256]
print(len(output_ids))

print(tokenizer.decode(output_ids))
# Out:
# 69
# <bos> <sp1> Sarah will help Sarah look at some apartment listings online. Sarah is having some trouble finding an apartment. Sarah can help Sarah to look for an apartment online. She will help her to find an apartment on the Internet. Sarah will also help Sarah with looking for a job. <sp2> Sure. What kind of apartment are you looking for?<|endoftext|>

# %%
print(tokenizer.decode([50260]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-aa415b9dc156> in <cell line: 1>()
# ----> 1 print(tokenizer.decode([50260]))
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py in decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, **kwargs)
#    3219         token_ids = to_py_obj(token_ids)
#    3220
# -> 3221         return self._decode(
#    3222             token_ids=token_ids,
#    3223             skip_special_tokens=skip_special_tokens,
#
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils.py in _decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, spaces_between_special_tokens, **kwargs)
#     930                 current_sub_text.append(token)
#     931         if current_sub_text:
# ...
