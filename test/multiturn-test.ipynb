# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch/
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp39-cp39-manylinux1_x86_64.whl (776.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.0 MB/s eta 0:00:00
# Collecting transformers==4.12.5
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.7 MB/s eta 0:00:00
# Collecting datasets==1.16.1
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 KB 24.1 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.5 MB/s eta 0:00:00
# Collecting tensorboard==2.7.0
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 39.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (2.27.1)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (3.10.7)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (2022.10.31)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 19.0 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 12.9 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (9.0.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (2023.3.0)
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (2.17.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (3.20.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (67.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.4.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==1.16.1->-r requirements.txt (line 3)) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 23.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==1.16.1->-r requirements.txt (line 3)) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard==2.7.0->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=0.11.15->tensorboard==2.7.0->-r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets==1.16.1->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets==1.16.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.12.5->-r requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.12.5->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.7.0->-r requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0->-r requirements.txt (line 5)) (3.2.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=27c0d1d75b77fbe3ce339ad118285a6b92585fc03cf1cc8572fe6b20a78edfec
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, xxhash, torch, tensorboard-data-server, sacremoses, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, tensorboard, datasets
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116

# %%
import json
import torch

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

from transformers import pipeline
summarizer = pipeline("summarization", model="philschmid/bart-large-cnn-samsum")

conversation = '''Jeff: Can I train a Transformers model on Amazon SageMaker? 
Philipp: Sure you can use the new Hugging Face Deep Learning Container. 
Jeff: ok.
Jeff: and how can I get started? 
Jeff: where can I find documentation? 
Philipp: ok, ok you can find everything here.                                   
'''
summarizer(conversation)[0]["summary_text"]

# %%
from datasets import *
from tqdm import tqdm


# For all
space = 'Ġ'
pre_quote = '’'
end_marks = ['.', ',', '?', '!', '...']
quotes = ['"', '\'']
abbreviations = ['s', 'd', 't', 'm', 're', 'll', 've', 'S', 'D', 'T', 'M', 'Re', 'Ll', 'Ve']

# For empathetic dialogues
exclude_symbol = "_conv"
comma_symbol = "_comma_"

# For persona chat
persona_chat_url = "https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json"
silence_symbol = "__ SILENCE __"


def load_daily():
    dataset = load_dataset('daily_dialog')
    test_dialogues = dataset['test']['dialog']
    
    return test_dialogues
    
    

def process_token_list(token_list):
    token_list[0] = token_list[0].capitalize()
    
    quote_count = 0
    for i, token in enumerate(token_list):
        if space in token:
            if token[1:] in end_marks or token[1:] in abbreviations:
                token_list[i] = token[1:]
                
            if token[1:] == quotes[1]:
                if i<len(token_list)-1:
                    if token_list[i+1] in abbreviations or (token_list[i+1][0] == space and token_list[i+1][1:] in abbreviations):
                        token_list[i] = token[1:]
                        
        if token[0] == space and token[1:] in quotes:
            if quote_count % 2 == 1:
                token_list[i] = token[1:]
                quote_count = 0
            else:
                if i<len(token_list)-1 and token_list[i+1][0] == space:
                    token_list[i+1] = token_list[i+1][1:]
                quote_count += 1
                
        if token in end_marks or token[1:] in end_marks:
            if i<len(token_list)-1:
                if token_list[i+1][0] != space:
                    token_list[i+1] = space + token_list[i+1].capitalize()
                else:
                    token_list[i+1] = space + token_list[i+1][1:].capitalize()
                
    new_token_list = [token for token in token_list if token != space and len(token)>0]
    if new_token_list[-1] not in end_marks:
        new_token_list.append(end_marks[0])
        
    return new_token_list

# %%
test_arr = load_daily()
load_daily()

# %%
import difflib
from transformers import GPT2Tokenizer, GPT2LMHeadModel, get_polynomial_decay_schedule_with_warmup

from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
from itertools import chain

import torch
import os, sys
import numpy as np
import argparse
import copy
import math
import random

class Arguments:
    def __init__(self):
        self.seed = 0 
        self.mode="test" 
        self.data_dir="data" 
        self.model_type="gpt2" 
        self.bos_token="<bos>" 
        self.sp1_token="<sp1>" 
        self.sp2_token="<sp2>" 
        self.gpu="0" 
        self.max_len=1024 
        self.max_turns=4
        self.top_p=0.8 
        self.ckpt_dir="saved_models" 
        self.ckpt_name="best_ckpt_epoch=3_valid_loss=2.5211" 
        self.end_command="Abort!"



#원래 shell로 들어가는 파라미터를 정의합니다.

class Manager():
    def __init__(self, args, test_arr):
        self.args = args
        self.test_arr = test_arr

        if torch.cuda.is_available():
            self.args.device = torch.device(f"cuda:{self.args.gpu}")
        else:
            self.args.device = torch.device("cpu")
        
        # Tokenizer & Vocab
        print("Loading the tokenizer...")
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.args.model_type)
        special_tokens = {
            'bos_token': self.args.bos_token,
            'additional_special_tokens': [self.args.sp1_token, self.args.sp2_token]
        }
        self.args.eos_token = self.tokenizer.eos_token
        num_new_tokens = self.tokenizer.add_special_tokens(special_tokens)
        vocab = self.tokenizer.get_vocab()
        self.args.vocab_size = len(vocab)
        self.args.bos_id = vocab[self.args.bos_token]
        self.args.eos_id = vocab[self.args.eos_token]
        self.args.sp1_id = vocab[self.args.sp1_token]
        self.args.sp2_id = vocab[self.args.sp2_token]
        
        # Load model    
        print("Loading the model...")
        self.fix_seed(self.args.seed)
        self.model = GPT2LMHeadModel.from_pretrained(self.args.model_type).to(self.args.device)
        self.model.resize_token_embeddings(self.args.vocab_size)
        
        self.args.max_len = min(self.args.max_len, self.model.config.n_ctx)
            
        
        
        if self.args.ckpt_name is not None:
            ckpt_path = f"{self.args.ckpt_dir}/{self.args.ckpt_name}.ckpt"
            if os.path.exists(ckpt_path):
                print("Loading the trained checkpoint...")
                ckpt = torch.load(ckpt_path, map_location=self.args.device)
                self.model.load_state_dict(ckpt['model_state_dict'])
                
                if self.args.mode == 'train':
                    print(f"The training restarts with the specified checkpoint: {self.args.ckpt_name}.ckpt.")
                    self.optim.load_state_dict(ckpt['optim_state_dict'])
                    self.sched.load_state_dict(ckpt['sched_state_dict'])
                    self.best_loss = ckpt['loss']
                    self.last_epoch = ckpt['epoch']
                else:
                    print("The inference will start with the specified checkpoint.")
            else:
                print(f"Cannot fine the specified checkpoint {ckpt_path}.")
                if self.args.mode == 'train':
                    print("Training will start with the initialized model.")
                else:
                    print("Cannot inference.")
                    exit()
              
        print("Setting finished.")
        
    def nucleus_sampling(self, input_ids, token_type_ids, input_len):
        output_ids = []
        for pos in range(input_len, self.args.max_len):
            output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
            output = F.softmax(output, dim=-1)  # (1, V)
            
            sorted_probs, sorted_idxs = torch.sort(output, descending=True)
            cumsum_probs = torch.cumsum(sorted_probs, dim=-1)  # (1, V)
            idx_remove = cumsum_probs > self.args.top_p
            idx_remove[:, 1:] = idx_remove[:, :-1].clone()
            idx_remove[:, 0] = False
            sorted_probs[idx_remove] = 0.0
            sorted_probs /= torch.sum(sorted_probs, dim=-1, keepdim=True)  # (1, V)
            
            probs = torch.zeros(output.shape, device=self.args.device).scatter_(-1, sorted_idxs, sorted_probs)  # (1, V)
            idx = torch.multinomial(probs, 1)  # (1, 1)
            
            idx_item = idx.squeeze(-1).squeeze(-1).item()
            output_ids.append(idx_item)
            
            if idx_item == self.args.eos_id:
                break
                
            input_ids = torch.cat((input_ids, idx), dim=-1)
            next_type_id = torch.LongTensor([[self.args.sp2_id]]).to(self.args.device)
            token_type_ids = torch.cat((token_type_ids, next_type_id), dim=-1)
            assert input_ids.shape == token_type_ids.shape
            
        return output_ids

    def fix_seed(self, seed):
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        random.seed(seed)  

    def test(self):
        test_arr = self.test_arr
        args = self.args
        print("Let's start!")
        self.model.eval()
        self.fix_seed(self.args.seed)

        input_hists = []
        user = []
        ground_truth = []
        ex_cnt = -1
        similarity = 0

        context_for_json = []
        ans_for_json = []

        for utters in test_arr:
            ex_cnt += 1
            assert (len(utters) > 1 , "there's a short dialogue") 

            hists = []

            for u, utter in enumerate(utters):
                if u % 2 == 0:
                    hists.append([args.sp1_id] + self.tokenizer.encode(utter))
                else:
                    hists.append([args.sp2_id] + self.tokenizer.encode(utter))

            if len(hists) >= self.args.max_turns:
                    num_exceeded = len(hists) - self.args.max_turns + 1
                    hists = hists[num_exceeded:]

            if hists[-1][0] == args.sp2_id:
                hists = hists[:-1]
                ground_truth.append(utters[-1])
            elif hists[-1][0] == args.sp1_id:
                hists = hists[:-2]
                ground_truth.append(utters[-2])
            else:
                assert (False, "there's an error, sp1,2 token failed")
            


            with torch.no_grad():
                input_ids = [self.args.bos_id] + list(chain.from_iterable(hists)) + [self.args.sp2_id]
                start_sp_id = hists[0][0]
                next_sp_id = self.args.sp1_id if start_sp_id == self.args.sp2_id else self.args.sp2_id
                assert start_sp_id != next_sp_id
                token_type_ids = [[start_sp_id] * len(hist) if h % 2 == 0 else [next_sp_id] * len(hist) for h, hist in enumerate(hists)]
                assert len(token_type_ids) == len(hists)
                token_type_ids = [start_sp_id] + list(chain.from_iterable(token_type_ids)) + [self.args.sp2_id]
                assert len(input_ids) == len(token_type_ids)
                input_len = len(input_ids)


                input_ids = torch.LongTensor(input_ids).unsqueeze(0).to(self.args.device)
                token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)

                output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)   
                res = self.tokenizer.decode(output_ids, skip_special_tokens=True)

                similarity += compute_similarity(res, ground_truth[ex_cnt])
                temp = []
               
                for u in hists[:-1]:
                    temp+=u

                print(f"multiturn : {self.tokenizer.decode(temp, skip_special_tokens=False)}")
                print(f"user : {self.tokenizer.decode(hists[-1], skip_special_tokens=False)}")
                print(f"res : {res}\n gt : {ground_truth[ex_cnt]}")

                context_for_json.append(self.tokenizer.decode(temp, skip_special_tokens=True) + self.tokenizer.decode(hists[-1], skip_special_tokens=True))
                ans_for_json.append(res)

                assert len(context_for_json) == len(ans_for_json)

                if len(context_for_json) == 300:
                    # 데이터 딕셔너리 생성
                    data = {"context": context_for_json, "ans": ans_for_json}

                    # JSON 파일로 저장
                    with open("test/multiturn_data.json", "w") as f:
                        json.dump(data, f)
                    

                # 예측한 문장과 ground truth를 비교할 수 있습니다.
                # 아직 눈으로 밖에 비교할 방법이 없음.

                #print(f"Bot: {res}")
                #input_hists.append([self.args.sp2_id] + self.tokenizer.encode(res))
        print(f"문자열 간에 유사도 : {similarity / len(test_arr)}")


def compute_similarity(string1, string2):

    matcher = difflib.SequenceMatcher(None, string1, string2)
    return matcher.ratio()

# 두 문자열을 비교하는 함수이나...
# 큰 의미는 없는것 같다.

# %%
args = Arguments()
args.ckpt_dir = f"{args.ckpt_dir}/{args.model_type}"
assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
manager = Manager(args, test_arr)
manager.test()
# Out:
# Loading the tokenizer...
# Loading the model...
# Loading the trained checkpoint...
# The inference will start with the specified checkpoint.
# Setting finished.
# Let's start!
# multiturn : <sp2>  Do you really have all of these drugs? Where do you get them from?  <sp1>  I got my connections! Just tell me what you want and I ’ ll even give you one ounce for free.  <sp2>  Sounds good! Let ’ s see, I want.
# user : <sp1>  Yeah?
# res :  Would you please put your name on the package please?
#  gt :  I want you to put your hands behind your head ! You are under arrest !
# multiturn : <sp1> The taxi drivers are on strike again.  <sp2>  What for?
# user : <sp1>  They want the government to reduce the price of the gasoline.
# res :  What is the driving fee?
#  gt :  It is really a hot potato .
# multiturn : <sp1>  Mainly because we've invested in a heat recovery system.  <sp2>  What does that mean exactly?
# user : <sp1>  Well, we use the exhaust gases from our printing presses to provide energy to heat our dryers.
# res :  Okay, This is exactly what we're doing.
#  gt :  What other sources of energy do you use ?
# multiturn : <sp2>  Sure, I like drinking tea at teahouses.  <sp1>  Oh, so do I.  <sp2>  Why don't we go for one now?
# user : <sp1>  Great. We can chat while enjoying a cup there.
# res : Let's go with you ; my friend is a busy woman ; he just wants to go shopping for his birthday ; so we should be waiting for him to come by.
#  gt :  Let's go !
# multiturn : <sp2>  I don ’ t try to lead people. I ’ d rather cooperate with everybody, and get the job done by working together.  <sp1>  Do you think you can make yourself easily understood in English?  <sp2>  Yes, in most circumstances.
# user : <sp1>  Are you available for travel?
# res : Of course. I “n myself ; I “ll be available for business trips and meetings.
#  gt :  Yes , I like travelling . I am young , and unmarried . It ’ s no problem for me to travel frequently .
# multiturn : <sp2>  ok. You haven ’ t seen my company car, have you?  <sp1>  no. let me take a look... it ’ s longer than my car.  <sp2>  I think it ’ s over five meters long. I can ’ t remember exactly. It has a maximum speed of over 200 kilometers an hour.
# user : <sp1>  wow! That ’ s fast! I don ’ t think we will be traveling that fast on the motorway.
# res :  Are you kidding me? I don ‘t think we are going to be speeding up here at all. We are heading for the coast!
#  gt :  we can ’ t . if we went that fast , we would break the speed limit .
# multiturn : <sp2>  There were a number of reasons.  <sp1>  What were they?  <sp2>  Basically, you just can't drive.
# user : <sp1>  Can I have another try?
# res :  Sure, You can try to take a taxi.
#  gt :  You can take it in a couple weeks .
# multiturn : <sp2>  Ah.  <sp1>  Your throat is inflamed. And your tongue is heavily coated. You have all the symptoms of influenza.  <sp2>  What am I supposed to do then?
# user : <sp1>  A good rest is all you need, and drink more water. I'll write you a prescription.
# res :  I will.
#  gt :  Thank you very much .
# multiturn : <sp1>  Very good, need I help you?  <sp2>  No, don't need, I can do myself.
# user : <sp1>  Thanks. I can watch TV now.
# res :  Well, I hope you don't mind.
#  gt :  But you must cook that dinner next time .
# multiturn : <sp2>  Things are going well with me.  <sp1>  Kara, I had fun the other night at the movies and was wondering if you would like to go out again this Friday.  <sp2>  Mike, I don't think that it's a good idea to go out again. I really need to focus on getting packed and ready to move back home.
# user : <sp1>  Maybe we could just meet for coffee or something.
# res :  Ok, Then.
#  gt :  I can't really deal with any distractions right now , but I appreciate the nice evening we spent together .
# multiturn : <sp1> Sun-set hotel. May I help you?  <sp2>  Yes, I have booked a room for 24th. It's a double room.
# user : <sp1>  Hold on, please. Let me check it for you. Yes, you're right. You will keep it for 3 days.
# res : Ok. I'll check for you then.
#  gt :  Well , now I want to change the date from 24th to 28th .
# multiturn : <sp1> Are you busy tomorrow morning?  <sp2>  I'm free. What's up?
# user : <sp1>  Someone has to pick up the boss at the airport.
# res : I thought I'd go in today.
#  gt :  Oh , I just remembered I've got a report to write .
# multiturn : <sp1> I'm sorry I'm so late. I had a really bad day.  <sp2>  It's ten after six.We're late.But dinner is at six thirty.
# user : <sp1>  I know. I know. I'm really sorry. I lost my bag.
# res : I'm sorry that it was my fault.
#  gt :  I'll call the lost and found office .
# multiturn : <sp1> Nani Book Store. How can I help you?  <sp2>  Do you have the'The man and the Sea'by Ernest Hemingway?
# user : <sp1>  Yes, we have one copy left.
# res : Thank you for your help.
#  gt :  Can you hold it for me ?
# multiturn : <sp1> Do you have maps of downtown area?  <sp2>  Yes, here you are.
# user : <sp1>  How much is it?
# res :  $ 15 a day.
#  gt :  It's free of charge .
# multiturn : <sp2>  Nonsmoking. Now, is a queen-size bed okay?  <sp1>  No problem.  <sp2>  Great, Mr. Sandals. Your reservation is confirmed. Now all I need is your phone number.
# user : <sp1>  Of course! It's area code 626-555-1739.
# res :  Ok, Now what?
#  gt :  Thank you so much , Mr . Sandals . We look forward to seeing you !
# multiturn : <sp2>  Certainly, sir.  <sp1>  I'm afraid there's been a mistake.  <sp2>  I'm sorry, sir. What seems to be the trouble?
# user : <sp1>  I believe you have charged me twice for the same thing. Look, the figure of 6.5 dollar appears here, then again here.
# res :  9 dollars, sir.
#  gt :  I'll just go and check it for you , sir .
# multiturn : <sp1>  Oh, how awful! May I have a look at the invoice?  <sp2>  Here it is.
# user : <sp1>  Well. please accept our sincere apologies, I'll be glad to change it for another one if you wish.
# res :  Okay, I'll let you know when we can work out the details ; I'll be glad to look over it ; I'll do my best to return it in the next few days.
#  gt :  That's very kind of you . Thank you .
# multiturn : <sp2>  Yes, that is today's sale price.  <sp1>  A dozen will be fine.  <sp2>  Is there anything else you'd like to get?
# user : <sp1>  No, thank you.
# res : This is a three-month fixed price.
#  gt :  These roses should make your wife very happy .
# multiturn : <sp1> Room service, is there anything I can do for you?  <sp2>  Yes, I am afraid there are not enough outlets.
# user : <sp1>  Well, we have 6 for each room.
# res :  Do you know which one is the one with the bathroom?
#  gt :  Yes , but 4 of them are broken . Can you send someone here ?
# multiturn : <sp2>  So, then why did you speed up?  <sp1>  I don't know what to tell you.  <sp2>  I'm going to have to write you a ticket.
# user : <sp1>  I understand.
# res :  But I'm afraid you're too late.
#  gt :  Here you go . Don't do that again .
# multiturn : <sp1> Can I have the roll of film developed here?  <sp2>  Surely of course.
# user : <sp1>  Here is the film. Can I get my pictures tomorrow?
# res : Of course ; you can.
#  gt :  Sure .
# multiturn : <sp1> Tell me a little bit about yourself, please.  <sp2>  My name is Dunlin and I live in Beijing. I was born in 1980. I will graduate from Peking University this July. I have majored in accounting.
# user : <sp1>  Would you tell me something about your family?
# res : My parents were Chinese and my father is a dentist.
#  gt :  There are three in my family , my parents and myself . My father is a teacher and my mother is a worker .
# multiturn : <sp2>  Actually, fruits and veggies are really good for you.  <sp1>  Yeah, I know, but what about the chicken?  <sp2>  I mainly eat baked chicken, because there's not a lot of fat.
# user : <sp1>  That does sound pretty good.
# res : Maybe I'll try that out.
#  gt :  I know it does , and that's because it is .
# multiturn : <sp1>  Oh, that suits you very well. Besides it is believed in China that the red color brings happiness and good luck.  <sp2>  Really? I'II take it and I'm leaving here tomorrow. Is it possible for you to send one in black to me by mail when you get it in?
# user : <sp1>  Our pleasure. Please fill out this form, leaving your address and telephone number.
# res : Thank you for your help ; I'm sure it will work out for me.
#  gt :  Thanks . How much would that come to ?
# multiturn : <sp2>  Oh, okay. Can I do that right now?  <sp1>  Is this Friday okay?  <sp2>  Is 6 o ’ clock Friday evening okay?
# user : <sp1>  Yes, I will schedule you for that time.
# res :  Okay, I will give you your schedule right now.
#  gt :  Thank you very much . See you then .
# multiturn : <sp1> Today I want to invite you to talk about insurance you ’ re interested in.  <sp2>  Thank you. I wonder whether I can enjoy the life insurance and health insurance.
# user : <sp1>  Of course. A two-week paid vacation a year, a five-day workweek.
# res : You mean this thing costs sixty-five dollars a week for a person of my age?
#  gt :  Good . Anything else ?
# multiturn : <sp1>  Let me see. En.. just a minute. Here it is. I need your signature on this note.  <sp2>  Oh, one more thing, where can I mail this letter?
# user : <sp1>  Drop it in the mail box mark out of town. at that corner.
# res :  Who sent you the letter?
#  gt :  Thank you very much .
# multiturn : <sp2>  I think I'll have a beer.  <sp1>  ok, shall I flag down the waitress?  <sp2>  I wouldn't recommend it. I think we should wait until she comes round.
# user : <sp1>  you're right. That might seem a bit rude. It's a good thing I've got you with me!
# res : Thanks.
#  gt :  what would you do without me ?
# multiturn :
# user : <sp1> This position demands a higher writing ability, so please say something about your writing ability.
# res : Oh, You know, I've got a lot of knowledge, So I don't want to waste time writing stupid stuff. I'll do it all by myself.
#  gt :  Of course . I've loved writing since I was a very little boy . I won the first prize in a national composition contest when I was in middle school . After attending Nanjing University , I never give up writing . My works , such as Father's Tobacco Pipe , Open Air Cinema , The old City were respectively published China Youth Daily , Yangzi Evening News , and New Beijing . During the period of studying for my degrees of master and doctor , I paid more attention to developing my research ability and published several papers . The Impact of Internet in Chinese Political Participation , The Discipline of Remold , The Historical Direction of Chinese Administration Reform , Bribery Cases of Self governance in Chinese Villages are respectively published in Chinese Publish Administration , Beijing Due Xuebao , Theory and Society and Chinese Reform . I joined in Yangzi Evening News to work as a part-time journalist in 2006 . During this period , I've written a lot of comments , which improved my writing ability to a new level , I have full confidence in my writing ability , and I believe I can do the job well .
# multiturn : <sp2>  Six couples.  <sp1>  Would you like to reserve a private dining room?  <sp2>  That sounds like a good idea.
# user : <sp1>  All right. May I have your name, Sir?
# res :  John "Ozzy" Johnson, Richard "Sonny" McDaniel, Amy Lee "Billie" Jackson, Jack Johnson.
#  gt :  My name is Ron Kollwitz .
# multiturn : <sp1> Ms. Wang, this is Mr. Cooper, president of Ivy Publishing.  <sp2>  It's nice to meet you, Mr. Cooper.
# user : <sp1>  Nice to meet you, Ms. Wang. You must be exhausted after your long trip from Canada.
# res : What a shame, I can't finish it.
#  gt :  Yes , it was quite a long flight . I'm glad to finally be here .
# multiturn : <sp1> Can you help me now?  <sp2>  No, but I'll be able to tomorrow.
# user : <sp1>  That'll be too late.
# res : I am sorry. How long is it?
#  gt :  Why don't you ask Bill if he can help ?
# multiturn : <sp1>  That's fine. What about operating the fax and duplicator?  <sp2>  I can handle them without any trouble
# user : <sp1>  What have you learned from jobs you have held?
# res : Not that much, But I am learning a lot from working with machines.
#  gt :  Above all , I have learned that what is good for the company is good for me . So I follow the instructions strictly and always keep my boss informed .
# multiturn : <sp2>  I am trying to find a job asap. Lily doesn't know yet. I didn't tell her. I spent the past three days at the coffee shop next to your office, and she thought I went to work as usual.  <sp1>  That's not the way to solve the problem. Did you look in the classified advertisements column?  <sp2>  Yes, I did. But I wasn't qualified for most of the jobs that I was interested in.
# user : <sp1>  Listen. I will see what I can do, ok? You go home and tell Lily about this problem you have now. She is your wife and I am sure she will understand.
# res :  Did you ask her if she wanted to take a job with me?
#  gt :  I just don't know how to bring it up . Well , all right . She has the right to know anyways .
# multiturn : <sp2>  Where did you park at?  <sp1>  At my apartment building.  <sp2>  Don't you have your own parking spot?
# user : <sp1>  I needed to be fast.
# res :  Did you get enough parking here?
#  gt :  That was very lazy of you .
# multiturn : <sp2>  The last four charges on the page.  <sp1>  I ’ m afraid we ’ re going to have to investigate these charges.  <sp2>  How long will an investigation take?
# user : <sp1>  I honestly don ’ t know, but we will freeze payment on these charges.
# res : Thank you for your kind help, I will try my best to answer the questions you have.
#  gt :  That sounds absolutely fantastic .
# multiturn : <sp1>  Yes, of course. We have Treasury Notes with two, three and five-year terms available.  <sp2>  Two years is fine, with a value of 1,000 RIB.
# user : <sp1>  OK, could I take a look at some ID please, like a passport?
# res :  Yes, This is the ID card from India.
#  gt :  Here you go . By the way , is it possible to cash them before the maturity comes up ?
# multiturn : <sp1>  Well you can ’ t just take the money. You have to ask the bank for money. And I ’ m the banker.  <sp2>  Banker?
# user : <sp1>  Yes...
# res : This is your cash. You have to tell the bank that you intend to withdraw money from your account.
#  gt :  Can I have my $ 200 please ?
# multiturn : <sp2>  My goodness! Are you OK?  <sp1>  I broke my leg, but it is healing.  <sp2>  How long will you be out of class?
# user : <sp1>  I should be able to return by next Monday.
# res :  Can you tell me how long you had to stay on campus?
#  gt :  Fine . Well , thanks for calling and letting me know you will be absent . I hope you feel better soon .
# multiturn : <sp1>  I see. Let me have a look. It seems that your toilet is clogged, and that ’ s why it won ’ t flush. Let me just get my plunger. No, that ’ s not working either. I suspect that there ’ s some sort of foreign object in the pipes that ‘ s causing a blockage. That ’ s what ’ s making your toilet overflow.  <sp2>  Oh, that must be because of my four-year-old daughter. She is always flushing things down the toilet. You know how kids are.
# user : <sp1>  Yeah, I have a little one myself. Anyway, these water pipes are really rusty, so they also should be changed. Thatcould be causing water to not drain completely, that might lead to more problems in the future. I would also suggest fixing this faucet that isn ’ t shutting off properly. I could have it all finished by today if it ’ s urgent.
# res :  Yes, It is. And that ” would be great relief to me too.
#  gt :  That would be great ! Is it expensive ?
# multiturn : <sp1>  I'd like to talk with her.This is short notice, I know. But Hank and I are leaving tonight.  <sp2>  I'll get you her number. I hope she can do it. She is very responsible.
# user : <sp1>  I'm glad you know someone. I knew you would be the best person to ask about this. I don't want to insult Jill or her mother. I think Jill maybe could do it.But I'd rather have someone a little older.
# res :  He certainly deserves respect and good credit.
#  gt :  I'll go home and get Sara's number . I'll call her first myself .
# multiturn : <sp1>  Draft beer and cans beer. Which do you prefer?  <sp2>  A draft beer please.
# user : <sp1>  OK. Here you are.
# res : Enjoy your stay here.
#  gt :  Could I have some fruit ?
# multiturn : <sp1>  Very well, thank you. It's nice to meet you again. I am awfully sorry for not being able to meet you at the airport, as I was busy yesterday. I do hope you had a very enjoyable trip from New York.  <sp2>  Yes, a very pleasant journey indeed. Thank you.
# user : <sp1>  How are you getting along with your business?
# res :  Good, Thank you very much for the tour of New York, You are doing a wonderful job.
#  gt :  Not bad . The fur market is not very brisk lately , but the selling season is advancing near . I hope there will be more buyers in the market this year .
# multiturn : <sp1> By the way miss, where is the toilet?  <sp2>  Toilets are in the rear, I am afraid all the toilets are fully occupied at the moment.
# user : <sp1>  What? Oh, what we live! Thank you very much for your help, miss.
# res :  Bye!
#  gt :  You are welcome .
# multiturn : <sp1>  no.  <sp2>  ok, here you go. That will be 18 pounds and seventy two pence.
# user : <sp1>  and the bubble wrap?
# res :  that will be 200 pounds and seventy six pence.
#  gt :  that ’ s another quid .
# multiturn : <sp2>  I am good at stewing beef with potato, frying chicken, hot and sour soup etc.  <sp1>  So many dishes. Next Friday week is my birthday. I would like to invite you to cook for my dinner party, OK?  <sp2>  Why not? It is a good opportunity for me to practise cooking.
# user : <sp1>  Thanks a lot.
# res :  Happy birthday!
#  gt :  It's my pleasure .
# multiturn : <sp2>  This is room 2012. Where is my laundry? You promised to send to me this morning.  <sp1>  Well, let me check for you. I am sorry, sir. They mistook your order as a normal one.Actualty it's an express laundry, is that right?  <sp2>  Yes, I ordered the express service.
# user : <sp1>  Sir, we are terribly sorry for that.We will refund the charge and send your laundry to your room 3 hours later. Is that all right?
# res : Thank you, Sir ; it's all right with me.
#  gt :  That's fine .
# multiturn : <sp1> I'd like you to do me a favor.  <sp2>  What is it?
# user : <sp1>  Can you mail this at the post office for me? I have to go to the doctor for an appointment and I don't have enough time to go to the post office.
# res : Will it be ten dollars?
#  gt :  Sure . And I'd like you to get some cold medicine for me when you go to the doctor's .
# multiturn : <sp1> Excuse me, may I help you?  <sp2>  Would you please fill some gas for me?
# user : <sp1>  Sure. Which kind of gas do you want?
# res : I want 500 RIB, A 30L tank.
#  gt :  Unleaded , please .
# multiturn : <sp2>  All right. But we demand the draft be accepted by a bank acceptable to us.  <sp1>  A bank's acceptance will add to the costs of our imports. You can rest assured that we will accept the draft and honour it when it comes due.  <sp2>  Then we will be in a position to arrange for a loan from our bank. You know we exports would like to have our investments returned as early as possible.
# user : <sp1>  I hope this transaction will pave the way for further business relations between our two countries.
# res : There is nothing we can do to delay the decision on the purchase of a single building or a site ; we have long been prepared to accept these kinds of proposals.
#  gt :  So do I .
# multiturn : <sp2>  That's nice, but tell me what she looks like.  <sp1>  The first thing I noticed was her beautiful brown eyes.  <sp2>  I think I might've bumped into her before.
# user : <sp1>  Are you telling me that you've seen her before?
# res :  I think so. What did she say?
#  gt :  I believe so .
# multiturn : <sp1>  Do you still want the car, sir?  <sp2>  Yes. It will be fun. Driving back down the coast. My girlfriend will like it.
# user : <sp1>  It's a beautiful drive.
# res : Thank you.
#  gt :  Where are the keys ?
# multiturn :
# user : <sp1> Gary. Could you type up this report for me? I have to take off early this afternoon.
# res : I will. I'll come back with your report on Saturday afternoon.
#  gt :  Sure . Just leave it to me . I'll finish it .
# multiturn : <sp1>  You are not too bad as well. I also want to have a steamed lobster. It is really taste like heaven.  <sp2>  Let's go into the restaurant and find a table to order some food.
# user : <sp1>  Wait. Let me tell the lady what we would like to order in front of the seafood fridge first.
# res :  She will tell us what we would like to order.
#  gt :  OK . I will wait for you inside the restaurant
# multiturn : <sp1>  It will cost you $ 10.  <sp2>  By the way, what's the time?
# user : <sp1>  You can see the time on the meter. I have radio time, you know.
# res :  I don't care what time I dial it.
#  gt :  It's a quarter to 12 . Could you please drive a little faster ?
# multiturn : <sp1>  You are right.  <sp2>  This is the very thing I've been dreaming of.
# user : <sp1>  It is the best quality porcelain-the famous egg-shell China.
# res :  Of course it is.
#  gt :  It must be most precious .
# multiturn : <sp2>  Sure. Do you want it to be registered?  <sp1>  Yes, I think so. There are some pictures in it. It would be a great pity if they were lost.  <sp2>  Yes, I will be glad to mail your letter.
# user : <sp1>  Thanks.
# res : Thank you very much.
#  gt :  you are welcome .
# multiturn : <sp1>  It really hurts.  <sp2>  Yes, maybe it does.But if you're going to drive like you did just now, you will have to get used to a little physical pain. You know what I mean?
# user : <sp1>  To hell with you. The accident was your fault.
# res :  So it wasn't your fault?
#  gt :  I'm afraid it wasn't . And when the police get here , you will also see that it wasn't . But enough of this bickering . I'm going to go find a phone.Don ' t move that arm while I'm gone . Alright ?
# multiturn : <sp1>  Oh, it's a reserved opera named The Monkey Creates Havoc in Heaven.  <sp2>  Wow, a story about the clever Monkey King. It's a classic and children's favorite.
# user : <sp1>  It surely is. And the cast is really the best.
# res :  It's the most beautiful opera of all time.
#  gt :  Wonderful ! How much is the ticket ?
# multiturn : <sp1> All right. I want to bring everybody back on this subject. When can we start working on this?  <sp2>  Well, we could probably get started with a preparatory meeting this afternoon at 2:00.
# user : <sp1>  I tell you what, 2:00 is not available for me, but you can get started and I'll come by at around 3:00
# res :  7.
#  gt :  That's fine with me . How much time are we going to have to work on this ?
# multiturn : <sp2>  French dressing, please.  <sp1>  I beg your pardon?  <sp2>  Oh, French dressing.
# user : <sp1>  Sorry, it's not available now.Anything else?
# res :  Here you go.
#  gt :  We still prefer French dressing .
# multiturn : <sp2>  Good. Thank you.sir.  <sp1>  Would you like to have some more beer?  <sp2>  No, thanks. I'Ve had enough. I'll have my bill, please.
# user : <sp1>  Of course. Please wait a moment. I'll go and get it.
# res :  See you then.
#  gt :  Thank you .
# multiturn : <sp2>  You misunderstood me. Clothes which are too colorful or too expensive suggest that you do not understand what behavior is appropriate for the job, or that you are snobbish or frivolous.  <sp1>  I know what you mean. I ought to wear right clothes at the right time.  <sp2>  You got it. Only in this way can you gain the respect of the interviewer and his confidence in your judgement.
# user : <sp1>  It seems that'clothes make the man '.
# res :  Too silly or boring for him to keep wearing a suit of clothes for a long time.
#  gt :  It may not be true , but the first and lasting impression of you is determined by your clothes and behavior .
# multiturn : <sp1> The boss announces the pay raise today, right? How much do you think we'll get?  <sp2>  No idea. Your guess is as good as mine.
# user : <sp1>  It better be more than last year.
# res : Don't worry. I know we'll get a raise.
#  gt :  Well , anything is better than nothing . Wait and see .
# multiturn : <sp1> I'm sorry, our appointment has to be changed.  <sp2>  What a pity!
# user : <sp1>  If you don't mind, may we put it off to the next day?
# res : Yes, Of course, It is our pleasure.
#  gt :  That's OK .
# multiturn : <sp1>  Thanks. Have you got the L / C number?  <sp2>  It's NX567822100007.
# user : <sp1>  Hang on a tick and I'll check for you. I'm sorry ; we have no record of that arriving.
# res :  Ok ; I'll check you again next time ; thanks.
#  gt :  OK , thanks for checking . Could you give me a ring when it arrives , please ?
# multiturn : <sp1> May I help you?  <sp2>  Yes. I have to stay in your cry for just one day, can you suggest a short tour?
# user : <sp1>  Are you interested in the natural landscape or the human landscape?
# res : We do want to visit the natural environment, But I think the world is very important. I want to go to the wilds, I want to visit the vast forests, And I want to get acquainted with the cultures.
#  gt :  I would prefer the first one .
# multiturn : <sp2>  I need to find out some more information for L / C. I would like an outline of responsibilities, both ours, yours and the beneficiary, please.  <sp1>  OK, to start, the conditions are specified by the buyer and may include Insurance Forms, Way Bills, Bills of Lading, Customs forms, various certificates.  <sp2>  OK, got it. Is there anything else I need to know before we go ahead?
# user : <sp1>  Just that in effect, a basic Letter of Credit is a financial contract between the bank, the bank's customer, and the beneficiary, and this contract involves the transfer of goods or services against funds.
# res : As I know now, Money deals are used very often for the acquisition andPuppy-banks are very common, Like Toyota Corp ;
#  gt :  That sounds fine , thanks for that . Let's go ahead !
# multiturn : <sp2>  I haven't checked yet.  <sp1>  Why do you think there was a break-in?  <sp2>  My front window was broken.
# user : <sp1>  We'll send a squad car shortly.
# res : Thanks ; You're welcome ; I'll see you in the hospital then.
#  gt :  I'd appreciate that .
# multiturn : <sp2>  One dollar.  <sp1>  So, I can have five for five dollars?  <sp2>  Actually, you can only have four.
# user : <sp1>  Oh, yeah. I forgot tax. Give me four then, please.
# res :  Uh, Where is your receipt?
#  gt :  Okay . Thanks .
# multiturn : <sp1>  Good evening, sir. I come to make the bed. Shall I do it now or later?  <sp2>  Well, since you have come, do it now please?
# user : <sp1>  That's all. Have a nice stay here.
# res :  I hope so.
#  gt :  Thank you.Please get some soap for us .
# multiturn :
# user : <sp1> Ms. Montgomery? This is Richard Thomas. I ’ m sorry to bother you at home, but I ’ Ve got a bit of a problem.
# res : Why not call Mr. Thomas ‘ Mr. Montgomery please?
#  gt :  Oh ? What ’ s wrong ?
# multiturn : <sp1>  I see. This is my advantage.  <sp2>  Good. Have you got any other questions?
# user : <sp1>  No.
# res :  I just want to check on your watch.
#  gt :  Ok , I will contact you in a week . See you .
# multiturn : <sp2>  Can you take he away from me?  <sp1>  I ’ m just coming for that.  <sp2>  She kept bothering me.
# user : <sp1>  She ’ s your sister. What she asked was only duck soup for you. Why can ’ t you be good to her?
# res :  Because you ’ are my sister and you ‘ are my brother.
#  gt :  But I am her brother , not her servant .
# multiturn : <sp2>  Maybe you should look around for an outlet.  <sp1>  That is a wonderful idea.  <sp2>  Outlets have more reasonable prices.
# user : <sp1>  Thank you for your help.
# res :  Thank you for your help.
#  gt :  No problem . Good luck
# multiturn : <sp1>  Now that's more like it! Bananas have lots of potassium, too!  <sp2>  They're also good for your digestion! Would you like some kiwis, too?
# user : <sp1>  Are they from Taiwan?
# res : Yes, They are from Taiwan.
#  gt :  They're imported from New Zealand . Four for 50NT . Nine for a hundred .
# multiturn : <sp2>  it'll be sad to see you go, but it sounds like you're found yourself a great opportunity.  <sp1>  I have. I feel lucky. I look forward to dealing with overseas companies and at the same time having a chance to use English more.  <sp2>  I'm sorry to bring this up, but would it be possible for you to write me a letter of recommendation before you go?
# user : <sp1>  of course I can. In fact, if there are other job opportunities at this new company, I'll recommend you personally.
# res :  I think it's really nice of you to help us.
#  gt :  thanks . I appreciate that .
# multiturn : <sp1> What can I show you?  <sp2>  Do you have this shirt in a small?
# user : <sp1>  Let me check. Yes, we have.
# res : Sure. What color would you like it in?
#  gt :  May I try it on ?
# multiturn : <sp1> the James ’ s file, Christine?  <sp2>  I had it right here a minute ago, Mr. Emory. Umm. Just a minute...
# user : <sp1>  Christine, I know you ’ re new here and there ’ s a lot to learn, but you are going to have to learn to keep your work in better order. We can ’ t afford to lose an important document.
# res :  Um.. I think so. I got what you asked for, Mr. Emory.
#  gt :  Yes , sir . I apologize for that . Here ’ s the file you were looking for , Mr . Emory .
# multiturn :
# user : <sp1> I wonder whether I could possibly borrow your new bicycle now.
# res : Yes, You can try it out.
#  gt :  Sorry , I'm using it myself.But you can use it this afternoon .
# multiturn : <sp2>  I think he's hot too.  <sp1>  How do they all get in such tiptop shape?  <sp2>  Exercised over and over. Exercise is a key.
# user : <sp1>  That's it. I decided to turn over a new leaf. I'm going to exercise every single day.
# res :  Give me a break.
#  gt :  Good for you , Leslie !
# multiturn : <sp2>  Thanks. I'll be right back.  <sp1>  OK.  <sp2>  Here's your receipt.
# user : <sp1>  Thank you.
# res :  Thank you.
#  gt :  You're welcome . Please come again .
# multiturn : <sp2>  I'm going to quit the job.  <sp1>  Why?  <sp2>  The task is tough.
# user : <sp1>  You'd look before you leap.
# res :  I hope I'm not alone in this.
#  gt :  Thanks for your concern .
# multiturn : <sp1> How long will you stay in New York?  <sp2>  Just tor three days. I won't need these luggages.CouId I put them here?
# user : <sp1>  I am sorry. If you have here more than 24 hours between connecting flights, we can't check your luggage through London.
# res :  I'm sorry, But they must be inside the United States for a long period of time ; you will have to check them for me.
#  gt :  Well , maybe I can put them in the airport storage there .
# multiturn :
# user : <sp1> Eat some more.
# res : I've been thinking about it.
#  gt :  No , thanks . I'm on a diet .
# multiturn : <sp2>  That's over on Callaway Street, isn't it?  <sp1>  Yes, but I can't find Callaway Street.  <sp2>  Walk that way for about four blocks. The hotel's about two blocks north of there.
# user : <sp1>  Thanks a lot.
# res : You should stop by the hotel in the back.
#  gt :  Not at all .
# multiturn :
# user : <sp1> I'm sorry I'm late.
# res : You didn't mean to. I'm sorry.
#  gt :  Better late than never .
# multiturn : <sp2>  For what? Are you taking up painting?  <sp1>  No. I can't paint. I'm asking for my niece. She is really into it.  <sp2>  Oh, good. How old is your niece?
# user : <sp1>  She is eight. Actually, I'm buying a good set of art supplies for her as a birthday gift.
# res :  Why not go shopping for something else, Dad?
#  gt :  It's a wise thing to do . Art will do a child a world of good .
# multiturn : <sp1>  O. K. No problem. Anything else?  <sp2>  No, but if she has any questions, she can call me at 555-2345.
# user : <sp1>  All right, I ’ ll leave her the message, Mary. Thanks for calling.
# res :  Thanks ; I'm glad you want to speak with me again.
#  gt :  Thank you . Bye .
# multiturn : <sp1> Do you speak English?  <sp2>  Yes, a little.
# user : <sp1>  Can you tell me how to get to the Jade Buddha Temple?
# res : Get off at the entrance of the Temple Gate.
#  gt :  I'm sorry . I can't quite follow you . Would you mind speaking slowly ?
# multiturn : <sp1> How do you get road news?  <sp2>  I've a driver mate in my car!
# user : <sp1>  So you have all the news on broadcast?
# res : Of course! What is the quality of air traffic today?
#  gt :  Yes , it's so helpful .
# multiturn : <sp1> Can I help you?  <sp2>  Yes, I'm in a bit of a rush. Could I have a piece of apple pie please?
# user : <sp1>  Certainly. Would you like it with ice cream?
# res : Sure.
#  gt :  No , thanks .
# multiturn : <sp1> I'd like to make an appointment with Dr.Cooper.Could you arrange it for me?  <sp2>  Yes.Would tomorrow morning be all right with you?
# user : <sp1>  Sorry, I've got a meeting from nine to ten.What about Monday afternoon?
# res : That will be fine, But please take care of your health first.
#  gt :  I'm afraid he's fully engaged.Could you make it another time ?
# multiturn : <sp2>  Where'd you get those?  <sp1>  I found them at JC Pennies.  <sp2>  Those are really cute.
# user : <sp1>  Do you want me to show you where I found them?
# res : I'll get them right away.
#  gt :  I would like that . Thank you .
# multiturn : <sp1> Hello, is that Xiaogang Li who applied for the Solar Studio of our college?  <sp2>  Yes, speaking.
# user : <sp1>  I want to know whether you will come to the interview. So have you accepted offers from other companies?
# res :  Yes, I accepted the offer of the Energy Capital program from a company I am an employee of.
#  gt :  No , I haven't got one by now . I will go to the interview of yours .
# multiturn : <sp2>  Yes, that would be best. Now, for food should we have Chinese or American food?  <sp1>  American food would be the best choice.  <sp2>  That would be great. What kind of music would you like, a band or recorded music?
# user : <sp1>  We should bring in a really good DJ.
# res :  We'd love to come here ; I'Ve heard of record stores such as this one in San Francisco.
#  gt :  That works for me . Let's see what we can each do about planning our part and meet again on Friday .
# multiturn :
# user : <sp1> Help! Help!
# res : This guy's laughing. Is he laughing?
#  gt :  What's the matter ?
# multiturn : <sp1> What would you like to eat, sir?  <sp2>  Scrambled egg, bacon, three pieces of bread and a cup of tea.
# user : <sp1>  Would you care for some lemon for your tea?
# res :  Of course.
#  gt :  No , thank you .
# multiturn :
# user : <sp1> Where's the toilet?
# res : It's on the fourth floor.
#  gt :  Over there .
# multiturn : <sp1>  But there are only two more days until the bidding closes!  <sp2>  I bid on a Chanel watch at the last minute, and got it sixty percent off!
# user : <sp1>  Oh... I'm such a newbie. But at least I'm sure I'll get that tennis racket.
# res :  Get your money back, Anne. Don't let a brick fall on your head, Anne.
#  gt :  Don't count on it , Babe . eBay is always full of surprises .
# multiturn : <sp2>  But our credit card saves you 10 percent.  <sp1>  That's a nice discount.  <sp2>  Here. Let me give you an application form.
# user : <sp1>  Thank you, but I'm just browsing today.
# res :  Ok, Here it is.
#  gt :  Okay . Enjoy your browsing .
# multiturn : <sp2>  I'm allergic to these things, you know.  <sp1>  Sorry, I forgot. I don ’ t like seafood, neither.  <sp2>  Let ’ s go over there and get some milk, a couple dozen eggs and some orange juice.
# user : <sp1>  Let's get frozen juice. It is really good. We ’ Ve got enough food. Let ’ s go over to the check-out stand.
# res :  Thank you, Dave. I'm sure you will enjoy your meal.
#  gt :  OK . But just let me pick up a bottle of cooking wine and oil as we go by .
# multiturn : <sp2>  Oh, my God! I hope you are all right.  <sp1>  I have a concussion, but I will be OK.  <sp2>  How much school will you miss?
# user : <sp1>  I only need to take this week off.
# res :  Oh, I really appreciate the offer.
#  gt :  I appreciate you calling and telling me that you won ’ t be in class . See you next week !
# multiturn : <sp1> Hello, Parker. How ’ s everything?  <sp2>  Can ’ t complain. And you?
# user : <sp1>  Business is booming. I understand you want to meet up with me next week. How ’ s your schedule looking?
# res : Nothing too difficult ; I ‘ve got no agenda, So it ‘ not difficult to arrange.
#  gt :  Let me see . I can come out and see you first thing Wednesday .
# multiturn : <sp1> How come it is slow as a snail today?  <sp2>  You mean the network connection?
# user : <sp1>  Yes, I wanted to look for some information on the company page just now. It took me almost one minute to open it. Then there is no response to any click.
# res : Oh, Wait a second, It looks like it's been sitting on your hard drive for too long.
#  gt :  I have the same question . I can ’ t send out mails . We ’ d better call the IT department and ask them to check it immediately .
# multiturn : <sp2>  Dad, I have to do my homework.  <sp1>  No, honey, why didn't you go to cram school last night?  <sp2>  Dad, I don't want to talk about it now.
# user : <sp1>  Honey, if you don't want to go to cram school, you should tell me the reason why.
# res :  I have a lot to learn and I really need some help here ; I'Ve already memorized a lot of English and learned to write some good letters ; I think I can get a few more girls on my teams to practice with ; I'll take them to a competition if I can.
#  gt :  I'm sorry , dad . But I would rather stay at school than go to cram school .
# multiturn : <sp2>  Do you think I should lie in bed?  <sp1>  Yes, stay in bed and drink a lot of water. Your fever will be gone in a day or two.  <sp2>  OK. Do you think I can play football tomorrow?
# user : <sp1>  Of course not. You need a good rest.
# res :  Then you should look for another job.
#  gt :  OK , I'll listen to you .
# multiturn : <sp2>  Do you want to know what kind of pie I like?  <sp1>  Sure, what kind do you like?  <sp2>  I love apple pie.
# user : <sp1>  Oh, I love apple pie too.
# res :  But I like fried fish pie too.
#  gt :  There you go . Problem solved .
# multiturn :
# user : <sp1> Let's go now.
# res : Yes, We can take a taxi.
#  gt :  I'll be with you in a minute .
# multiturn : <sp2>  Could you tell me what the exchange rate for USD is today?  <sp1>  The buying rate is 826. 44 yuan for 100 dollars.  <sp2>  I want to change some Us dollars to cover my expense here.
# user : <sp1>  Please go to Counter No. 2, the foreign exchange counter. It's over there.
# res :  Please check it out ; it's not too expensive.
#  gt :  Thank you .
# multiturn : <sp1>  Never mind being sorry, what are you going to do about it?  <sp2>  Don't worry, we'll soon fix them.
# user : <sp1>  Good, I hope you'll make sure that it won't happen again.
# res :  Is there anything you'd like to do now?
#  gt :  I'll certainly look into that .
# multiturn : <sp1>  Is there a price reduction?  <sp2>  We are having a sale now. The price has already gone down.
# user : <sp1>  How much is that one?
# res :  $ 120 a square foot.
#  gt :  It's two hundred and eighty dollars .
# multiturn : <sp2>  Can I test it out?  <sp1>  Of course.  <sp2>  It sounds great. I'll take it.
# user : <sp1>  Fine. I think you'll be happy with it. It's a very good unit. Very reliable. I'll go get you a new one in a box. I will be back in just a moment.
# res : I see.
#  gt :  Thanks .
# multiturn : <sp2>  I tend to spend too much time making sure the customer is satisfied. However, I began setting time-limits for myself.  <sp1>  Why do you want to work for our company?  <sp2>  After following your firm's progress for the last 3 years, I am convinced that your company is becoming one of the market leaders and I would like to be a part of that team.
# user : <sp1>  When can you begin?
# res :  We are in talks to arrange a promotion for our new PR department.
#  gt :  Immediately .
# multiturn : <sp2>  Well, all right. There are four points you should keep in mind when you file documents, information and other things.  <sp1>  What are they?  <sp2>  They are keep the documents in chronological order, remove all the chips and pins, punch the documents evenly and place them in the folder.
# user : <sp1>  And what is the most important point?
# res :  Don't forget to give special notice to any such documents if you wish to file a complaint.
#  gt :  You should always remember that one customer one file is the rule .
# multiturn : <sp1> Yeah, look at all those new buildings going up! Mr. Zhang, the traffic is pretty smooth. But we were told the roads from the airport to downtown were quite crowded and traffic jams could be as long as half an hour.  <sp2>  Yes, they were. But it has already past. The traffic from the airport to downtown has been relieved after the completion of Yan'an Aerial Road.
# user : <sp1>  We've never expected that Shanghai is such a big metropolis, same as New York city. David, would it be a good idea to rent a car here? I've got an international driver's license with a pretty good record in the States.
# res : Would you recommend driving in this part of the world?
#  gt :  That's wonderful . OK . I'll remember that . But I have to warn you that you must drive very carefully in the downtown area , for there're no separate lanes for motor vehicles and bicycles in some places , and still quite a few people don't take road regulations seriously .
# multiturn : <sp2>  I hear that the kitchen is quite large. Let ’ s go check it out.  <sp1>  The kitchen may be large, but it doesn ’ t have any storage space.  <sp2>  The master suite is supposed to be quite elegant. Maybe it will be a little better.
# user : <sp1>  How many dogs live in this house?
# res :  The dogs are said to live in five rooms ” The master suite has nine dogs ; the second unit has four.
#  gt :  I think that we have seen all that we need to see here . Let ’ s go look at another house .
# multiturn : <sp1> Excuse me, waiter, I would like to have some wine before the main course.  <sp2>  Have you decided what wine you would like?
# user : <sp1>  I have no idea. Maybe you can give me some advice.
# res :  I'd like to have a glass of champagne with me.
#  gt :  I recommend you the white wine . It will wake up your appetite .
# multiturn : <sp1>  Well, it won't if there no line at the pump.  <sp2>  Well, I'm not quite ready.
# user : <sp1>  I'll give you five more minutes, then I'm going on without you!
# res :  Can I still have a line?
#  gt :  You wouldn't do a thing like that !
# multiturn : <sp1> I wonder if I can see your mother, little boy. Is she engaged?  <sp2>  Engaged? She ’ s married.
# user : <sp1>  Johnny, I wish you ’ d stop reaching for things. Haven ’ t you a tongue?
# res : Never mind. I'll take the first one for you.
#  gt :  Yes , Mother , but my arm is longer .
# multiturn : <sp2>  It'll be our pleasure. We'll call you at 7 and then at 7 fifteen.  <sp1>  Oops, cancel that. Change the second call to 7 thirty will you, please?  <sp2>  No sooner said than done. Can I help you with anything else?
# user : <sp1>  No, that's about it for now. Thanks.
# res :  Oh, Yeah, Just call me over.
#  gt :  Okay , sir . Have a pleasant evening .
# multiturn :
# user : <sp1> Have you seen our new packing specifications?
# res : Yes.
#  gt :  Yes , I have , Mr . Thomas . We'll pack them two dozen to one carton , and the gross weight is around 25 kilos a carton .
# multiturn : <sp1> I'm really in a flap about the interview.  <sp2>  Take it easy.you'Ve made enough preparations.
# user : <sp1>  I'm in such a need of the job that I can't afford any mistakes.
# res : You're so right!
#  gt :  I'm sure you'll pass it .
# multiturn : <sp2>  Let me see. Laptop, flash disk, a ballpoint pen, a pencil, a notebook, a pair of glasses, cell phone, charger, moisture lotion,... Oh, that is too much. You are not going to a business trip.  <sp1>  I guess I need all of them.  <sp2>  Actually, the company will provide you with all of these supplies. So, you can leave this very thick notebook at home.
# user : <sp1>  I know. But it is my lucky charm. I carry it all the time.
# res :  Hmm, Wait a minute. I don't have to worry about such things.
#  gt :  Suit yourself . Don ’ t forget to set the alarm clock .
# multiturn : <sp1>  I'm sorry. You are going in the wrong direction.  <sp2>  Oh no! What shall I do?
# user : <sp1>  Don't worry. You can get off at the next stop and go across the street through the overpass. The bus stop is right there.
# res :  That's a good idea. You should check the safety ticket before you leave.
#  gt :  Thank you very much .
# multiturn : <sp1>  I see. We will go the day after tomorrow.  <sp2>  By the way, what kind of stores do we need to go?
# user : <sp1>  I want to buy some clothes in clothing store. When we are going back, go to the butcher's shop and buy some chicken.
# res :  I see, That would be fine.
#  gt :  Let ’ s also go to the jewelry store to buy a crystal necklace . I want to buy one for you as your birthday present .
# multiturn : <sp1> Have you seen the tower in front of us. That's the famous Eiffel Tower. It was built in 1889 for the World's Fair.  <sp2>  How tall is this building?
# user : <sp1>  It stands 320m ( 1050ft ) high and held the record as the world's tallest structure until 1930.
# res : Wow! I'Ve never seen anything like this before.
#  gt :  I have heard its name is connected with someone , is that right ?
# multiturn : <sp2>  That ’ s 1POJ7403.  <sp1>  That ’ s correct.  <sp2>  Thank you!
# user : <sp1>  Is there anything else I can do for you?
# res :  We have something for sale at the airport.
#  gt :  No , thanks . I ’ m all set . Good-bye .
# multiturn : <sp1> Is this supply?  <sp2>  Yeah. This is supply. What can I do for you?
# user : <sp1>  This is Rachel in Human Resources. I need two boxes of company letterhead, one box of ball-point pens, and a box of envelopes.
# res : What kind of envelopes do you need?
#  gt :  All right . No problem . What ’ s your extension ?
# multiturn : <sp1>  He has a mustache, if I remember correctly, and a light complexion.  <sp2>  How old is he?
# user : <sp1>  He is in his late thirties.
# res : Which one is he?
#  gt :  Well . I shouldn ’ t have any trouble recognizing him . What time does his flight arrive ?
# multiturn : <sp2>  May I have a Sprite, please?  <sp1>  Sure, no problem.  <sp2>  I would also like a bag of chips.
# user : <sp1>  Will that be all?
# res : Let me check.
#  gt :  That's everything .
# multiturn : <sp2>  I care about people and I know the importance of insurance.  <sp1>  Do you have any work experience in promotion?  <sp2>  Yes, I do. I have worked as a salesman for P & G Company Ltd.
# user : <sp1>  Do people respond well to you?
# res :  Yes, We do.
#  gt :  Yes , I'm good with people .
# multiturn : <sp2>  This is the place I was telling you about.  <sp1>  Would you like to sit near the window?  <sp2>  Good.
# user : <sp1>  Let's have a look at the menu. Oh, there isn't a menu. Do you think you could ask the people at the next table if we could look at their menu?
# res :  I'll try.
#  gt :  Yes , of course . Excuse me . Could you possibly let us see your menu ? Oh . They haven't got one either .
# multiturn : <sp1>  Your discount is already included. Normally we charge ¥ 400, but now we can give you a special price. This is our sale period.  <sp2>  It ’ s still too much. Can ’ t you make it any cheaper than that?
# user : <sp1>  Sorry, but this is the best price. You can ’ t get it any cheaper than here.
# res :  How about it from this side?
#  gt :  I see . Can I pay by traveler ’ s checks ?
# multiturn : <sp2>  Well, first you have to turn this switch on.  <sp1>  Silly me.  <sp2>  Now press this button.
# user : <sp1>  Oh, and it's out of paper. Do you have any more?
# res : No, Thanks. I don't have any more books.
#  gt :  Just a second . I'll go get some .
# multiturn : <sp2>  The quarters go into the slot. You have to push the slot in, and the machine will turn on.  <sp1>  Is that everything that I have to do?  <sp2>  That's all there is.
# user : <sp1>  I appreciate you helping me with this.
# res :  Thank you very much.
# ...
# res :  Could you come to see Susan at home?
#  gt :  Yeah , maybe . Thanks , anyway . Hope you guys have a great time !
# multiturn : <sp2>  Not at all. The changing rooms are just this way.  <sp1>  Thanks. It's a little tight. Do you have any in a larger size?  <sp2>  Sure. I'll give you the next size up. That one is small, right?
# user : <sp1>  Yes. Also, I'm not so sure about the color.
# res : It's pretty nice that you're a single father now, But you're very kind. Do you know how to put it?
#  gt :  Well.It doesn't go with your skirt . I think the color itself is fine though .
# multiturn : <sp2>  I ’ m not kidding.  <sp1>  It ’ s a good thing I asked you.  <sp2>  That should ’ Ve been something you knew already.
# user : <sp1>  I couldn ’ t remember.
# res :  It ” is kind of all the right ” to say so.
#  gt :  Whatever . Just make sure you go vote .
# multiturn : <sp1>  I've been talking to WebTracker. I'm thinking of jumping ship.  <sp2>  What? Are you serious? You'd defect to our archrival!?
# user : <sp1>  Keep your voice down. We'll talk more later. Right now I need to see Vince.
# res : I'll do that later, Come and talk to him in person sometime.
#  gt :  We definitely have to talk , Zina . And watch your back . Elvin is still mad about his nose .
# multiturn : <sp2>  Is that right?  <sp1>  Yup, and you can keep the money in your pocket.  <sp2>  That sounds nice.
# user : <sp1>  You should go get yours.
# res :  I'd love to get mine.
#  gt :  Yeah , I think I will .
# multiturn : <sp1>  Oh, I'm sorry, 447-9626.  <sp2>  Yes, that's right. Extension 162.
# user : <sp1>  Extension 162. Okay, Mr. Suzuki. I'll give him the message.
# res : Thank you.
#  gt :  Thank you . Good-bye .
# multiturn : <sp1>  Let's line up. The steak is very inviting. I'll have it.  <sp2>  I'll have ham and egg with French fries. What dessert do you want?
# user : <sp1>  Banana pie.
# res :  Strawberry muffin with strawberry jam, lemon jam, and honey syrup. It's perfect. Thank you very much.
#  gt :  Where shall we sit ?
# multiturn : <sp2>  Italian, Indian and chinese. I ’ Ve only recently started cooking chinese meals and I need some more practice.  <sp1>  Do you find it hard to get ingredients for Chinese food?  <sp2>  Not at all.You can find most of them in supermarkets.The ingredients are usually the same as in Western food.The way that the food is prepared is the big difference, not the ingredients.
# user : <sp1>  How long does it take you to cook a meal for 5 or 6 people?
# res :  5 to 6 hours.
#  gt :  Obviously , it depends on what I ’ m cooking.But I ’ d say it generally takes about one and a half hours .
# multiturn : <sp2>  That one truly is a beautiful piece of work, isn't it?  <sp1>  One last question  <sp2>  Oh, no. Everything we sell here is " as is. "
# user : <sp1>  I guess I was asking for too much.
# res :  Really, How about this one?
#  gt :  If it breaks down , maybe you can find a repairman on the Internet .
# multiturn : <sp2>  Ok. How about we get a cat or a ferret?  <sp1>  We ’ re planning on having children soon, I don ’ t think those animals are a good idea with a baby in the house.  <sp2>  Fine! Let ’ s get a bird then! We can keep it in its cage and teach it to talk! A parrot would be awesome!
# user : <sp1>  I ’ ll tell you what, I can get you some hamsters and we ’ ll take it from there.
# res :  I ’ vouch for that, I ’ var a squirrel and get my ‘ ‘ animals to live with the hamsters and squirrels when they are young!
#  gt :  Yay !
# multiturn : <sp2>  But I haven't used exercising equipment before. Can you tell us some more details?  <sp1>  Certainly. We have here the race apparatus, stationary bike, muscle builder set, chest expander, bar bell, dumb bell and so on.  <sp2>  Working in the gym is a very good way for losing weight. What else do you have?
# user : <sp1>  Here's the swimming pool. It's open from 10 a. m. to 11 p. m. There are also massage rooms here.
# res : Sounds good. So I'm going to use that pool to drink water during the race?
#  gt :  That's wonderful ! I like swimming .
# multiturn : <sp2>  Hey, I've always gone hunting or fishing on vacation. I am sorry that bothers you.  <sp1>  After a year together, I thought it pretty safe to assume that we would automatically spend our vacation together.  <sp2>  Says who? I don't think that is necessarily the case.
# user : <sp1>  You know, now that I think about it, I really don't have much more to say to you at all!
# res :  It is a pity to have to share a vacation with you again ; it is such a great honor to have been invited by you to a treasure hunt.
#  gt :  Whatever you say !
# multiturn : <sp1> Have you declared your income and are you prepared to pay tax?  <sp2>  Not yet. I don't know how to fill out the form. What is the tax-free allowance for supporting a dependent?
# user : <sp1>  I don't really know. Why not ask the accountant or the lawyer of the law firm? They will tell you which is subject or not subject to taxation. He can even help you avoid paying tax legally.
# res : Great! Now I am sure I can qualify for a tax free allowance.
#  gt :  If I don't pay my taxes , would the tax officials discover it ?
# multiturn : <sp2>  What would you do if you were in my shoes?  <sp1>  Just stay cool. You know. When you get back home tonight, tell him that you didn't mean to quarrel with him.  <sp2>  No way, Kate. I mean it's just not my fault.
# user : <sp1>  I know. It wouldn't hurt much to say sorry first. And after that, you can casually mention the problem. I am sure he will cooperate.
# res :  I am very sorry for you ; I didn't mean to bother him again ; I just thought I would be quiet this time.
#  gt :  I am too angry to do that .
# multiturn : <sp1> Excuse me. I am looking for a book called Little Women, but I can't find it anywhere.  <sp2>  Let me see. I am sorry we just have sold it out.
# user : <sp1>  Will you have it later?
# res : Sure. Here you are.
#  gt :  I think so . Could I have you name , telephone number ? If we get one , I will call you .
# multiturn :
# user : <sp1> Who do you think is the greatest novelist in the history of English literature?
# res : I think that William Wordsworth.
#  gt :  Charles Dickens.Actually no one can parallel him in writing .
# multiturn : <sp1>  Do you play bridge?  <sp2>  Yes, I do. It ’ s hard to find four players though, so I don ’ t play very often. Do you know anyone who plays? If so, we could set up a game.
# user : <sp1>  I can play quite well. I have a friend who likes playing, but she ’ s not very good at it. Shall I invite her to play?
# res :  I think so.
#  gt :  Sure , I have a friend who play fairly well . We should find out when our friends are free and arrange a game .
# multiturn : <sp2>  Sure. The coach leaves at 6:30 a. m., in front of our office. The drive takes eight hours, with two stops to see some sights.  <sp1>  What about the hotel accommodations?  <sp2>  You'll be staying at Holiday Inn. It's a three-star hotel with two restaurants and a swimming pool.
# user : <sp1>  Great. What types of things will we do at Lushun Falls?
# res :  Hotel guests will be served on night tours. Most of the tours are for 1, 2, 3 days.
#  gt :  The second day you take a four-hour city tour . In the afternoon you go on the famous boat cruise under the falls .
# multiturn : <sp2>  Any idea when he might be back?  <sp1>  Well, he shouldn't be long. He said he was just going to get some paint. But I wouldn't be surprised if he's stopped off at the pub on the way back.  <sp2>  OK. well, tell him I've called, will you, and I'll try again later.
# user : <sp1>  All right. Goodbye, Dave.
# res :  Bye.
#  gt :  Thanks then Sally . Goodbye .
# multiturn : <sp1>  Sure that ’ s fine. Here is the list of all the things you need to get. Don't forget anything! And can you pick up a bottle of wine on your way home?  <sp2>  Hey, honey I ’ m back. Wow, the house looks really good!
# user : <sp1>  Great! Can you set the table?
# res :  Ok. Will that be all tomorrow evening?
#  gt :  Just a sec I ’ m just gonna vacuum this rug real fast
# multiturn : <sp2>  I'd like to talk to somebody about the Group Account Deposit Service.  <sp1>  This refers to the deposit business offered to the level 1 account of group companies.  <sp2>  What is it used for? I mean, why bother to get this special account?
# user : <sp1>  Group companies can use this to make their arrangement of funds flexible, when dealing with their subsidiaries.
# res :  Sounds great ; I think I'll ask for your deposit account information.
#  gt :  I see , so this can really cut down on time and centralise management . Interesting ...
# multiturn : <sp2>  Yes, sir. What can I do for you?  <sp1>  I want to buy some specialties. Can you recommend me some?  <sp2>  Sure. I strongly advise you to buy a bottle of perfume and a lighter.
# user : <sp1>  Fine. They look nice. I will take both of them.
# res : Do you have any big specialties?
#  gt :  May I have a look at your passport , please ?
# multiturn : <sp2>  Oh, it looks well. I like it very much.  <sp1>  It's made in Jingdezhen.  <sp2>  How much is it?
# user : <sp1>  One thousand eight hundred yuan.
# res :  This one is a hundredth of an inch thick.
#  gt :  It's not expensive . I'll take it .
# multiturn : <sp1> Oh, so Dalian is hotter than New York now.  <sp2>  Not hot but warm. Very comfortable.
# user : <sp1>  Are you staying at the Hilton?
# res : Yes, I'd like to stay at the Hilton.
#  gt :  Yes , I have already booked a room .
# multiturn : <sp1> Could you show me what you've got?  <sp2>  We've got several good chicken dishes if you like chicken.
# user : <sp1>  We'll try one of your specials this time.
# res : Thanks. It's great.
#  gt :  This is worth trying .
# multiturn : <sp2>  That sounds good. But I have a proposal now.  <sp1>  What's the proposal?  <sp2>  Both of our two parties were involved in the discussion previously. Shall we also allow some of our clients to join us?
# user : <sp1>  Good idea! In this way, our clients'needs will be met and disagreements between the two parties avoided.
# res :  I would suggest that we come to an agreement on how to proceed and then finish the review in a week.
#  gt :  Sounds like we have the same idea .
# multiturn : <sp2>  Generally speaking, job seekers can enter the websites either of job agencies or of some units for job advertisements.  <sp1>  How should I contact them?  <sp2>  You can e-mail your application materials for application to the websites of job agencies for enrollment in their database.
# user : <sp1>  Can I get a quick reply from the sites?
# res :  If they haven't responded to you yet, You can try to send a quick email or send aphone call to the applications processing center if they haven't answered you.
#  gt :  Yes , usually it takes a short time , but you have to await the choice of the units for a while .
# multiturn :
# user : <sp1> Can you direct me to Holiday inn?
# res : I can call you any time.
#  gt :  Cross the street and walk two blocks west.You can't miss it .
# multiturn : <sp1> I would like to buy a bottle of cleansing milk.Can you recommend me some kinds?  <sp2>  Sure. What kind of skin do you have?
# user : <sp1>  My skin is oily.
# res : Which kind of soap are you using?
#  gt :  Then I advise you to buy the LAY cleansing milk .
# multiturn : <sp1> Hello, is Sue there?  <sp2>  Who?
# user : <sp1>  Sue John.
# res : Are you coming over?
#  gt :  You must have the wrong number .
# multiturn : <sp1> Sorry, stewardess. Where shall I put my bags?  <sp2>  You can place the smaller one in the overhead bin and put the bigger one under the seat in front of you.
# user : <sp1>  Thank you very much.
# res : Your kind welcome.
#  gt :  Please make sure to fasten your seat belt . We are to take off .
# multiturn : <sp2>  I think this color isn ’ t quite right for me. Do they have the same dress in white?  <sp1>  Let me look. Let ’ s see... they ’ Ve got one in blue, green, pink, black... and white. Here you are.  <sp2>  This is perfect! What do you think?
# user : <sp1>  I think you look fantastic. Happy Birthday!
# res : You're welcome.
#  gt :  I ’ m so lucky . You only get a chance like this once in a blue moon ! Thanks honey !
# multiturn : <sp2>  OK. Please do so if it is not troublesome.  <sp1>  No trouble at all. May I know your name and room number?  <sp2>  I'm Du Juan, in Room 312.
# user : <sp1>  I see. Wait in the room, please.
# res :  When is your flight on then?
#  gt :  Thank you for your kindness .
# multiturn : <sp1> Let's have seafood for a change.How about oyster and lobster?  <sp2>  I couldn't agree more!
# user : <sp1>  Anything else you want to add?
# res :  You can try lobster and shrimp.
#  gt :  Oh , yeah , two beers .
# multiturn : <sp1>  No problem. I'll give you an aisle seat in the center row. And here is your ticket, passport and boarding pass. Please board the plane at Gate 15.  <sp2>  Thank you. And when is the latest time for me to board the plane?
# user : <sp1>  15mins before the plane takes off. The plane is scheduled to leave on time.
# res :  And I have a ticket to London ; can you tell me where it leaves?
#  gt :  Thank you very much !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7ebdb9ef3721> in <cell line: 5>()
#       3 assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
#       4 manager = Manager(args, test_arr)
# ----> 5 manager.test()
#
# <ipython-input-14-59f6cce149e4> in test(self)
#     192                 token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)
#     193
# --> 194                 output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)
#     195                 res = self.tokenizer.decode(output_ids, skip_special_tokens=True)
#     196
#
# <ipython-input-14-59f6cce149e4> in nucleus_sampling(self, input_ids, token_type_ids, input_len)
#     101         output_ids = []
#     102         for pos in range(input_len, self.args.max_len):
# --> 103             output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
#     104             output = F.softmax(output, dim=-1)  # (1, V)
#     105
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1062             hidden_states = hidden_states.to(self.lm_head.weight.device)
#    1063
# -> 1064         lm_logits = self.lm_head(hidden_states)
#    1065
#    1066         loss = None
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
# -> 1692         output = input.matmul(weight.t())
#    1693         if bias is not None:
#    1694             output += bias
#
# KeyboardInterrupt:
