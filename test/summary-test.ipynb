# %% [markdown]
# ## load pretrained summary model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch/
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp39-cp39-manylinux1_x86_64.whl (776.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 1.6 MB/s eta 0:00:00
# Collecting transformers==4.12.5
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.8 MB/s eta 0:00:00
# Collecting datasets==1.16.1
#   Downloading datasets-1.16.1-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.3/298.3 KB 26.9 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.4 MB/s eta 0:00:00
# Collecting tensorboard==2.7.0
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 89.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch==1.7.1->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (3.10.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.12.5->-r requirements.txt (line 2)) (2022.10.31)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.5 MB/s eta 0:00:00
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 55.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (2023.3.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (9.0.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 17.4 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 12.5 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets==1.16.1->-r requirements.txt (line 3)) (1.4.4)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.53.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (67.6.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (1.8.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (2.17.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard==2.7.0->-r requirements.txt (line 5)) (3.4.3)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 16.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 19.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==1.16.1->-r requirements.txt (line 3)) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets==1.16.1->-r requirements.txt (line 3)) (22.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard==2.7.0->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.12.5->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=0.11.15->tensorboard==2.7.0->-r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets==1.16.1->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets==1.16.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.12.5->-r requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.12.5->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==2.7.0->-r requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.7.0->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.7.0->-r requirements.txt (line 5)) (3.2.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=7ab33ae60009ef3eef3c190ca8170083e8a8186085a4156cbcfa55d42c2ce32a
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: tokenizers, sentencepiece, xxhash, torch, tensorboard-data-server, sacremoses, multidict, frozenlist, dill, async-timeout, yarl, multiprocess, huggingface-hub, aiosignal, transformers, google-auth-oauthlib, aiohttp, tensorboard, datasets
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.1
#     Uninstalling tensorboard-2.12.1:

# %%
import json
import torch

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
from transformers import pipeline
summarizer = pipeline("summarization", model="philschmid/bart-large-cnn-samsum")

# %%
conversation = '''Jeff: Can I train a Transformers model on Amazon SageMaker? 
Philipp: Sure you can use the new Hugging Face Deep Learning Container. 
Jeff: ok.
Jeff: and how can I get started? 
Jeff: where can I find documentation? 
Philipp: ok, ok you can find everything here.                                   
'''
summarizer(conversation)[0]["summary_text"]

# %% [markdown]
# ## dataset devset test - bart

# %%
from datasets import *
from tqdm import tqdm


# For all
space = 'Ġ'
pre_quote = '’'
end_marks = ['.', ',', '?', '!', '...']
quotes = ['"', '\'']
abbreviations = ['s', 'd', 't', 'm', 're', 'll', 've', 'S', 'D', 'T', 'M', 'Re', 'Ll', 'Ve']

# For empathetic dialogues
exclude_symbol = "_conv"
comma_symbol = "_comma_"

# For persona chat
persona_chat_url = "https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json"
silence_symbol = "__ SILENCE __"


def load_daily():
    dataset = load_dataset('daily_dialog')
    test_dialogues = dataset['test']['dialog']
    
    return test_dialogues
    
    

def process_token_list(token_list):
    token_list[0] = token_list[0].capitalize()
    
    quote_count = 0
    for i, token in enumerate(token_list):
        if space in token:
            if token[1:] in end_marks or token[1:] in abbreviations:
                token_list[i] = token[1:]
                
            if token[1:] == quotes[1]:
                if i<len(token_list)-1:
                    if token_list[i+1] in abbreviations or (token_list[i+1][0] == space and token_list[i+1][1:] in abbreviations):
                        token_list[i] = token[1:]
                        
        if token[0] == space and token[1:] in quotes:
            if quote_count % 2 == 1:
                token_list[i] = token[1:]
                quote_count = 0
            else:
                if i<len(token_list)-1 and token_list[i+1][0] == space:
                    token_list[i+1] = token_list[i+1][1:]
                quote_count += 1
                
        if token in end_marks or token[1:] in end_marks:
            if i<len(token_list)-1:
                if token_list[i+1][0] != space:
                    token_list[i+1] = space + token_list[i+1].capitalize()
                else:
                    token_list[i+1] = space + token_list[i+1][1:].capitalize()
                
    new_token_list = [token for token in token_list if token != space and len(token)>0]
    if new_token_list[-1] not in end_marks:
        new_token_list.append(end_marks[0])
        
    return new_token_list

# %%
test_arr = load_daily()
load_daily()

# %%
import difflib
from transformers import GPT2Tokenizer, GPT2LMHeadModel, get_polynomial_decay_schedule_with_warmup

from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
from itertools import chain

import torch
import os, sys
import numpy as np
import argparse
import copy
import math
import random

class Arguments:
    def __init__(self):
        self.seed = 0 
        self.mode="test" 
        self.data_dir="data" 
        self.model_type="gpt2" 
        self.bos_token="<bos>" 
        self.sp1_token="<sp1>" 
        self.sp2_token="<sp2>" 
        self.gpu="0" 
        self.max_len=1024 
        self.max_turns=5 
        self.top_p=0.8 
        self.ckpt_dir="saved_models" 
        self.ckpt_name="best_ckpt_epoch=11_valid_loss=2.6479" 
        self.end_command="Abort!"



#원래 shell로 들어가는 파라미터를 정의합니다.

class Manager():
    def __init__(self, args, test_arr):
        self.args = args
        self.test_arr = test_arr

        if torch.cuda.is_available():
            self.args.device = torch.device(f"cuda:{self.args.gpu}")
        else:
            self.args.device = torch.device("cpu")
        
        # Tokenizer & Vocab
        print("Loading the tokenizer...")
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.args.model_type)
        special_tokens = {
            'bos_token': self.args.bos_token,
            'additional_special_tokens': [self.args.sp1_token, self.args.sp2_token]
        }
        self.args.eos_token = self.tokenizer.eos_token
        num_new_tokens = self.tokenizer.add_special_tokens(special_tokens)
        vocab = self.tokenizer.get_vocab()
        self.args.vocab_size = len(vocab)
        self.args.bos_id = vocab[self.args.bos_token]
        self.args.eos_id = vocab[self.args.eos_token]
        self.args.sp1_id = vocab[self.args.sp1_token]
        self.args.sp2_id = vocab[self.args.sp2_token]
        
        # Load model    
        print("Loading the model...")
        self.fix_seed(self.args.seed)
        self.model = GPT2LMHeadModel.from_pretrained(self.args.model_type).to(self.args.device)
        self.model.resize_token_embeddings(self.args.vocab_size)
        
        self.args.max_len = min(self.args.max_len, self.model.config.n_ctx)
            
        
        
        if self.args.ckpt_name is not None:
            ckpt_path = f"{self.args.ckpt_dir}/{self.args.ckpt_name}.ckpt"
            if os.path.exists(ckpt_path):
                print("Loading the trained checkpoint...")
                ckpt = torch.load(ckpt_path, map_location=self.args.device)
                self.model.load_state_dict(ckpt['model_state_dict'])
                
                if self.args.mode == 'train':
                    print(f"The training restarts with the specified checkpoint: {self.args.ckpt_name}.ckpt.")
                    self.optim.load_state_dict(ckpt['optim_state_dict'])
                    self.sched.load_state_dict(ckpt['sched_state_dict'])
                    self.best_loss = ckpt['loss']
                    self.last_epoch = ckpt['epoch']
                else:
                    print("The inference will start with the specified checkpoint.")
            else:
                print(f"Cannot fine the specified checkpoint {ckpt_path}.")
                if self.args.mode == 'train':
                    print("Training will start with the initialized model.")
                else:
                    print("Cannot inference.")
                    exit()
              
        print("Setting finished.")
        
    def nucleus_sampling(self, input_ids, token_type_ids, input_len):
        output_ids = []
        for pos in range(input_len, self.args.max_len):
            output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
            output = F.softmax(output, dim=-1)  # (1, V)
            
            sorted_probs, sorted_idxs = torch.sort(output, descending=True)
            cumsum_probs = torch.cumsum(sorted_probs, dim=-1)  # (1, V)
            idx_remove = cumsum_probs > self.args.top_p
            idx_remove[:, 1:] = idx_remove[:, :-1].clone()
            idx_remove[:, 0] = False
            sorted_probs[idx_remove] = 0.0
            sorted_probs /= torch.sum(sorted_probs, dim=-1, keepdim=True)  # (1, V)
            
            probs = torch.zeros(output.shape, device=self.args.device).scatter_(-1, sorted_idxs, sorted_probs)  # (1, V)
            idx = torch.multinomial(probs, 1)  # (1, 1)
            
            idx_item = idx.squeeze(-1).squeeze(-1).item()
            output_ids.append(idx_item)
            
            if idx_item == self.args.eos_id:
                break
                
            input_ids = torch.cat((input_ids, idx), dim=-1)
            next_type_id = torch.LongTensor([[self.args.sp2_id]]).to(self.args.device)
            token_type_ids = torch.cat((token_type_ids, next_type_id), dim=-1)
            assert input_ids.shape == token_type_ids.shape
            
        return output_ids

    def fix_seed(self, seed):
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        random.seed(seed)  

    def test(self):
        test_arr = self.test_arr
        print("Let's start!")
        self.model.eval()
        self.fix_seed(self.args.seed)

        summarized_utter = []
        user = []
        ground_truth = []

        context_for_json = []
        ans_for_json = []
        gt_for_json = []

        for utters in test_arr:
            user.append(utters[-2]) #user utter
            ground_truth.append(utters[-1]) #ground truth 진짜 정답.

            ## 여기서부터
        
        with torch.no_grad():
            input_hists = []
            ex_cnt = -1
            similarity = 0
            for utters in test_arr:
                #utter = input("You: ")
                ex_cnt += 1
                if ex_cnt == len(test_arr):
                    break
                
                ## summarized input ##
                input_hists = []
                if len(utters) >= 3:
                    string_input = ' '.join(utters[:-2])
                    sumrz_input = summarizer(string_input , max_length= 1 * len(string_input) // 6 , min_length=1 * len(string_input) // 12)[0]["summary_text"]
                else:
                    string_input = ""
                    sumrz_input = ""    

                context_for_json.append(string_input)

                summarized_utter.append(sumrz_input)

                sumrz_input_ids = [self.args.sp1_id] + self.tokenizer.encode(sumrz_input) # sp1 sumar.. utter
                input_hists.append(sumrz_input_ids)

                ## sumarized utter를 하나씩 꺼냅니다. ##

                input_ids = [self.args.sp2_id] + self.tokenizer.encode(utters[-2]) # sp2 user utter
                input_hists.append(input_ids)
                
                #if len(input_hists) >= self.args.max_turns:
                    #num_exceeded = len(input_hists) - self.args.max_turns + 1
                    #input_hists = input_hists[num_exceeded:]
                # 역시 턴 개념은 사용하지 않습니다.
                    
                input_ids = [self.args.bos_id] + list(chain.from_iterable(input_hists)) + [self.args.sp1_id] # 2 -> 1
                #start_sp_id = input_hists[0][0]
                start_sp_id = self.args.sp1_id
                


                #next_sp_id = self.args.sp1_id if start_sp_id == self.args.sp2_id else self.args.sp2_id
                next_sp_id = self.args.sp2_id

                assert start_sp_id != next_sp_id
                token_type_ids = [[start_sp_id] * len(hist) if h % 2 == 0 else [next_sp_id] * len(hist) for h, hist in enumerate(input_hists)] 
                assert len(token_type_ids) == len(input_hists)
                token_type_ids = [start_sp_id] + list(chain.from_iterable(token_type_ids)) + [self.args.sp1_id] # 2 -> 1
                assert len(input_ids) == len(token_type_ids)
                input_len = len(input_ids)
                
                input_ids = torch.LongTensor(input_ids).unsqueeze(0).to(self.args.device)
                token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)
                
                output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)
           
                # output_ids = self.model.generate(
                #     input_ids=input_ids, token_type_ids=token_type_ids, pad_token_id=self.args.eos_id,
                #     do_sample=True, top_p=self.args.top_p, max_length=self.args.max_len,
                #     output_hidden_states=True, output_scores=True, return_dict_in_generate=True,
                # ).sequences
                # output_ids = output_ids[0].tolist()[input_len:]
                res = self.tokenizer.decode(output_ids, skip_special_tokens=True)

                similarity += compute_similarity(res, ground_truth[ex_cnt])

                print(f"summarized : {summarized_utter[ex_cnt]}")
                print(f"user : {user[ex_cnt]}")
                print(f"res : {res}\n gt : {ground_truth[ex_cnt]}")

                context_for_json[-1] += user[ex_cnt]
                ans_for_json.append(res)

                assert len(context_for_json) == len(ans_for_json)
                
                if len(context_for_json) % 10==0:
                    print("#"*50)
                    print(len(context_for_json))
                    print("#"*50)

                if len(context_for_json) == 600:
                    # 데이터 딕셔너리 생성
                    data = {"context": context_for_json, "ans": ans_for_json}
                    gt = {"ans":ground_truth}
                    # JSON 파일로 저장
                    with open("test/json/bart_11e.json", "w") as f:
                        json.dump(data, f)
                    with open("test/json/gt.json","w") as f:
                        json.dump(gt, f)

                    break

                # 예측한 문장과 ground truth를 비교할 수 있습니다.
                # 아직 눈으로 밖에 비교할 방법이 없음.

                #print(f"Bot: {res}")
                #input_hists.append([self.args.sp2_id] + self.tokenizer.encode(res))
        print(f"문자열 간에 유사도 : {similarity / len(test_arr)}")

# %%
args = Arguments()
args.ckpt_dir = f"{args.ckpt_dir}/{args.model_type}"
assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
manager = Manager(args, test_arr)
manager.test()
# Out:
# Loading the tokenizer...
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Loading the model...
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Loading the trained checkpoint...
# The inference will start with the specified checkpoint.
# Setting finished.
# Let's start!
# summarized : Man wants to buy weed. He also has blow and he has dope and acid. He will give him one ounce of weed for free. He has connections to get all these drugs.
# user :  Yeah ?
# res : Yeah, I know. The rest is out of my control. I could blow $200 and get free pills.
#  gt :  I want you to put your hands behind your head ! You are under arrest !
# summarized : Taxi drivers
# user :  They want the government to reduce the price of the gasoline .
# res : That's right.
#  gt :  It is really a hot potato .
# summarized : The factory has reduced its energy consumption by 15% in the last two years thanks to a heat recovery system. The system uses the exhaust gases from the printing presses to heat the dryers.
# user :  What other sources of energy do you use ?
# res : Most of the imports are of paper products.
#  gt :  We don't use any fossil fuels . Most of our power comes from hydro-electric plants . We're hoping to use even more energy from alternative sources in the future - perhaps even wind power .
# summarized : Tea is the most popular beverage in the world after water. People from Asia to Europe all enjoy tea. China is the homeland of tea. There are several categories of Chinese tea. Oulong tea and compressed tea are good for one's health. Peter likes drinking tea at teahouses.
# user :  Great . We can chat while enjoying a cup there .
# res : Come on, Let's talk. Do you drink tea regularly?
#  gt :  Let's go !
# summarized : I'm a poor talker. I don't want to be a leader. I prefer to cooperate with everybody and get the job done by working together. I think I can make myself easily understood in English.
# user :  Are you available for travel ?
# res : Yes, I am.
#  gt :  Yes , I like travelling . I am young , and unmarried . It ’ s no problem for me to travel frequently .
# summarized : It will take three hours to drive from here to London. The journey should be two hours on the motorway. The company car has a maximum speed of over 200 km/h. It is longer than the car of the driver. It will travel at high speeds at the beginning and end of the journey.
# user :  wow ! That ’ s fast ! I don ’ t think we will be traveling that fast on the motorway .
# res : Good idea!
#  gt :  we can ’ t . if we went that fast , we would break the speed limit .
# summarized : I failed my driving test. There were a number of reasons why, but the most important one is that I can't drive.
# user :  Can I have another try ?
# res : I'm afraid I'll have to pass the latest tests.
#  gt :  You can take it in a couple weeks .
# summarized : Yesterday he had a runny nose, now his nose is stuffed up, he has a sore throat and a temperature, and he feels terrible. He has all the symptoms of influenza. The doctor gives him an examination.
# user :  A good rest is all you need , and drink more water . I'll write you a prescription .
# res : Do you have any medicine for your headache?
#  gt :  Thank you very much .
# summarized : Red cooked carp and rape with fresh mushrooms for supper. Sour-peppery soup with ginger, garlic scallion, hot pepper and vinegar for condiment.
# user :  But you must cook that dinner next time .
# res : Then why don't you serve it to the guests?
#  gt :  Okay , I'll do it next time .
# summarized : Mike and Kara had fun at the movies the other night. Kara doesn't want to go out again this Friday as she needs to focus on packing and moving back home.
# user :  Maybe we could just meet for coffee or something .
# res : Sure. I'm glad to hear that.
#  gt :  I can't really deal with any distractions right now , but I appreciate the nice evening we spent together .
# ##################################################
# 10
# ##################################################
# summarized : Sun-set hotel has booked a double room for 24th for 3 days.
# user :  Well , now I want to change the date from 24th to 28th .
# res : Will that be OK?
#  gt :  OK , that shall be arranged .
# summarized : Tomorrow I'm free
# user :  Someone has to pick up the boss at the airport .
# res : We will pick you up there, And pick you up at the airport.
#  gt :  Oh , I just remembered I've got a report to write .
# summarized : Dinner is at 6:30. It's ten after 6. I'm late because I lost my bag.
# user :  I'll call the lost and found office .
# res : Let's go to the reception area.
#  gt :  I didn't think of it.Thank you.And I do apologize for being late .
# summarized : Nani Book Store has "The man and the sea" by Ernest
# user :  Yes , we have one copy left .
# res : Why not try it out for yourself?
#  gt :  Can you hold it for me ?
# summarized : The maps of downtown area are here.
# user :  It's free of charge .
# res : It's too crowded for children.
#  gt :  Thanks so much .
# summarized : Michelle booked a room at John Sandals from April 14th to the 17th. The room costs $ 308 a night. Michelle prefers nonsmoking as she can't handle the smell of smoking. Michelle wants John's phone number as she needs to make a further reservation.
# user :  Of course ! It's area code 626-555-1739 .
# res : Is this the same room for office?
#  gt :  Thank you so much , Mr . Sandals . We look forward to seeing you !
# summarized : There's been a mistake in the bill and the customer can't have his.
# user :  I believe you have charged me twice for the same thing . Look , the figure of 6.5 dollar appears here , then again here .
# res : Is it all right?
#  gt :  I'll just go and check it for you , sir .
# summarized : Madam bought a sheet yesterday, but when she spread it out back home, she found a hole. She will change the sheet for another one.
# user :  That's very kind of you . Thank you .
# res : Don't worry, Madam. I'll save it for later.
#  gt :  We're sorry that this has happened , and I guarantee that the same mistake won't happen again .
# summarized : Today's sale price for red roses is $20 a dozen, which is the price for a dozen flowers for his wife.
# user :  No , thank you .
# res : You'll get some free flowers tomorrow.
#  gt :  These roses should make your wife very happy .
# summarized : There are not enough outlets in the room service.
# user :  Yes , but 4 of them are broken . Can you send someone here ?
# res : Of course, I can.
#  gt :  OK sir , please wait a minute .
# ##################################################
# 20
# ##################################################
# summarized : I ran a red light. I didn't realize that I did. I was taught that yellow means slow down, not speed up.
# user :  I understand .
# res : Wait a minute. Did you realize that yellow lights mean slow down?
#  gt :  Here you go . Don't do that again .
# summarized : The roll of film will be developed and the pictures taken tomorrow.
# user :  Sure .
# res : Oh, Thank you. It's nice to have you around.
#  gt :  Besides I want two copies of all the photos .
# summarized : Dunlin was born in 1980 and he will graduate from Peking University this July. He majored in accounting.
# user :  Would you tell me something about your family ?
# res : My brother was a huge connoisseur.
#  gt :  There are three in my family , my parents and myself . My father is a teacher and my mother is a worker .
# summarized : I try to eat only fruits, vegetables and chicken. I mainly eat baked chicken because there's not a lot of fat in it. I really need to start eating healthier.
# user :  That does sound pretty good .
# res : Are you dieting for a long time now?
#  gt :  I know it does , and that's because it is .
# summarized : A Chinese woman wants to buy a silk coat in Chinesc-style clothing. She will buy a red one as it's believed in China that the red color brings happiness and good luck. She'll send it to her by mail when she gets it in. She's leaving the country tomorrow. She needs to fill out the form.
# user :  Thanks . How much would that come to ?
# res : About what?
#  gt :  Let me see ...
# summarized : The person who wants to view the apartment for rent today won't be able to do it as he has to make an appointment first.
# user :  Yes , I will schedule you for that time .
# res : Okay. But wait a minute, I'll take you to the landlord.
#  gt :  Thank you very much . See you then .
# summarized : Today I invite you to talk about insurance you're interested in. I wonder whether I can enjoy the life insurance and health insurance.
# user :  Good . Anything else ?
# res : What else?
#  gt :  Yes , all the insurance will be linked with your work . We will issue an insurance policy .
# summarized : A man wants to send a registered airmail letter to France for four dollars twenty cents. He also wants to pack up his package and drop it in the mail box mark out of town at the corner.
# user :  Thank you very much .
# res : I'm sorry to hear that, Sir. We will not drop anything.
#  gt :  You ‘ re welcome .
# summarized : Two people got the last available table for two. They didn't have a reservation. They will have samosas, poppadoms, lamb kebabs and beer as their main course. The waitress will be on her way and they will wait until she comes round to flag down the table for them.  They will wait for her until she arrives.
# user :  you're right . That might seem a bit rude . It's a good thing I've got you with me !
# res : No need for any interruptions, The waitress will have you back by the time I arrive.
#  gt :  what would you do without me ?
# summarized :
# user : This position demands a higher writing ability , so please say something about your writing ability .
# res : Good. I'd like to do my best to write as fast as possible. I've never had a bad book, And I have a lot of literature.
#  gt :  Of course . I've loved writing since I was a very little boy . I won the first prize in a national composition contest when I was in middle school . After attending Nanjing University , I never give up writing . My works , such as Father's Tobacco Pipe , Open Air Cinema , The old City were respectively published China Youth Daily , Yangzi Evening News , and New Beijing . During the period of studying for my degrees of master and doctor , I paid more attention to developing my research ability and published several papers . The Impact of Internet in Chinese Political Participation , The Discipline of Remold , The Historical Direction of Chinese Administration Reform , Bribery Cases of Self governance in Chinese Villages are respectively published in Chinese Publish Administration , Beijing Due Xuebao , Theory and Society and Chinese Reform . I joined in Yangzi Evening News to work as a part-time journalist in 2006 . During this period , I've written a lot of comments , which improved my writing ability to a new level , I have full confidence in my writing ability , and I believe I can do the job well .
# ##################################################
# 30
# ##################################################
# summarized : Six couples are coming for dinner. They are reserving a private dining room for the dinner.
# user :  All right . May I have your name , Sir ?
# res : Yours, Steven.
#  gt :  My name is Ron Kollwitz .
# summarized : Mr. Cooper is the president of Ivy Publishing.
# user :  Nice to meet you , Ms . Wang . You must be exhausted after your long trip from Canada .
# res : What was the motivation?
#  gt :  Yes , it was quite a long flight . I'm glad to finally be here .
# summarized : Can't help now, but will be able
# user :  Why don't you ask Bill if he can help ?
# res : Oh, It's fine, He's just trying to figure out something.
#  gt :  I did , but he wasn't able to either .
# summarized : In the past two years, she has been working in the Public Relations Section of a company in the PR department planning the advertising campaign and cooperating the work of artists and typographers. She also acted as a secretary in an insurance company. She studied in a computer training program and she can process data through the computer. She can handle the fax and duplicator without any trouble.   She has a better memory than average and she has made notes in shorthand and types.
# user :  Above all , I have learned that what is good for the company is good for me . So I follow the instructions strictly and always keep my boss informed .
# res : By doing so, I can improve myself as a manager.
#  gt :  Very good .
# summarized : Dan got fired from his job one month ago. He messed up a business deal that would have made ten million dollars. Now he's looking for a new job. Lily doesn't know he's been fired yet. He's been working at the coffee shop next to Dan's office for the last three days. He didn't tell Lily he was working there.
# user :  Listen . I will see what I can do , ok ? You go home and tell Lily about this problem you have now . She is your wife and I am sure she will understand .
# res : I will, But I'm a little nervous, Don't you think?
#  gt :  I just don't know how to bring it up . Well , all right . She has the right to know anyways .
# summarized : Yesterday he got a parking ticket for parking in the red zone. He parked at his apartment building. He has his own parking spot.
# user :  I needed to be fast .
# res : What's wrong?
#  gt :  That was very lazy of you .
# summarized : There have been charges made on her debit card that she didn't make. The last four charges are on the page. They will have to investigate these charges.
# user :  I honestly don ’ t know , but we will freeze payment on these charges .
# res : What if they were yours?
#  gt :  That sounds absolutely fantastic .
# summarized : Treasury Certificates are available for two years with a value of 1,000 RIB. The counter offers Treasury Notes with two, three and five-year terms.
# user :  Here you go . By the way , is it possible to cash them before the maturity comes up ?
# res : Yes, This is a huge savings.
#  gt :  No , I'm afraid that isn't possible . You must wait until maturity before you cash them .
# summarized : When you pass go, you collect $ 200. You have to ask the bank for the money.
# user :  Can I have my $ 200 please ?
# res : We have three days left to make it.
#  gt :  Sure . Here you are , $ 200 , Thank you , please come again ! Now it ’ s my turn to roll the dice .
# summarized : Professor Clark had a skydiving accident over the weekend and won't be able to come to school today. He broke his leg, but it's healing.
# user :  I should be able to return by next Monday .
# res : He'll be fine.
#  gt :  Fine . Well , thanks for calling and letting me know you will be absent . I hope you feel better soon .
# ##################################################
# 40
# ##################################################
# summarized : A plumber came to the house to fix the toilet. The old house is falling apart. The water pipes are rusty and need to be changed. The faucet that doesn't shut off properly also needs to be fixed. The plumber could have it all finished by today if it's urgent for him.  He suspects that there's a foreign object in the pipes that's causing the blockage.
# user :  That would be great ! Is it expensive ?
# res : Not at all.
#  gt :  Let ’ s see ... I would say about eight hundred dollars .
# summarized : Karen's mother-in-law is in hospital in Los Angeles. Hank and Karen will be flying there tonight. Suzy has a bad cold. Karen will ask Sara Ralston, a 17-year-old girl from her church, if she can take care of Suzy overnight or for two or three days. She will get Sara's number from Hank and ask her if she will be able to help Karen and Hank with Suzy's care.  She doesn't want to take Suzy with them, because she might get sick.
# user :  I'll go home and get Sara's number . I'll call her first myself .
# res : Don't worry, Hank, I'm going to be with you tonight.
#  gt :  Great . Then call me and let me know if she's free .
# summarized : I'll have a draft beer and a can of beer.
# user :  Could I have some fruit ?
# res : What's the difference?
#  gt :  Of course . Wait for a moment , please .
# summarized : Mr. Black had a pleasant journey from New York. He didn't meet Mr. Black at the airport yesterday as he was busy.
# user :  Not bad . The fur market is not very brisk lately , but the selling season is advancing near . I hope there will be more buyers in the market this year .
# res : Yeah, It is encouraging.
#  gt :  I hope we can do more business together . Though we are satisfied with our past trade record , there are still possibilities for more business . In the meantime , let's discuss other spheres of cooperation , such as investment , technology transfer and technical assistance .
# summarized : Toilets are in the rear. All the toilets are fully occupied.
# user :  What ? Oh , what we live ! Thank you very much for your help , miss .
# res : No problem.
#  gt :  You are welcome .
# summarized : There's a long line to buy bubble wrap and stamps. She needs 30 stamps for her Christmas cards. She's sending them abroad to China and America. The stamps cost 18 pounds and seventy two pence. The bubble wrap costs 18 pounds, 70 pence, and she'll have to stand in line for an hour.
# user :  that ’ s another quid .
# res : Really?
#  gt :  thanks a lot . You ’ Ve been very helpful .
# summarized : Saliva is cooking steamed fish in a pressure cooker. Saliva studied cooking skills recently at a training school and wants to run a restaurant. Next Friday Saliva will cook for his birthday dinner party and invite Saliva to join him.  He will teach Saliva how to prepare many different dishes.   It will be a good opportunity for him to practise his cooking skills and to meet Saliva.  It's Saliva's birthday next Friday.
# user :  Thanks a lot .
# res : Wow, I was quite excited about this, But I didn't know you were a vegetarian.
#  gt :  It's my pleasure .
# summarized : The room service mistook his order for an express laundry and sent it to room 2012 instead of the room 2012.
# user :  Sir , we are terribly sorry for that.We will refund the charge and send your laundry to your room 3 hours later . Is that all right ?
# res : Not really.
#  gt :  That's fine .
# summarized : I need
# user :  Can you mail this at the post office for me ? I have to go to the doctor for an appointment and I don't have enough time to go to the post office .
# res : Ok, I'll send the package in 2 business days. I have 15 days left until my next appointment.
#  gt :  Sure . And I'd like you to get some cold medicine for me when you go to the doctor's .
# summarized : The gas station attendant will fill up the gas tank for him.
# user :  Unleaded , please .
# res : Thanks.
#  gt :  OK .
# ##################################################
# 50
# ##################################################
# summarized : I will come and talk about the financing of our imports. I will draw a draft on us at 90 days sight and a draft at 120 days sight. The draft will be accepted by a bank acceptable to us. Then we will arrange for a loan from the bank.
# user :  I hope this transaction will pave the way for further business relations between our two countries .
# res : Yes, I will be happy to inform you of the banking relationship.
#  gt :  So do I .
# summarized : There's a new girl in school. She's short and probably about 5 feet tall. She has beautiful brown eyes and she's probably met someone before.
# user :  Are you telling me that you've seen her before ?
# res : I've never seen her before, But I can see her. I think she's always dressed in dark clothes.
#  gt :  I believe so .
# summarized : The Porsche costs 45 dollars for three days. He will take it and buy the insurance. He can't return it to the office in San Francisco, so he will drive it back to the lot. He still wants to drive the car back down the coast with his girlfriend, so will take the Porsche.
# user :  Where are the keys ?
# res : I can drive them on the car.
#  gt :  Just a moment , sir . We have to finish filling out the forms .
# summarized :
# user : Gary . Could you type up this report for me ? I have to take off early this afternoon .
# res : Ok, Can you keep me?
#  gt :  Sure . Just leave it to me . I'll finish it .
# summarized : After watching a food show at a famous seafood restaurant, he wants to eat at that restaurant. He will order salmon sashimi, roast salmon head, stir-fried squids, steamed shrimps and steamed lobster. They will go to the seafood restaurant in their neighborhood and order their food in front of the seafood fridge.
# user :  OK . I will wait for you inside the restaurant
# res : Ok, Ok. Let me get my steak.
#  gt :  Do you think we should try some deep fried oysters ?
# summarized : I'm going to the hospital. I'll take you. It will cost you $10.
# user :  It's a quarter to 12 . Could you please drive a little faster ?
# res : Sure. Just take a long left to get back to the main road.
#  gt :  Certainly .
# summarized : The china tea set is unusual. It was made in Jingdezhen. It's the best quality porcelain from the famous egg-shell China.
# user :  It must be most precious .
# res : Yes, I heard it was very expensive.
#  gt :  But it is really worth the price .
# summarized : Miao Li is going to the store to buy some fruit. Miao Li will mail a letter to Miao-Li on her way there. The letter will be registered.
# user :  Thanks .
# res : Ok, How about it?
#  gt :  you are welcome .
# summarized : The accident was your fault. You should make a police report first and then go to the hospital. The cell phone in your car doesn't work. You will have to wait for the police to arrive. I will go into one of those houses over there and use their phone to call the police. You'll get to a hospital in time.
# user :  I'm afraid it wasn't . And when the police get here , you will also see that it wasn't . But enough of this bickering . I'm going to go find a phone.Don ' t move that arm while I'm gone . Alright ?
# res : Are you saying that I will be heading to the hospital tomorrow?
#  gt :  To hell with you .
# summarized : There will be a charity performance on Saturday night and a solo concert by an opera star on Sunday night. The one on Saturday is to raise money for the homeless. It's a reserved opera named The Monkey Creates Havoc in Heaven. It is a story about the clever Monkey King.
# user :  Wonderful ! How much is the ticket ?
# res : It's $10.
#  gt :  The price varies according to the seats . 300 for the front , 200 for the middle , and 50 for the back .
# ##################################################
# 60
# ##################################################
# summarized : The preparatory meeting will start at 2:00 this afternoon and end at around 3:00.
# user :  That's fine with me . How much time are we going to have to work on this ?
# res : There are a lot of meetings in the morning and then at night the meeting starts at 2:00.
#  gt :  Perhaps one year , I'm not sure .
# summarized : French dressing will be added to the salad.
# user :  Sorry , it's not available now.Anything else ?
# res : I will have to go.
#  gt :  We still prefer French dressing .
# summarized : The man will have some fish, spinach and beer. He will pay for his own bill, as he's had enough beer.
# user :  Of course . Please wait a moment . I'll go and get it .
# res : Thank you very much.
#  gt :  Thank you .
# summarized : George is going to have a job interview next week. George will try his best to make a good impression on the interviewer. George advises George not to be late to the appointment and to be well-groomed and modestly dressed. George loves wearing T-shirts and jeans, but advises not to wear a too casual style. George can't afford more expensive clothes, but he loves T-shirt and jeans. George likes to wear right clothes at the right time to gain the respect of the interviewer and his confidence in his judgement. George is not sure if he can afford to buy expensive clothes for the job interview. George doesn't like to wear expensive clothes. George prefers to wear t-shirts, jeans and dirty shoes for the interview.
# user :  It seems that ' clothes make the man ' .
# res : I think so.
#  gt :  It may not be true , but the first and lasting impression of you is determined by your clothes and behavior .
# summarized : The boss is going to announce the pay raise today.
# user :  It better be more than last year .
# res : Yes, It's better than last year.
#  gt :  Well , anything is better than nothing . Wait and see .
# summarized : The appointment has to be changed
# user :  If you don't mind , may we put it off to the next day ?
# res : Yes, We will.
#  gt :  That's OK .
# summarized : Felix Wasserman Associates has a receipt of proceeds from Felix Wasserman Associates. The L / C number is NX567822100007.
# user :  OK , thanks for checking . Could you give me a ring when it arrives , please ?
# res : Sure, Can I pick it up?
#  gt :  No problem . I'll be in touch as soon as it comes in .
# summarized : I have to stay in your cry for just one day. Can you suggest a short tour?
# user :  I would prefer the first one .
# res : I'll have a stop in Vienna to see the beautiful monument and the famous local businesses, Then we can visit the nearest to you.
#  gt :  Sure . We have a one-day trip along the river . It's quite beautiful .
# summarized : The buyer needs to find out more information about the L / C. The conditions are specified by the buyer and may include Insurance Forms, Way Bills, Bills of Lading, Customs forms and various certificates.
# user :  Just that in effect , a basic Letter of Credit is a financial contract between the bank , the bank's customer , and the beneficiary , and this contract involves the transfer of goods or services against funds .
# res : No, I don't think it's a transfer of goods and services ; the customer has to pay a registration fee for the transfer.
#  gt :  That sounds fine , thanks for that . Let's go ahead !
# summarized : There was a break-in at my house last night. The front window was broken. Nothing was stolen.
# user :  We'll send a squad car shortly .
# res : The car is going to be ours.
#  gt :  I'd appreciate that .
# ##################################################
# 70
# ##################################################
# summarized : The chocolate bar costs one dollar. You can only have four.
# user :  Oh , yeah . I forgot tax . Give me four then , please .
# res : Then you can drink your lunch again at once.
#  gt :  Okay . Thanks .
# summarized : The housekeeper will make the bed now as requested by the guest.
# user :  Thank you.Please get some soap for us .
# res : Thank you, Sir. I am delighted to see that.
#  gt :  Just a moment . I will do it right now .
# summarized : Richard Thomas has a problem at Ms. Montgomery's home.
# user :  Oh ? What ’ s wrong ?
# res : I'Ve had a couple of beers lately, And it was just kind of pouring in.
#  gt :  My daughter ’ s just banged up her knee pretty badly and I ’ m going to have to take her to the hospital . I ’ ll be about two hours late .
# summarized : Liu has an appointment with Mr. Li at 9. He is applying for a position as an experienced software engineer. His major was computer science at college and he is familiar with Visual C + + and Java language. He has designed some programs for the network and passed the test for programmers - MUSE. He would be responsible for the development of software products in the position. He thinks the software industry has a great future and more and more problems are resolved by software in the future. He doesn't have any other questions for the interview.
# user :  Ok , I will contact you in a week . See you .
# res : Thank you, Liu.
#  gt :  Thank you , bye-bye .
# summarized : Jenny is crying. Tom will take her away from him.
# user :  She ’ s your sister . What she asked was only duck soup for you . Why can ’ t you be good to her ?
# res : What's the matter?
#  gt :  But I am her brother , not her servant .
# summarized : Outlets are a good place to buy an inexpensive cashmere sweater.
# user :  Thank you for your help .
# res : We'll make it for you.
#  gt :  No problem . Good luck
# summarized : There are apples, bananas, pineapples and kiwis for sale. The apples are 30NT each. The bananas are 35NT for this bunch. The pineapple is 250NT each, but it's only used for worship, so you can't eat it.
# user :  They're imported from New Zealand . Four for 50NT . Nine for a hundred .
# res : I see. They're okay.
#  gt :  OK . I'll take four kiwis .
# summarized : Amelia has put in her notice at her company as she's got a better offer. Amelia will be dealing with overseas companies and flying to this side of the world from time to time. Amelia wants Amelia to write a letter of recommendation before she goes.    She feels lucky and she will be able to use English more at work there.     The company's head office is in New York.
# user :  of course I can . In fact , if there are other job opportunities at this new company , I'll recommend you personally .
# res :  Ok. I'll look at the letter.
#  gt :  thanks . I appreciate that .
# summarized : The shirt is in a small size.
# user :  May I try it on ?
# res : Yes.
#  gt :  Sure . Let me help you .
# summarized : Christine has the file on James' file.
# user :  Christine , I know you ’ re new here and there ’ s a lot to learn , but you are going to have to learn to keep your work in better order . We can ’ t afford to lose an important document .
# res : Let me tell you how it got here. I went back in my earlier interview and asked him what he thought of the package. He was totally shocked at all of it. He said that it had nothing to do with James' file. I thought he was joking and I was totally lost!
#  gt :  Yes , sir . I apologize for that . Here ’ s the file you were looking for , Mr . Emory .
# ##################################################
# 80
# ##################################################
# summarized : I wonder if I could
# user :  Sorry , I'm using it myself.But you can use it this afternoon .
# res : You'll need it tomorrow.
#  gt :  Thank you very much .
# summarized : Joan invited Leslie to work out with her. Leslie is impressed with Joan's body. Leslie thinks Joan is hot. Leslie wishes she could get in shape like Joan.
# user :  That's it . I decided to turn over a new leaf . I'm going to exercise every single day .
# res : Yes, You should exercise regularly. It helps your body to recover from weakness.
#  gt :  Good for you , Leslie !
# summarized : To-go food will cost 25 dollars. The restaurant accepts Visa and MasterCard cards. The delivery man will bring the food to the customer.
# user :  Thank you .
# res : Thank you.
#  gt :  You're welcome . Please come again .
# summarized : I'm going to quit the job because the task is
# user :  You'd look before you leap .
# res : Do you want to quit?
#  gt :  Thanks for your concern .
# summarized : Coupled flights can't check luggage through London if you have more than 24 hours between connecting flights in New York.
# user :  Well , maybe I can put them in the airport storage there .
# res : How about letting us get a 10 percent discount?
#  gt :  That's right . It's over there .
# summarized :
# user : Eat some more .
# res : I think you are done. I want to come back tomorrow.
#  gt :  No , thanks . I'm on a diet .
# summarized : The Admiral Hotel is two blocks north of Callaway Street, but it's difficult to find it.
# user :  Thanks a lot .
# res : So what does it have to do with the place?
#  gt :  Not at all .
# summarized :
# user : I'm sorry I'm late .
# res : I'm sorry. I haven't been able to get your call.
#  gt :  Better late than never .
# summarized : Professor Li is looking for a place to buy art supplies for his niece.
# user :  She is eight . Actually , I'm buying a good set of art supplies for her as a birthday gift .
# res : You look adorable, Miss.
#  gt :  It's a wise thing to do . Art will do a child a world of good .
# summarized : Mary will leave Jenny a message about band practice being moved to Tuesday at 8:30. Jenny can call Mary at 555-2345 if she has any questions.
# user :  Thank you . Bye .
# res : I'm so sorry for the delay, Jenny. I'd like to make it better for you.
#  gt :  Goodbye .
# ##################################################
# 90
# ##################################################
# summarized : English is
# user :  Can you tell me how to get to the Jade Buddha Temple ?
# res : I've been living in Australia for the last four years.
#  gt :  I'm sorry . I can't quite follow you . Would you mind speaking slowly ?
# summarized : How do you get road news
# user :  So you have all the news on broadcast ?
# res : By telecast.
#  gt :  Yes , it's so helpful .
# summarized : A woman is in a hurry and wants to have
# user :  Certainly . Would you like it with ice cream ?
# res : I'll make it.
#  gt :  No , thanks .
# summarized : Dr. Cooper will make an appointment with Dr. Cooper tomorrow morning.
# user :  Sorry , I've got a meeting from nine to ten.What about Monday afternoon ?
# res : That's when it will be at 10:30.
#  gt :  I'm afraid he's fully engaged.Could you make it another time ?
# summarized : Both of them are shopping for some new clothes. She found a few pairs of pants at JC Pennies.
# user :  Do you want me to show you where I found them ?
# res : I don't think so. I had to go and check them.
#  gt :  I would like that . Thank you .
# summarized : Xiaogang Li applied for the Solar Studio of
# user :  I want to know whether you will come to the interview . So have you accepted offers from other companies ?
# res : No, I've just been accepted by them.
#  gt :  No , I haven't got one by now . I will go to the interview of yours .
# summarized : The office party is going to be a formal affair. American food will be the best choice for the food. The entertainment will be a band or recorded music. The food will probably be Chinese or American.
# user :  We should bring in a really good DJ .
# res : Yeah, You can check it out if you like.
#  gt :  That works for me . Let's see what we can each do about planning our part and meet again on Friday .
# summarized :
# user : Help ! Help !
# res : I'm looking for a card.
#  gt :  What's the matter ?
# summarized : What would you like to eat? Scrambled egg,
# user :  Would you care for some lemon for your tea ?
# res : That would be nice.
#  gt :  No , thank you .
# summarized :
# user : Where's the toilet ?
# res : I thought it was out.
#  gt :  Over there .
# ##################################################
# 100
# ##################################################
# summarized : There are only two more days until the bidding closes for the Chanel watch and Chanel bag. The newbie got the watch at the last minute and got it sixty percent off.
# user :  Don't count on it , Babe . eBay is always full of surprises .
# res : It's hard to believe. The demand is huge.
#  gt :  Well ... guess how low the bidding starts on the tennis racket ?
# summarized : Pots and pans are right over there. The store credit card saves you 10% off the purchase of the pots and pans.
# user :  Thank you , but I'm just browsing today .
# res : The C is right here.
#  gt :  Okay . Enjoy your browsing .
# summarized : Lobsters and crabs are on offer at the fish counter, but she's allergic to them. She'll buy milk, eggs, a couple dozen eggs and orange juice instead.
# user :  Let's get frozen juice . It is really good . We ’ Ve got enough food . Let ’ s go over to the check-out stand .
# res : I see. You're welcome. You should give us a call and see what we have available.
#  gt :  OK . But just let me pick up a bottle of cooking wine and oil as we go by .
# summarized : Kalina ran her car into a tree yesterday and needs to miss a few days of school. She has a concussion, but she will be OK.
# user :  I only need to take this week off .
# res : I guess you're right.
#  gt :  I appreciate you calling and telling me that you won ’ t be in class . See you next week !
# summarized : Parker's business is booming. He wants to meet with Parker next week.
# user :  Let me see . I can come out and see you first thing Wednesday .
# res : Thank you very much.
#  gt :  Great .
# summarized : It took me almost one minute to open the company page and there was no response to any click.
# user :  I have the same question . I can ’ t send out mails . We ’ d better call the IT department and ask them to check it immediately .
# res : Thanks.
#  gt :  Ok .
# summarized : Honey didn't go to cram school last night because she has to do her homework.
# user :  Honey , if you don't want to go to cram school , you should tell me the reason why .
# res : I don't know why I can't go to school.
#  gt :  I'm sorry , dad . But I would rather stay at school than go to cram school .
# summarized : The young man has a fever, cough and headache. He should stay in bed and drink a lot of water. He can play football tomorrow.
# user :  Of course not . You need a good rest .
# res : Do you have a doctor?
#  gt :  OK , I'll listen to you .
# summarized : After dinner, she wants to get some pie. She loves apple pie.   She doesn't know what kind of pie she wants.
# user :  Oh , I love apple pie too .
# res : Oh, I forgot. I am talking about the table.
#  gt :  There you go . Problem solved .
# summarized :
# user : Let's go now .
# res : Excuse me, Please. It's only for us. It's because of the intermission.
#  gt :  I'll be with you in a minute .
# ##################################################
# 110
# ##################################################
# summarized : The buying rate for USD is 826 . 44 yuan for 100 dollars today. The bank is authorized to deal with foreign exchange. It can change only three kinds of currency: USD, Japanese Yen and HK Dollar.
# user :  Please go to Counter No . 2 , the foreign exchange counter . It's over there .
# res : It's not so bad. Is there any difference between them?
#  gt :  Thank you .
# summarized : Steven is the Sales Manager of a company that sells typewriters. Steven is angry because only five of the ten new ones work properly. Steven promises to fix them.
# user :  I'll certainly look into that .
# res : Sure.
#  gt :  Thank you . Goodbye .
# summarized : A man is looking for a string of pearls for his wife. The one he wants to buy costs three hundred and fifty dollars. The price has already gone down.
# user :  It's two hundred and eighty dollars .
# res : Let's say you are about to buy the first one.
#  gt :  OK . I'll take it . Thank you .
# summarized : Kreng portable cassette player is very good. It has auto-reverse, recording capability, and an AM / FM radio band. It also has a built-in microphone. It sells for $ 39.99. The last one broke after two months. It's too high-tech for him. He'll take the one with no auto- reverse. It sounds great, so he'll test it out. It costs $39.99 and he'll buy it. It is a German-made model.
# user :  Fine . I think you'll be happy with it . It's a very good unit . Very reliable . I'll go get you a new one in a box . I will be back in just a moment .
# res : You're right, Mr. Dozy.
#  gt :  Thanks .
# summarized : Beijing-born, Peking University graduate is looking for a full-time or part-time job. He worked for 2 years as a financial consultant in Beijing for China Pacific Insurance Co . Ltd. He is an excellent communicator and he is convinced his company is becoming one of the market leaders and he would like to be a part of that team. He has set time limits for himself to limit how much time he spends making sure the customer is satisfied. He would also like to work for the company's progress in the last 3 years and he's convinced that it is becoming a market leader. He wants to join the team that is developing the company.  For more information, visit: www.chinapacificinsurance.co.
# user :  When can you begin ?
# res : Sure.
#  gt :  Immediately .
# summarized : There are four points you should keep in mind when you file documents. They are keep the documents in chronological order, remove all the chips and pins, punch the documents evenly and place them in the folder.
# user :  And what is the most important point ?
# res : The most important point is to make sure that your files are written by the public. That's the first thing you must do.
#  gt :  You should always remember that one customer one file is the rule .
# summarized : The traffic from the airport to downtown has been smooth since the completion of Yan'an Aerial Road. The traffic jams could be as long as half an hour long.
# user :  We've never expected that Shanghai is such a big metropolis , same as New York city . David , would it be a good idea to rent a car here ? I've got an international driver's license with a pretty good record in the States .
# res : Good idea. Why not just go downtown?
#  gt :  That's wonderful . OK . I'll remember that . But I have to warn you that you must drive very carefully in the downtown area , for there're no separate lanes for motor vehicles and bicycles in some places , and still quite a few people don't take road regulations seriously .
# summarized : The house is not looking very good from the outside. The kitchen is too small and the master suite is not very elegant. The house needs some fresh paint and cleaning to look a little better inside. The master suite should be better.
# user :  How many dogs live in this house ?
# res : Twenty and thirty dogs, That's twenty-five dogs.
#  gt :  I think that we have seen all that we need to see here . Let ’ s go look at another house .
# summarized : The waiter will have some wine for the main course.
# user :  I recommend you the white wine . It will wake up your appetite .
# res : Come on! Look at these details. They're pretty detailed.
#  gt :  That's great , bring me a bottle of that please .
# summarized : It's time to go, but he has to stop and get gas in the car first. He'll give her five more minutes and he'll go without her.
# user :  You wouldn't do a thing like that !
# res : No, I'd do everything except driving my car into his face.
#  gt :  Oh , yes , I would !
# ##################################################
# 120
# ##################################################
# summarized : I wonder if I can see your mother, little boy
# user :  Johnny , I wish you ’ d stop reaching for things . Haven ’ t you a tongue ?
# res : You know, You really don't know the answers.
#  gt :  Yes , Mother , but my arm is longer .
# summarized : Tomorrow he needs a wake-up call. They will call him at 7, then at 7:15. He cancels the first call and changes the second to 7:30.
# user :  No , that's about it for now . Thanks .
# res : That's okay, Bye.
#  gt :  Okay , sir . Have a pleasant evening .
# summarized :
# user : Have you seen our new packing specifications ?
# res : Yes. Here you are.
#  gt :  Yes , I have , Mr . Thomas . We'll pack them two dozen to one carton , and the gross weight is around 25 kilos a carton .
# summarized : I'm in a flap about the interview.
# user :  I'm in such a need of the job that I can't afford any mistakes .
# res : What did you think about him?
#  gt :  I'm sure you'll pass it .
# summarized : The company will provide you with all the supplies you need for a business trip. You can leave the thick notebook at home instead of taking it with you.
# user :  I know . But it is my lucky charm . I carry it all the time .
# res : Really? Then what would you like to do?
#  gt :  Suit yourself . Don ’ t forget to set the alarm clock .
# summarized : Beijing Hotel is not where she wants to go. She can get off at the next stop and go across the street through the overpass to get to Beijing Hotel.
# user :  Thank you very much .
# res : Really?
#  gt :  My pleasure .
# summarized : Steven and I will go shopping the day after tomorrow. Steven wants to buy some clothes in a clothing store and chicken in a butcher's shop.   He doesn't want to go shopping on Saturday as he hates the hustle and bustle.
# user :  Let ’ s also go to the jewelry store to buy a crystal necklace . I want to buy one for you as your birthday present .
# res : I don't want to go to the jewelry store unless I can bring something.
#  gt :  Thank you , darling .
# summarized : The Eiffel Tower was built in 1889 for the World's Fair. It is 320m high and held the record as the world's tallest structure until 1930.
# user :  I have heard its name is connected with someone , is that right ?
# res : I think so.
#  gt :  Yes , the towel was named after its designer Gustave Eiffel .
# summarized : Judy Wang cancels her reservation for Trans Pacific Flight 8 on July 19 from Taipei to Minneapolis and reschedules it to August 2. The ticket has a penalty of $ 75 for any change or cancellation. Judy will pay for the penalty at the airport. The new reservation is for Flight 8 at 9:30 a.m. on August 2, 1POJ7403.
# user :  Is there anything else I can do for you ?
# res : Just ask. My last name is Jenny Liu.
#  gt :  No , thanks . I ’ m all set . Good-bye .
# summarized : This is supply.
# user :  This is Rachel in Human Resources . I need two boxes of company letterhead , one box of ball-point pens , and a box of envelopes .
# res : Where are these?
#  gt :  All right . No problem . What ’ s your extension ?
# ##################################################
# 130
# ##################################################
# summarized : Charles Brown is the new manager at the airport. He is short, well-built and in his late thirties. He has light blond hair, a mustache and a light complexion.
# user :  Well . I shouldn ’ t have any trouble recognizing him . What time does his flight arrive ?
# res : About ten minutes.
#  gt :  At 2 thirty .
# summarized : Today I will get a hamburger, Sprite, chips and a bag of chips for a man.
# user :  Will that be all ?
# res : What is this for?
#  gt :  That's everything .
# summarized : As a college student, she took many insurance courses and worked at an insurance company for her graduation field work. She has worked as a salesman for P & G Company Ltd.
# user :  Do people respond well to you ?
# res : Yes, They are very friendly.
#  gt :  Yes , I'm good with people .
# summarized : The place I was telling you about is here. Would you like to
# user :  Let's have a look at the menu . Oh , there isn't a menu . Do you think you could ask the people at the next table if we could look at their menu ?
# res : No. I just want to make sure it is right.
#  gt :  Yes , of course . Excuse me . Could you possibly let us see your menu ? Oh . They haven't got one either .
# summarized : The bicycle is too expensive for him. He will buy it at a special price of ¥ 350.    The discount is already included in the price but it's still too much.
# user :  I see . Can I pay by traveler ’ s checks ?
# res : No, The check is already provided.
#  gt :  I'm afraid you can ’ t . You ’ re welcome to pay in cash .
# summarized : I'm having some trouble with using the printer. Do you have a free moment?
# user :  Oh , and it's out of paper . Do you have any more ?
# res : Yes.
#  gt :  Just a second . I'll go get some .
# summarized : The washer costs 50 cents and the dryer costs a dollar. The quarters go into the slot and the machine turns on when pushed in the slot.
# user :  I appreciate you helping me with this .
# res : Yes, Thank you.
#  gt :  If you need anything else , just let me know .
# summarized : After a year of working at the company, you qualify for a three-day vacation. If you use up your sick days before the end of the year, your pay will be deducted.
# user :  Yes . That's the company policy .
# res : Would you like to do a five-day vacation?
#  gt :  It was the same as the last place I worked at . I was hoping you ’ d be different .
# summarized : Lunch is going to be at the cafeteria. He bought some chow mein from the cafeteria and liked it very much. He likes the food there.
# user :  We can eat at the cafeteria .
# res : Thanks. I'll go and have a try.
#  gt :  I think you'll really like the food there .
# ...
# user :  How can I see test results from tests I have taken before ?
# res : It's a good idea to check that they are legal, Or to try to provide a short list of tests for you to see if you're allowed to have a review.
#  gt :  We put all of your test results up in the same place . Just check the dates for what you need .
# summarized : Mr. Lee's unit price is 100 dollars higher than ours. Mr. Lee suggests a further reduction of 50 dollars in their price, but it's impossible. The best they can do is another 30 dollars off, which is definitely the lowest they can go.
# user :  That still leaves a gap of 20 dollars . Let's meet each other half-away again and split the difference ; I think this is a price we can both be satisfied with .
# res : But you still say you'd like to receive $ 100 a month.
#  gt :  OK . We can meet halfway again .
# summarized : Carl and Ruth are supposed to meet at the Chinatown terminal of the Avenue B bus or D bus at 10:45. Carl tells Ruth to get off at Canal Street instead of the last stop in Chinatown. Ann is not coming.
# user :  See you around , Carl .
# res : Just stay where you are.
#  gt :  See you later .
# summarized : The company has had to clean up its production process to meet tough government standards. It's had to cut down on the amount of solvents and lead in its products.
# user :  What happens if you exceed the limits ?
# res : I think the government will take care of the problem.
#  gt :  We try not to because you might have to pay quite a heavy fine .
# summarized : That's the best
# user :  Okay , I'll take one .
# res : Thanks for helping me with that. I really appreciate that.
#  gt :  That'll be $ 200 , sir .
# summarized : Sir wants to make up the room
# user :  Yes , please . We're on our way out , so we put the ' make up ' sign on . Could you bring us some towels and hangers ?
# res : No problem.
#  gt :  No problem , sir . Everything will be ready when you come back .
# summarized : The main external factors are political, economic, social and technological factors.
# user :  What are the internal factors that influence the company ?
# res : Our main internal factor is competition with competitors.
#  gt :  The internal factors are composed of human resources , team spirit , innovation spirit and coordination between different departments , etc .
# summarized : Tony has some bad habits now. He says painful words everyday. Tony is a young child, but sometimes he is not reasonable. His mother should treat him with patience, affection, and respect. If he needs to do something, guide or help him to get it done, but lead him with gentleness.
# user :  Motivate Tony to cooperate by rewarding his good behavior . Do not emphasize punishment for bad moods , etc . Do not threaten him with punishment if he resists the actions you desire .
# res : For example, If he refuses to listen to your commands, Do you expect him to apologize to you?
#  gt :  I know my parents sometimes threaten to punish him . But this doesn ’ t work , instead he picks up another bad habit .
# summarized : James Mason from Anderson and Associates wants to meet with Mr. Smith, but he left the office this morning and is not expected back until after 4 pm. Ms. Terry, the office manager will be with James Mason shortly to brief him on his project. James will show him around while he's waiting.
# user :  That would be very nice . Thank you .
# res : Yes. You will see.
#  gt :  Right this way , Mr . Mason . We can start with our front office . When Ms . Terry is ready , you may take the elevator at the front to the 6th floor . There is a conference room already prepared
# summarized : Angelina Jolie and Brad Pitt didn't attend the Oscars on Sunday night. They got into a fight and decided not to go. Tom Cruise and Katie Holmes made an appearance at the Oscars. Neither Tom Cruise nor Katie Holmes won an Oscar this year. They only got married to get more publicity for their movies and themselves. I would never want to be a celebrity because the paparazzi would follow you everywhere you go and take pictures of you.
# user :  thank goodness we're not rich and famous !
# res : I bet some of you are too.
#  gt :  being famous , I can do without , but I wouldn't mind being rich .
# ##################################################
# 570
# ##################################################
# summarized : The exchange rate for cash purchases is listed on the electronica screen. RIB exchange rate is 20,000 RIB. He will exchange RIB for RIB and change 2,000 US dollars into Swiss francs. He can't exchange coins because the exchange rates are low and they don't have enough foreign coins.
# user :  Please sign the memo on the bottom and keep your money and memo .
# res : Thank you.
#  gt :  Thanks a lot . Good-bye .
# summarized :
# user : Why are you holding me in this jail cell ?
# res : Because I am scared.
#  gt :  We'd like to hear your account of the events of last night .
# summarized : I have to go to London for a couple of days next week. I prefer to go by train, but I don't want to take the car as it's more expensive.
# user :  But very much quicker . But I know we'll never agree on this subject . You prefer the car . I prefer the train .
# res : But the car is cheaper than the train?
#  gt :  Now , have you ever thought of going by express bus ?
# summarized : The house with the Open House flags out front is one of the houses on our Open House list. The listing agent provided water on such a hot day. The owner will sign the registry to let the listing agent know that they were here. He will pick up a flyer with the information about the house.
# user :  Is the current asking price listed on the flyer ?
# res : No, There's nothing on the site yet.
#  gt :  The asking price has recently gone down to two hundred and twenty-five thousand dollars .
# summarized : Mrs. Wilson wants to buy a new car. Mike's Sporting Goods is not the car store, it's Mike's. Mrs. Wilson should look in the phone book for the number.
# user :  I'm sorry to have bothered you .
# res : Thank you.
#  gt :  No problem .
# summarized : Tonight she will go to the cinema to see a romantic movie. She prefers thrillers.
# user :  Don't you think it's too bloody ?
# res : It's great that I like romance, Don't you?
#  gt :  On the contrary , very exciting .
# summarized : Dr. Smith's appointment with Dr. Smith was on Monday at 10, but she can't make it on that day. She would prefer next Thursday.
# user :  I want to come in at 2
# res : We'll have your emergency room appointment on Tuesday.
#  gt :  I am writing you down for that time . We look forward to seeing you .
# summarized : Janet Reese from American Advertising placed an order with Office Supplies Inc. a week ago.
# user :  Yes , Ms . Reese . I remember , you spoke with me . Is there a problem ?
# res : I don't know. It's too late.
#  gt :  Well , it still hasn ’ t gotten here , and my boss is pretty angry about it .
# summarized : Mike is the Division Chief of ABC Company and welcomes Ms Anderson to Toronto.
# user :  A pleasure meeting you as well , the flowers are for you .
# res : Thank you.
#  gt :  Thank you , they are beautiful .
# summarized : The TV is being sold for $2500, which is too expensive for the buyer. The TV is of very high quality and is of high quality.
# user :  I'll buy it for $ 2000 .
# res : Good luck.
#  gt :  I'm sorry , but the price is final .
# ##################################################
# 580
# ##################################################
# summarized : The bag is traditional Chinese Medicine. He packed it himself and it hasn't been taken out of his possession before checking-in. He's not bringing any plants or animal products. The sniffer dog will not find anything in the suitcase.
# user :  Oh no ! I forgot about those too ! Those are Chinese sausages for my Aunt Lily .
# res : Yes, But your aunt has a special medicine that she likes.
#  gt :  I ’ m sorry sir , but you can ’ t take any of this into the country . We will also have to check your carry-on . Please step this way . Don ’ t ’ be nervous ; we ’ ll just look through it briefly and then
# summarized : Bob has gone out and will be back at about 7 o'clock. Paul will leave a message for Bob on his phone. He will call Bob tomorrow afternoon.
# user :  All right . I'll tell him when he comes back .
# res : Okay, Well, Let's go out there and get some lunch.
#  gt :  Thank you very much .
# summarized : Dad wants to buy a life insurance policy for his son. Dad is a fireman and has to consider his mother's life. Dad took out a policy and made his mother the beneficiary.
# user :  That's true . Well , how much do you think I should get ?
# res : About $ 25, 000.
#  gt :  A $ 100 000 policy shouldn't be too expensive . Here , call my agent . He'll give you a good deal .
# summarized : Mr. Macmillan sends Susan the completed schedule for next week.
# user :  Thank you , sir . Sorry to trouble you .
# res : You're a good man. I just need to see what time you are in the lobby on Wednesday.
#  gt :  Not at all , Susan . Just tell him to leave it with my secretary when he ’ s finished with it
# summarized : Jane is going to the hospital to see Susan. She caught a number 7 bus to get there. The number 13 bus will also take her there.
# user :  Thank you , Henry . I'll get a number 13 .
# res : Jane, Thanks for taking your time.
#  gt :  But number 13 buses leave from the center of town.You ' ll have to walk two miles to catch one .
# summarized : Passport is brought for inspection. He has 6 packets of cigarettes and 2 bottles of champagne. He also has two cameras, one of which is for his own use and the other is a gift. According to the law, each passenger is allowed only one camera duty-free. He will have to pay duty for the other one.
# user :  Very well . I hope you ' ll enjoy your stay in America .
# res : Yes, I do. I hope I can get back to you soon.
#  gt :  Thank you .
# summarized : Nancy is a staff member of Nokia company. She is satisfied with her job. She learned to pay more attention to the external expressions during the interview. Good gestures and mien can let other feel comfortable.
# user :  How can I have the good external expressions ?
# res : Well, Sometimes, I find I can use them to be very nice to someone who is at an advanced age.
#  gt :  Don ’ t worry about that . You just pay more attention to the details of people ’ s action in life , and you will know how to transfer information by their body language .
# summarized : At the Universal Bank ATM, the girl wants to withdraw 10000 USD to the World Wildlife Foundation, but the machine refuses to accept her card. She has to withdraw the money from the ATM herself. She is angry at the machine for making her spend so much money. She wants to take her card from the slot.
# user :  No , no way ! What happened ? Give me my money !
# res : Sorry, Sir. Please move it, Sir.
#  gt :  Danger , danger ! The exits have been sealed and the doors will remain locked in until the local authorities arrive . Thank you for using our bank . Have a nice day .
# summarized : Mary will stay home tonight and finish her term paper. Joe wants to go to the movies with her on Friday night to see a movie about the rapist serial killer.
# user :  How about “ The Secret Life of Bees ” ?
# res : I'll see that movie next time.
#  gt :  That's a chick flick !
# summarized : The new branch office will open next month. It will be in the northeast of the city, near the airport and on the edge of the CBD. The HR person will hire the staff. They have already signed two contracts with companies they already do work for in other countries. They hope to sign another three this month. The advertising campaign has been prepared. It is a little rushed, but they should be able to set up the branch office and expand their business quickly.
# user :  Yes , it has . We ’ re going to target the business community through business magazines .
# res : But it will be in the neighbourhood. The neighbourhood is our most important job and we want to make sure our users can find jobs there too.
#  gt :  I made plenty of business contract on my last visit and through the embassy . We should be able to get plenty of customers .
# ##################################################
# 590
# ##################################################
# summarized : I want to pick up my valuables, so I want to borrow a key
# user :  Here is your valuable . Is that right ?
# res : Yes, Of course. My wallet is in our house.
#  gt :  Yes , thank you .
# summarized : Abortion is still illegal in many states in the USA. Most people in America are against abortion. Religious people blame teenage pregnancy on pre-marital sex, not on abortion being illegal. I would never want to have an abortion, but I think that since a pregnancy can affect a woman's entire life, she should have the right to decide for herself. I don't think fathers should have to give their approval to the mothers of their children.
# user :  that may be true , but when a woman gets pregnant , it changes her life completely . Men can still carry on with their lives after the birth exactly as they did beforehand .
# res : I agree with you on that. So there are many benefits of having a child. ButWomen's rights are too important to lose.
#  gt :  that might be true , but I think men should have some kind of say in the matter .
# summarized : You should read English books and review for your test. It might help you get to sleep.
# user :  Aw , Mom-you're such a drag .
# res : Thanks, Mom.
#  gt :  You say that now , Lily , but you'll thank me later . I'm your mom , and mother knows best .
# summarized : The company hasn't made a decision about the position yet.
# user :  We will let you know probably next Monday . I hope to give you a positive reply .
# res : Thank you.
#  gt :  I'm willing to wait until you have come to a decision .
# summarized : There are websites that can hook you up with a roommate if you want to rent a one-bedroom apartment. It will probably cost you around twelve hundred dollars a month.
# user :  Would you come with me to look at apartments ?
# res : I'd like to. If we're still having problems, We'd better get an agent here.
#  gt :  I would be happy to look at apartments with you .
# summarized : Deborah has just had her baby. The baby was 8 pounds 6 ounces. Will visit them.
# user :  I just wanted to give you the good news .
# res : Thank you very much. Have you got the address of the home?
#  gt :  Thanks for letting me know .
# summarized : It was the first thing that came to her mind when she heard the earthquake.
# user :  Maybe the situation is too urgent .
# res : I want to move my house.
#  gt :  Yes , I think I should have jumped in any case .
# summarized : I need to stop eating unhealthy foods. I tend to stick to fruits, vegetables, and chicken. I've started eating better myself.
# user :  It's really healthy to eat when you bake it .
# res : Really?
#  gt :  I guess that does sound a lot healthier .
# summarized : Grace Williams and Peter Smith are new comers in the office. It's Peter's first day at work.
# user :  Thank you . It's very kind of you .
# res : Who did you work with?
#  gt :  You are welcome .
# summarized : Advertising planner should have active thoughts, creative talent and be sensitive to the changes in the market, according to him. He used to work as an advertising planner in an advertising company.
# user :  What was the most important thing you have learned at work ?
# res : Well, The most important thing is to follow the market, And to make the most of what's available.
#  gt :  The most important thing I learned was that I must continuously improve my abilities . Advertising is a constantly evolving trade and creativity is an important fact to success . If I want to make in marking in advertising industry , I can ’ t stop studying and creating .
# ##################################################
# 600
# ##################################################
# 문자열 간에 유사도 : 0.15828901433190182

# %% [markdown]
# ## dataset devset test - text rank - 이거말고 textrank-test.ipynb 이용할것

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
def textrank(conversation):
    notbadlen = len(conversation) // 2
    # 문장 토큰화
    sentences = sent_tokenize(conversation)

    # 불용어 제거 및 어간 추출
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    # 전처리
    def preprocess(sentence):
        tokens = word_tokenize(sentence.lower())
        tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalnum() and token not in stop_words]
        return tokens

    sentences_tokenized = [preprocess(sentence) for sentence in sentences]

    word_set = set(word for sentence in sentences_tokenized for word in sentence)
    word_to_idx = {word: i for i, word in enumerate(word_set)}

    word_vectors = np.zeros((len(word_set), len(word_set)))
    for sentence in sentences_tokenized:
        for i in range(len(sentence)):
            for j in range(i+1, len(sentence)):
                word_i_idx, word_j_idx = word_to_idx[sentence[i]], word_to_idx[sentence[j]]
                word_vectors[word_i_idx, word_j_idx] += 1
                word_vectors[word_j_idx, word_i_idx] += 1

    sentence_vectors = np.zeros((len(sentences), len(word_set)))
    for i, sentence in enumerate(sentences_tokenized):
        for word in sentence:
            sentence_vectors[i, word_to_idx[word]] += 1

    similarity_matrix = cosine_similarity(sentence_vectors)

    # summarization
    def summarization(similarity_matrix, d=0.85, max_iter=100):
        scores = np.ones(len(sentences))
        for i in range(max_iter):
            scores = (1-d) + d*np.dot(similarity_matrix.T, scores)
        return scores

    scores = summarization(similarity_matrix)
    ranked_sentences = sorted(((score, i) for i, score in enumerate(scores)), reverse=True)

    # 요약문 출력 (대화문 중 핵심이 되는 대화 2문장 출력)
    num_sentences = notbadlen
    summary_sentences = sorted(ranked_sentences[:num_sentences])
    summary = ' '.join([sentences[i] for _, i in summary_sentences])
    return summary

# %%
from datasets import *
from tqdm import tqdm


# For all
space = 'Ġ'
pre_quote = '’'
end_marks = ['.', ',', '?', '!', '...']
quotes = ['"', '\'']
abbreviations = ['s', 'd', 't', 'm', 're', 'll', 've', 'S', 'D', 'T', 'M', 'Re', 'Ll', 'Ve']

# For empathetic dialogues
exclude_symbol = "_conv"
comma_symbol = "_comma_"

# For persona chat
persona_chat_url = "https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json"
silence_symbol = "__ SILENCE __"


def load_daily():
    dataset = load_dataset('daily_dialog')
    test_dialogues = dataset['test']['dialog']
    
    return test_dialogues
    
    

def process_token_list(token_list):
    token_list[0] = token_list[0].capitalize()
    
    quote_count = 0
    for i, token in enumerate(token_list):
        if space in token:
            if token[1:] in end_marks or token[1:] in abbreviations:
                token_list[i] = token[1:]
                
            if token[1:] == quotes[1]:
                if i<len(token_list)-1:
                    if token_list[i+1] in abbreviations or (token_list[i+1][0] == space and token_list[i+1][1:] in abbreviations):
                        token_list[i] = token[1:]
                        
        if token[0] == space and token[1:] in quotes:
            if quote_count % 2 == 1:
                token_list[i] = token[1:]
                quote_count = 0
            else:
                if i<len(token_list)-1 and token_list[i+1][0] == space:
                    token_list[i+1] = token_list[i+1][1:]
                quote_count += 1
                
        if token in end_marks or token[1:] in end_marks:
            if i<len(token_list)-1:
                if token_list[i+1][0] != space:
                    token_list[i+1] = space + token_list[i+1].capitalize()
                else:
                    token_list[i+1] = space + token_list[i+1][1:].capitalize()
                
    new_token_list = [token for token in token_list if token != space and len(token)>0]
    if new_token_list[-1] not in end_marks:
        new_token_list.append(end_marks[0])
        
    return new_token_list

# %%
test_arr = load_daily()
load_daily()

# %%
# utters= ["hello" , "my" , "name" , "is" , "susan" , "thank" , "you" , "for" , "listening"] 

# print(' '.join(utters[:-2]))

# %%
import difflib
from transformers import GPT2Tokenizer, GPT2LMHeadModel, get_polynomial_decay_schedule_with_warmup

from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
from itertools import chain

import torch
import os, sys
import numpy as np
import argparse
import copy
import math
import random
import json

class Arguments:
    def __init__(self):
        self.seed = 0 
        self.mode="test" 
        self.data_dir="data" 
        self.model_type="gpt2" 
        self.bos_token="<bos>" 
        self.sp1_token="<sp1>" 
        self.sp2_token="<sp2>" 
        self.gpu="0" 
        self.max_len=1024 
        self.max_turns=5 
        self.top_p=0.8 
        self.ckpt_dir="saved_models" 
        self.ckpt_name="best_ckpt_epoch=3_valid_loss=2.6631" 
        self.end_command="Abort!"



#원래 shell로 들어가는 파라미터를 정의합니다.

class Manager():
    def __init__(self, args, test_arr):
        self.args = args
        self.test_arr = test_arr

        if torch.cuda.is_available():
            self.args.device = torch.device(f"cuda:{self.args.gpu}")
        else:
            self.args.device = torch.device("cpu")
        
        # Tokenizer & Vocab
        print("Loading the tokenizer...")
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.args.model_type)
        special_tokens = {
            'bos_token': self.args.bos_token,
            'additional_special_tokens': [self.args.sp1_token, self.args.sp2_token]
        }
        self.args.eos_token = self.tokenizer.eos_token
        num_new_tokens = self.tokenizer.add_special_tokens(special_tokens)
        vocab = self.tokenizer.get_vocab()
        self.args.vocab_size = len(vocab)
        self.args.bos_id = vocab[self.args.bos_token]
        self.args.eos_id = vocab[self.args.eos_token]
        self.args.sp1_id = vocab[self.args.sp1_token]
        self.args.sp2_id = vocab[self.args.sp2_token]
        
        # Load model    
        print("Loading the model...")
        self.fix_seed(self.args.seed)
        self.model = GPT2LMHeadModel.from_pretrained(self.args.model_type).to(self.args.device)
        self.model.resize_token_embeddings(self.args.vocab_size)
        
        self.args.max_len = min(self.args.max_len, self.model.config.n_ctx)
            
        
        
        if self.args.ckpt_name is not None:
            ckpt_path = f"{self.args.ckpt_dir}/{self.args.ckpt_name}.ckpt"
            if os.path.exists(ckpt_path):
                print("Loading the trained checkpoint...")
                ckpt = torch.load(ckpt_path, map_location=self.args.device)
                self.model.load_state_dict(ckpt['model_state_dict'])
                
                if self.args.mode == 'train':
                    print(f"The training restarts with the specified checkpoint: {self.args.ckpt_name}.ckpt.")
                    self.optim.load_state_dict(ckpt['optim_state_dict'])
                    self.sched.load_state_dict(ckpt['sched_state_dict'])
                    self.best_loss = ckpt['loss']
                    self.last_epoch = ckpt['epoch']
                else:
                    print("The inference will start with the specified checkpoint.")
            else:
                print(f"Cannot fine the specified checkpoint {ckpt_path}.")
                if self.args.mode == 'train':
                    print("Training will start with the initialized model.")
                else:
                    print("Cannot inference.")
                    exit()
              
        print("Setting finished.")
        
    def nucleus_sampling(self, input_ids, token_type_ids, input_len):
        output_ids = []
        for pos in range(input_len, self.args.max_len):
            output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
            output = F.softmax(output, dim=-1)  # (1, V)
            
            sorted_probs, sorted_idxs = torch.sort(output, descending=True)
            cumsum_probs = torch.cumsum(sorted_probs, dim=-1)  # (1, V)
            idx_remove = cumsum_probs > self.args.top_p
            idx_remove[:, 1:] = idx_remove[:, :-1].clone()
            idx_remove[:, 0] = False
            sorted_probs[idx_remove] = 0.0
            sorted_probs /= torch.sum(sorted_probs, dim=-1, keepdim=True)  # (1, V)
            
            probs = torch.zeros(output.shape, device=self.args.device).scatter_(-1, sorted_idxs, sorted_probs)  # (1, V)
            idx = torch.multinomial(probs, 1)  # (1, 1)
            
            idx_item = idx.squeeze(-1).squeeze(-1).item()
            output_ids.append(idx_item)
            
            if idx_item == self.args.eos_id:
                break
                
            input_ids = torch.cat((input_ids, idx), dim=-1)
            next_type_id = torch.LongTensor([[self.args.sp2_id]]).to(self.args.device)
            token_type_ids = torch.cat((token_type_ids, next_type_id), dim=-1)
            assert input_ids.shape == token_type_ids.shape
            
        return output_ids

    def fix_seed(self, seed):
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        random.seed(seed)  

    def test(self):
        test_arr = self.test_arr
        print("Let's start!")
        self.model.eval()
        self.fix_seed(self.args.seed)

        summarized_utter = []
        user = []
        ground_truth = []
        for utters in test_arr:

            #summarized_utter.append(summarizer(utters[:-2])[0]["summary_text"]) #요약문장
            user.append(utters[-2]) #user utter
            ground_truth.append(utters[-1]) #ground truth 진짜 정답.

        
        with torch.no_grad():
            input_hists = []
            ex_cnt = -1
            similarity = 0
            context_for_json = []
            ans_for_json = []
            for utters in test_arr:
                #utter = input("You: ")
                ex_cnt += 1
                if ex_cnt == len(test_arr):
                    break
                
                ## summarized input ##
                input_hists = []
                if len(utters) >= 3:
                    string_input = ' '.join(utters[:-2])
                    sumrz_input = textrank(string_input)
                else:
                    string_input = ""
                    sumrz_input = ""    
                summarized_utter.append(sumrz_input)

                context_for_json.append(string_input) #chatgpt classification

                sumrz_input_ids = [self.args.sp1_id] + self.tokenizer.encode(sumrz_input) # sp1 sumar.. utter
                input_hists.append(sumrz_input_ids)

                ## sumarized utter를 하나씩 꺼냅니다. ##

                input_ids = [self.args.sp2_id] + self.tokenizer.encode(utters[-2]) # sp2 user utter
                input_hists.append(input_ids)
                
                #if len(input_hists) >= self.args.max_turns:
                    #num_exceeded = len(input_hists) - self.args.max_turns + 1
                    #input_hists = input_hists[num_exceeded:]
                # 역시 턴 개념은 사용하지 않습니다.
                    
                input_ids = [self.args.bos_id] + list(chain.from_iterable(input_hists)) + [self.args.sp1_id] # 2 -> 1
                #start_sp_id = input_hists[0][0]
                start_sp_id = self.args.sp1_id
                


                #next_sp_id = self.args.sp1_id if start_sp_id == self.args.sp2_id else self.args.sp2_id
                next_sp_id = self.args.sp2_id

                assert start_sp_id != next_sp_id
                token_type_ids = [[start_sp_id] * len(hist) if h % 2 == 0 else [next_sp_id] * len(hist) for h, hist in enumerate(input_hists)] 
                assert len(token_type_ids) == len(input_hists)
                token_type_ids = [start_sp_id] + list(chain.from_iterable(token_type_ids)) + [self.args.sp1_id] # 2 -> 1
                assert len(input_ids) == len(token_type_ids)
                input_len = len(input_ids)
                
                input_ids = torch.LongTensor(input_ids).unsqueeze(0).to(self.args.device)
                token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)
                
                output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)
           
                # output_ids = self.model.generate(
                #     input_ids=input_ids, token_type_ids=token_type_ids, pad_token_id=self.args.eos_id,
                #     do_sample=True, top_p=self.args.top_p, max_length=self.args.max_len,
                #     output_hidden_states=True, output_scores=True, return_dict_in_generate=True,
                # ).sequences
                # output_ids = output_ids[0].tolist()[input_len:]
                res = self.tokenizer.decode(output_ids, skip_special_tokens=True)

                similarity += compute_similarity(res, ground_truth[ex_cnt])

                print(f"summarized : {summarized_utter[ex_cnt]}")
                print(f"user : {user[ex_cnt]}")
                print(f"res : {res}\n gt : {ground_truth[ex_cnt]}")

                # 예측한 문장과 ground truth를 비교할 수 있습니다.
                # 아직 눈으로 밖에 비교할 방법이 없음.

                #print(f"Bot: {res}")
                #input_hists.append([self.args.sp2_id] + self.tokenizer.encode(res))

                context_for_json[-1] += user[ex_cnt]
                ans_for_json.append(res)

                assert len(context_for_json) == len(ans_for_json)
                if len(context_for_json) == 600:
                    # 데이터 딕셔너리 생성
                    data = {"context": context_for_json, "ans": ans_for_json}

                    # JSON 파일로 저장
                    with open("test/json/textrank_3e.json", "w") as f:
                        json.dump(data, f)
                    break
                

        print(f"문자열 간에 유사도 : {similarity / len(test_arr)}")


def compute_similarity(string1, string2):

    matcher = difflib.SequenceMatcher(None, string1, string2)
    return matcher.ratio()

# 두 문자열을 비교하는 함수이나...
# 큰 의미는 없는것 같다.

# %%
args = Arguments()
args.ckpt_dir = f"{args.ckpt_dir}/{args.model_type}"
assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
manager = Manager(args, test_arr)
manager.test()
# Out:
# Loading the tokenizer...
# Loading the model...
# Loading the trained checkpoint...
# The inference will start with the specified checkpoint.
# Setting finished.
# Let's start!
# summarized : Some what ? Sounds good ! Pot , Ganja , Mary Jane some chronic ! You know ? I also have blow if you prefer to do a few lines . Try some ! Where do you get them from ? Oh , umm , no thanks . Let ’ s see , I want . Just tell me what you want and I ’ ll even give you one ounce for free . I got my connections ! I even got dope and acid ! Come on man ! Weed ! No , I am ok , really . Do you really have all of these drugs ? Hey man , you wanna buy some weed ?
# user :  Yeah ?
# res : Of course I have. The rest is out of my head. I only ask that you bring me one ounce of heroin.
#  gt :  I want you to put your hands behind your head ! You are under arrest !
# summarized : What for ? The taxi drivers are on strike again .
# user :  They want the government to reduce the price of the gasoline .
# res : You know, These days, Even with high gasoline prices, The fuel is cheaper than ordinary gasoline. So, They can pay less.
#  gt :  It is really a hot potato .
# summarized : What does that mean exactly ? That's excellent . Mainly because we've invested in a heat recovery system . Well , we use the exhaust gases from our printing presses to provide energy to heat our dryers . How have you managed that ? We've managed to reduce our energy consumption in our factory by about 15 per cent in the last two years .
# user :  What other sources of energy do you use ?
# res : My burning needs are made mainly by cooking food.
#  gt :  We don't use any fossil fuels . Most of our power comes from hydro-electric plants . We're hoping to use even more energy from alternative sources in the future - perhaps even wind power .
# summarized : isn't it ? Right . Any Others ? Oh , yeah . Oh , so do I . Why don't we go for one now ? Some even claim they can't live without tea . Believe it or not , tea is the most popular beverage in the world after water . Well , people from Asia to Europe all enjoy tea . Sure , I like drinking tea at teahouses . Oulong tea is good for one's health . Yes , Chinese people love drinking tea so much . Do you know there are several catagories of Chinese tea ? You surely know a lot about Chinese tea . And China is the homeland of tea . Well , have you ever heard of Oulong tea and compressed tea ? Yes , I believe there are green teas , black teas and scented teas .
# user :  Great . We can chat while enjoying a cup there .
# res : Of course. What about black tea?
#  gt :  Let's go !
# summarized : What are your personal weaknesses ? Are you more of a leader or a follower ? Yes , in most circumstances . That is not very good for business , so I have been studying public speaking . I ’ d rather cooperate with everybody , and get the job done by working together . Do you think you can make yourself easily understood in English ? I ’ m afraid I ’ m a poor talker . I ’ m not comfortable talking with the people whom I have just met for the first time . I don ’ t try to lead people .
# user :  Are you available for travel ?
# res : No problem. I am available for business trips.
#  gt :  Yes , I like travelling . I am young , and unmarried . It ’ s no problem for me to travel frequently .
# summarized : no . I can ’ t remember exactly . you ’ re right . ok . that ’ s unless there is a traffic jam . We will be able to travel at high speeds at the beginning and end of the journey , because we will be in built-up areas . You haven ’ t seen my company car , have you ? I think it ’ s over five meters long . let me take a look ... it ’ s longer than my car . It has a maximum speed of over 200 kilometers an hour . I think it ’ s a distance of 180 kilometers from here to London , so it should be a two-hour drive on the motorway . so , shall we allow three hours to cover the distance ? how long will it take us to drive to London ? It could take three hours .
# user :  wow ! That ’ s fast ! I don ’ t think we will be traveling that fast on the motorway .
# res :  Will we run out of time?
#  gt :  we can ’ t . if we went that fast , we would break the speed limit .
# summarized : How ? What were they ? Do you want the truth ? There were a number of reasons . Well , you really didn't do all that well . Of course , I do . How bad did I do ? Basically , you just can't drive . So how did I do on my driving test ? To be completely honest , you failed your test .
# user :  Can I have another try ?
# res : I've never driven with a single driver in my life.
#  gt :  You can take it in a couple weeks .
# summarized : Open your mouth and say'ah ' . You have all the symptoms of influenza . What's the matter with you ? Ah . What am I supposed to do then ? Lat me give you an examination . And your tongue is heavily coated . Tell me how it got started . And I ’ m afraid I've got a temperature . Now my nose is stuffed up . Yesterday I had a runny nose . I have a terrible headache . I feel terrible . All right , young man . Don't worry , young man . First let me take a look at your throat . I have a sore throat . Your throat is inflamed . Good morning . Good morning , doctor .
# user :  A good rest is all you need , and drink more water . I'll write you a prescription .
# res : Thanks, Doctor. I'll take that medicine now. Thank you very much.
#  gt :  Thank you very much .
# summarized : My dear , what's for supper ? I can watch TV now . Thanks . Red cooked carp and rape with fresh mushrooms . I'll use ginger , garlic scallion , hot pepper and vinegar . Which condiment do you use for ? No , don't need , I can do myself . Very good , need I help you ? What about soup ? Sour-peppery soup .
# user :  But you must cook that dinner next time .
# res : Is soup enough?
#  gt :  Okay , I'll do it next time .
# summarized : How are you ? I really need to focus on getting packed and ready to move back home . Everything is fine , and how are you ? Things are going well with me . Good to hear from you . Kara , I had fun the other night at the movies and was wondering if you would like to go out again this Friday . Mike , I don't think that it's a good idea to go out again . Hello , this is Mike , Kara . Mike !
# user :  Maybe we could just meet for coffee or something .
# res : Sure. You two should really hang out together next time we go out.
#  gt :  I can't really deal with any distractions right now , but I appreciate the nice evening we spent together .
# summarized : May I help you ? Hold on , please . Let me check it for you . Sun-set hotel . You will keep it for 3 days . It's a double room . Yes , you're right . Yes , I have booked a room for 24th .
# user :  Well , now I want to change the date from 24th to 28th .
# res : That's ok, Thank you.
#  gt :  OK , that shall be arranged .
# summarized : What's up ? I'm free . Are you busy tomorrow morning ?
# user :  Someone has to pick up the boss at the airport .
# res : I know, But I need to go to work tomorrow morning.
#  gt :  Oh , I just remembered I've got a report to write .
# summarized : I lost my bag . It's ten after six.We ' re late.But dinner is at six thirty . I had a really bad day . I'm sorry I'm so late . I'm really sorry . I know . I know .
# user :  I'll call the lost and found office .
# res : I'm sorry I have to do this.
#  gt :  I didn't think of it.Thank you.And I do apologize for being late .
# summarized : How can I help you ? Do you have the ' The man and the Sea ' by Ernest Hemingway ? Nani Book Store .
# user :  Yes , we have one copy left .
# res : Thank you. I really appreciate your help.
#  gt :  Can you hold it for me ?
# summarized : Yes , here you are . How much is it ? Do you have maps of downtown area ?
# user :  It's free of charge .
# res : Very reasonable price, That is.
#  gt :  Thanks so much .
# summarized : What is it ? I'm Michelle , at your service . It's $ 308 a night . Now , is a queen-size bed okay ? Your reservation is confirmed . Could I have your full name , please ? My plans are to be there April 14th to the 17th . Will that be acceptable to you ? Well , it depends on the price , of course . I can't handle that smell . Now all I need is your phone number . We have new room rates , sir . When do you need the room ? Hi there , I want to reserve a hotel room . Hi , Mr . Great ! Great , Mr . Would you prefer smoking or nonsmoking ? Definitely nonsmoking . Nonsmoking . Sure , John Sandals . Sandals . Sandals . No problem at all . I have no problem with that . No problem .
# user :  Of course ! It's area code 626-555-1739 .
# res : Sounds great!
#  gt :  Thank you so much , Mr . Sandals . We look forward to seeing you !
# summarized : I'm afraid there's been a mistake . What seems to be the trouble ? Could I have my bill , please ? Certainly , sir . I'm sorry , sir .
# user :  I believe you have charged me twice for the same thing . Look , the figure of 6.5 dollar appears here , then again here .
# res : Well, I am sorry I'm late for the bill.
#  gt :  I'll just go and check it for you , sir .
# summarized : Here it is . please accept our sincere apologies , I'll be glad to change it for another one if you wish . Anything wrong with it ? Oh , how awful ! When I spread it out back home , I found this hole . Can I help you ? Well . Good evening , madam . I bought this sheet here yesterday . May I have a look at the invoice ? Yes . Yes .
# user :  That's very kind of you . Thank you .
# res : Thanks again.
#  gt :  We're sorry that this has happened , and I guarantee that the same mistake won't happen again .
# summarized : I need to buy some flowers for my wife . Yes , that is today's sale price . Perhaps you'd be interested in red roses . What would the roses cost me ? I like the sound of that . Is there anything else you'd like to get ? They're only $ 20 a dozen . A dozen will be fine .
# user :  No , thank you .
# res : We'll get the roses tomorrow.
#  gt :  These roses should make your wife very happy .
# summarized : Yes , I am afraid there are not enough outlets . Room service , is there anything I can do for you ? Well , we have 6 for each room .
# user :  Yes , but 4 of them are broken . Can you send someone here ?
# res : Sure. I have something for you.
#  gt :  OK sir , please wait a minute .
# summarized : I apologize , but I didn't realize that I did . I don't know what to tell you . Why'd you pull me over ? Yes , you did . I did learn that . I'm going to have to write you a ticket . Weren't you taught that yellow means slow down , not speed up ? So , then why did you speed up ? Are you aware that you drove through a red light ? I ran a red light ?
# user :  I understand .
# res : Can you explain?
#  gt :  Here you go . Don't do that again .
# summarized : Surely of course . Can I get my pictures tomorrow ? Can I have the roll of film developed here ? Here is the film .
# user :  Sure .
# res : How much film will you need?
#  gt :  Besides I want two copies of all the photos .
# summarized : I was born in 1980 . I have majored in accounting . Tell me a little bit about yourself , please . My name is Dunlin and I live in Beijing . I will graduate from Peking University this July .
# user :  Would you tell me something about your family ?
# res : My parents are from Shanghai and my mother is from Guangzhou.
#  gt :  There are three in my family , my parents and myself . My father is a teacher and my mother is a worker .
# summarized : That's basically it . How do you stick to only those foods ? I have to start eating better too . Yeah , I know , but what about the chicken ? I really need to start eating healthier . Actually , fruits and veggies are really good for you . What kind of food do you usually eat ? I mainly eat baked chicken , because there's not a lot of fat . I try my best to eat only fruits , vegetables , and chicken . Is that really all that you eat ?
# user :  That does sound pretty good .
# res : Yes, And it's nice to have fresh vegetables too. I also like to make healthier salad dressing and salads.
#  gt :  I know it does , and that's because it is .
# summarized : Here they are . l'm sorry . Can I help you ? Could you show me where the Chinesc-style clothing is located ? I want to buy a silk coat . They're all handmade . Of course . OK . What do you think ? Really ? Our pleasure . The fitting room is right over there . Oh , they look nice . Oh , that suits you very well . I'II take it and I'm leaving here tomorrow . This way , please . Please fill out this form , leaving your address and telephone number . Good afternoon ! Do you have a medium in the same color ? Besides it is believed in China that the red color brings happiness and good luck . Let me try it on . All the black of that size are sold out . Would you like a red one ? This one is a little tight . Is it possible for you to send one in black to me by mail when you get it in ? May I try that black one on ?
# user :  Thanks . How much would that come to ?
# res : It would cost me some money.
#  gt :  Let me see ...
# summarized : Why not ? Great , thanks . Can I help you ? Can I do that right now ? You have to make an appointment first . I would actually like to view the apartment for rent today . How are you today ? I ’ m sorry , but you won ’ t be able to view it today . Oh , okay . Is 6 o ’ clock Friday evening okay ? Is this Friday okay ?
# user :  Yes , I will schedule you for that time .
# res : Is that all?
#  gt :  Thank you very much . See you then .
# summarized : Thank you . Of course . A two-week paid vacation a year , a five-day workweek . I wonder whether I can enjoy the life insurance and health insurance . Today I want to invite you to talk about insurance you ’ re interested in .
# user :  Good . Anything else ?
# res : About health insurance, What is it?
#  gt :  Yes , all the insurance will be linked with your work . We will issue an insurance policy .
# summarized : Here it is . Let me see . En .. just a minute . Hello , may I help you , sir ? Here is your change . at that corner . Here is five dollars . Ok , it comes four dollars twenty cents . I also want to pack up my package . Next , please . Yes , I want to send a registered airmail letter to France . Drop it in the mail box mark out of town . Oh , one more thing , where can I mail this letter ? Please wait for your receipt of the registered mail . This is the notes . I need your signature on this note .
# user :  Thank you very much .
# res : May I have a copy of the note with your address?
#  gt :  You ‘ re welcome .
# summarized : we really were lucky . I'm starving ! that's my favourite . What are you going to have for your main course ? We got the last available table for two---and we didn't even have a reservation ! it's got chickpeas and vegetables in a spicy curry sauce with rice . I heard that one of their specialities is the samosa . I wouldn't recommend it . what would you rather have , samosas or poppadoms ? sounds good . that sounds nice . ok . ok , shall I flag down the waitress ? let's take a look at the menu so we can order . Did you see the long lines behind us ? well , let's get a plate of those then . How about some lamb kebabs ? yeah , I'm glad that we didn't have to wait long . Do you want to choose an appetizer for us to share ? Do you want to share some kebabs as well ? what's in a dahl ? Do you want to have some wine or beer ? I think we should wait until she comes round . I think I'll have a beer . I think I might have a dahl .
# user :  you're right . That might seem a bit rude . It's a good thing I've got you with me !
# res : I'm really sorry if I offended you.
#  gt :  what would you do without me ?
# summarized :
# user : This position demands a higher writing ability , so please say something about your writing ability .
# res : I am an engineer.
#  gt :  Of course . I've loved writing since I was a very little boy . I won the first prize in a national composition contest when I was in middle school . After attending Nanjing University , I never give up writing . My works , such as Father's Tobacco Pipe , Open Air Cinema , The old City were respectively published China Youth Daily , Yangzi Evening News , and New Beijing . During the period of studying for my degrees of master and doctor , I paid more attention to developing my research ability and published several papers . The Impact of Internet in Chinese Political Participation , The Discipline of Remold , The Historical Direction of Chinese Administration Reform , Bribery Cases of Self governance in Chinese Villages are respectively published in Chinese Publish Administration , Beijing Due Xuebao , Theory and Society and Chinese Reform . I joined in Yangzi Evening News to work as a part-time journalist in 2006 . During this period , I've written a lot of comments , which improved my writing ability to a new level , I have full confidence in my writing ability , and I believe I can do the job well .
# summarized : How may I help you ? Six couples . pompous . How large a group are you expecting ? That sounds like a good idea . Would you like to reserve a private dining room ? Yes , I'd like to reserve a table for dinner .
# user :  All right . May I have your name , Sir ?
# res : Sir.
#  gt :  My name is Ron Kollwitz .
# summarized : Ms . Wang , this is Mr . It's nice to meet you , Mr . Cooper , president of Ivy Publishing . Cooper .
# user :  Nice to meet you , Ms . Wang . You must be exhausted after your long trip from Canada .
# res : Thanks a lot for coming, Ms. Wang. We have a great meeting with you today.
#  gt :  Yes , it was quite a long flight . I'm glad to finally be here .
# summarized : No , but I'll be able to tomorrow . Can you help me now ? That'll be too late .
# user :  Why don't you ask Bill if he can help ?
# res : What time would it be?
#  gt :  I did , but he wasn't able to either .
# summarized : Finally , she can make notes in shorthand and types and has the skills in report writing , summary writing , keep minutes at meetings , and so on . Most important of all is that she seems to have a better memory than average . That's fine . What about operating the fax and duplicator ? I can handle them without any trouble   What have you learned from jobs you have held ? Sometimes I have to do the work of a specialist when there ’ s something urgent . Well , to begin with , I would say she needs to be diligent , and the second point is that she has to do a lot of things on her own initiative . Yes , sir . Yes , I have been working in the Public Relations Section of a company in the past two years . I plan the advertising campaign and cooperate the work of artists and typographers . Would you tell me the essential qualities a secretary should maintain ? I acted as a secretary in an insurance company . Yes , I studied in a computer training program , and can process data through the computer . Have you got any experience in advertising ? Do you have any practical experience as a secretary ? Have you had any experience with computer ?
# user :  Above all , I have learned that what is good for the company is good for me . So I follow the instructions strictly and always keep my boss informed .
# res : Do you use any sales manual, anyway?
#  gt :  Very good .
# summarized : Where have you been ? What's up ? Hi , Dan . I got fired . Why this sudden change ? It's a long story . What's new ? How come ? What are you going to do now ? I didn't tell her . Did you look in the classified advertisements column ? Yes , I did . Last time I saw you . That was only one month ago . Lily doesn't know yet . That's not the way to solve the problem . I messed up a business deal , a deal that would have made ten million dollars and I messed it up . I went to Salt Lake City on business . I spent the past three days at the coffee shop next to your office , and she thought I went to work as usual . I've been trying to get in touch with you for two days . I am trying to find a job asap . But I wasn't qualified for most of the jobs that I was interested in . You told me it was a good job , and you'd like to take it as a career . In a word , I didn't do a good job of it .
# user :  Listen . I will see what I can do , ok ? You go home and tell Lily about this problem you have now . She is your wife and I am sure she will understand .
# res :  Thank you very much. I will be back soon.
#  gt :  I just don't know how to bring it up . Well , all right . She has the right to know anyways .
# summarized : Have you ? Why did you do that ? At my apartment building . Where did you park at ? I parked in the red zone . I got a ticket yesterday . Don't you have your own parking spot ? Really ? Have you ever gotten a parking ticket ? I needed to get something really quick . I've never gotten one . What did you get one for ?
# user :  I needed to be fast .
# res : How long had you been stuck with a ticket?
#  gt :  That was very lazy of you .
# summarized : Here it is . How may I help you ? How long will an investigation take ? Do you have the statement for your card ? The last four charges on the page . I ’ m afraid we ’ re going to have to investigate these charges . There have been charges made on my debit card that I didn ’ t make . What are the charges you ’ re referring to ? I ’ m having a problem . What problem are you having ?
# user :  I honestly don ’ t know , but we will freeze payment on these charges .
# res : But your debit card charge is ‘I know it, But ‘I ‘cannot bear it anymore. I ‘give you my number ‘I am sorry for the inconvenience.
#  gt :  That sounds absolutely fantastic .
# summarized : Good afternoon . Yes , of course . OK , could I take a look at some ID please , like a passport ? Can I be of service ? I don't know . Two years is fine , with a value of 1,000 RIB . Can I purchase Treasury Certificates here at this counter ? We have Treasury Notes with two , three and five-year terms available .
# user :  Here you go . By the way , is it possible to cash them before the maturity comes up ?
# res : Yes, It is.
#  gt :  No , I'm afraid that isn't possible . You must wait until maturity before you cash them .
# summarized : I should send you to jail ! Hey . You are such a cheater ! I am not cheating . Yes ... When you pass go , you collect $ 200 , Everyone knows that ! And I ’ m the banker . Banker ? You have to ask the bank for money . Well you can ’ t just take the money . Why did you take that money ?
# user :  Can I have my $ 200 please ?
# res : Ok, You will pay me back in two weeks.
#  gt :  Sure . Here you are , $ 200 , Thank you , please come again ! Now it ’ s my turn to roll the dice .
# summarized : I had a skydiving accident over the weekend and won ’ t be able to come to school today . Yes , what can I do for you ? My goodness ! Are you OK ? I broke my leg , but it is healing . How long will you be out of class ? Hi , this is Kalina from your morning literature class . This is Professor Clark speaking . Hi , is this Professor Clark ’ s office ?
# user :  I should be able to return by next Monday .
# res : Right, Good-bye. I'm sorry for your interruption.
#  gt :  Fine . Well , thanks for calling and letting me know you will be absent . I hope you feel better soon .
# summarized : Good afternoon ! Did you call for a plumber ? I ’ m so glad you came ! No , that ’ s not working either . You know how kids are . Yes , yes I did . This old house is falling apart ! I could have it all finished by today if it ’ s urgent . Oh , that must be because of my four-year-old daughter . Yeah , I have a little one myself . Let me have a look . Let me just get my plunger . Please come in ! Come on into the bathroom . It seems that your toilet is clogged , and that ’ s why it won ’ t flush . She is always flushing things down the toilet . That ’ s what ’ s making your toilet overflow . I would also suggest fixing this faucet that isn ’ t shutting off properly . I suspect that there ’ s some sort of foreign object in the pipes that ‘ s causing a blockage . Thatcould be causing water to not drain completely , that might lead to more problems in the future . Anyway , these water pipes are really rusty , so they also should be changed . I see . See , here , there ’ s water leaking everywhere !
# user :  That would be great ! Is it expensive ?
# res : Oh, It is worth the little extra, Would you like a couple hundred dollars a month for a porcelain countertop?
#  gt :  Let ’ s see ... I would say about eight hundred dollars .
# summarized : Why not ? I'm sorry to hear it . I hope she can do it . She is very responsible . My mother-in-law just went into the hospital in L.A.Hank and I will be flying there tonight . But Hank and I are leaving tonight . What's wrong ? What's wrong with her ? I'll get you her number . Doctors aren't sure yet.But the real problem is Suzy . I don't want to do that to you , Karen . It might even be for two or three days . Your own kids would get Suzy's cold . She has a bad cold , and we don't want to take her with us . I think it would be better to have a good babysitter here . I don't want to insult Jill or her mother . Listen , Karen , I need your help . You need a babysitter . I could have Suzy stay at my place . I'm glad to help you . I think Jill maybe could do it.But I'd rather have someone a little older . I need someone more mature than Jill . I knew you would be the best person to ask about this . Yes , I'd ask Jill , the girl I've had before , but I need someone overnight.Maybe even for two nights . There is a girl I know , Sara Ralston.She is 17 , and she will usually take this kind of job . I'd like to talk with her.This is short notice , I know . I know her from my church , and I trust her completely . I don't know anyone here yet . I'm glad you know someone . But we don't know who can stay with her . But I don't know who to ask . I know who we can ask .
# user :  I'll go home and get Sara's number . I'll call her first myself .
# res : I'm not sure if she will call me in the morning or night.
#  gt :  Great . Then call me and let me know if she's free .
# summarized : What'll you have ? Here you are . Good evening . Which do you prefer ? OK . I'd like a beer . What kind of beer do you have ? A draft beer please . Draft beer and cans beer .
# user :  Could I have some fruit ?
# res : Of course ; if I have anything, Please send me some.
#  gt :  Of course . Wait for a moment , please .
# summarized : Hello , Mr . I do hope you had a very enjoyable trip from New York . Black , how are you ? Yes , a very pleasant journey indeed . How are you getting along with your business ? I am awfully sorry for not being able to meet you at the airport , as I was busy yesterday . It's nice to meet you again . Fine , thank you , and how are you ? Very well , thank you . Thank you .
# user :  Not bad . The fur market is not very brisk lately , but the selling season is advancing near . I hope there will be more buyers in the market this year .
# res : No, I am not disappointed. There are quite a few looking for the latest one as well.
#  gt :  I hope we can do more business together . Though we are satisfied with our past trade record , there are still possibilities for more business . In the meantime , let's discuss other spheres of cooperation , such as investment , technology transfer and technical assistance .
# summarized : Toilets are in the rear , I am afraid all the toilets are fully occupied at the moment . By the way miss , where is the toilet ?
# user :  What ? Oh , what we live ! Thank you very much for your help , miss .
# res : Thank you very much, My great-grandfather. I hope you have enjoyed your stay in Nanjing ; Thanks a lot for your stay in Nanjing.
#  gt :  You are welcome .
# summarized : no . If you do , those are less expensive . ok , here you go . That will be 18 pounds and seventy two pence . sure . I need 30 for my Christmas cards . How many would you like ? do you have any going anywhere in the EU ? are you sending them abroad ? twenty of them are going abroad to China and America . it takes about 3 minutes per person , so it ’ ll probably be about an hour ’ s wait . How long do you think it ’ ll take to get through all those people ? that ’ s a really long line . can I buy stamps here ? and the bubble wrap ? excuse me , could you tell me which line I ’ m supposed to stand in to buy bubble wrap and to post a package ? you can buy the bubble wrap here , but you ’ ll have to stand in line over here to post your passage .
# user :  that ’ s another quid .
# res : Alright,
#  gt :  thanks a lot . You ’ Ve been very helpful .
# summarized : What are you doing now ? ! Why not ? I think there is not enough time to steam it and soy sauce is too much . I have studied its skills recently at a training school . Yes , I have . That's the case . Next Friday week is my birthday . What's that wonderful aroma from your kitchen ? I would like to invite you to cook for my dinner party , OK ? It's OK . Thank you for your praise . Thank you . Please have a taste of it . Oh , it's very delicious . I am steaming fish in a pressure cooker . So many dishes . I have the same idea as yours . The fish is not well-done and too salty . Have you ever tried steamed fish ? But the taste of steamed fish at that restaurant is not delicious . I am good at stewing beef with potato , frying chicken , hot and sour soup etc . Good evening , Saliva . It is a good idea . I plan to run a restaurant , so I have to practise cooking ! What dish are you cooking now ? Besides steamed fish , what else are you good at cooking ? I am cooking now ! It is a good opportunity for me to practise cooking . Are you good at cooking ?
# user :  Thanks a lot .
# res : I don't have much time to cook now ; Why not?
#  gt :  It's my pleasure .
# summarized : I am sorry , sir . You promised to send to me this morning . Well , let me check for you . Yes , I ordered the express service . Where is my laundry ? They mistook your order as a normal one.Actualty it's an express laundry , is that right ? This is room 2012 . Room service.What can I do for you ?
# user :  Sir , we are terribly sorry for that.We will refund the charge and send your laundry to your room 3 hours later . Is that all right ?
# res : Sure, Just wait a little while.
#  gt :  That's fine .
# summarized : What is it ? I'd like you to do me a favor .
# user :  Can you mail this at the post office for me ? I have to go to the doctor for an appointment and I don't have enough time to go to the post office .
# res : You know what? I'm out.
#  gt :  Sure . And I'd like you to get some cold medicine for me when you go to the doctor's .
# summarized : Sure . Excuse me , may I help you ? Would you please fill some gas for me ? Which kind of gas do you want ?
# user :  Unleaded , please .
# res : I'm sorry, I'm afraid it's not efficient.
#  gt :  OK .
# summarized : You know we exports would like to have our investments returned as early as possible . All right . I'll be willing to come and talk about the financing of our imports . Then we will be in a position to arrange for a loan from our bank . A bank's acceptance will add to the costs of our imports . You can rest assured that we will accept the draft and honour it when it comes due . But we demand the draft be accepted by a bank acceptable to us . What about a draft at 120 days sight ? It can be solved by drawing a draft on us at 90 days sight .
# user :  I hope this transaction will pave the way for further business relations between our two countries .
# res : Excellent. So it will be two years from now, Right?
#  gt :  So do I .
# summarized : She's kind of short . What height is she ? She's probably about five feet . The first thing I noticed was her beautiful brown eyes . I think that she is very pretty . I think I might've bumped into her before . There's a new girl in school , have you seen her yet ? I haven't seen her yet . Tell me how she looks . That's nice , but tell me what she looks like .
# user :  Are you telling me that you've seen her before ?
# res : Not exactly. I was a little surprised.
#  gt :  I believe so .
# summarized : That's only with the very big companies . My girlfriend will like it . No , sir.We only have this office here . Really ? Hmm . It will be fun . At 45 dollars for three days , it is a good deal . Driving back down the coast . It's a beautiful drive . Well , I guess I will have to drive back down then . I think it's necessary . I didn't think of that . You're smart to buy it . Yes . Take a seat inside and see what you think.So you will take the Porsche then , sir ? Yes , and I want to buy the insurance too . No , sir . I'm sorry , but this car must be returned to this lot . Do you still want the car , sir ? San Francisco ? You will have to return it here . I heard in America you can return rental cars in different cities . Can I return the car in San Francisco ?
# user :  Where are the keys ?
# res : Right, Here they are.
#  gt :  Just a moment , sir . We have to finish filling out the forms .
# summarized :
# user : Gary . Could you type up this report for me ? I have to take off early this afternoon .
# res : Ok.
#  gt :  Sure . Just leave it to me . I'll finish it .
# summarized : You are not too bad as well . True . Wait . They all look very fresh and delicious . I also want to have a steamed lobster . Look at the crystal clear fridge . Look at the show on TV . Sound great . I would like to have some salmon sashimi and a roast salmon head . It is really taste like heaven . I would like to have some stir-fried squids and steamed shrimps . I really want to eat at that restaurant . You can see so many kinds of seafood in it . Speaking of seafood , my mouth is watering . Let's go ! Let's go into the restaurant and find a table to order some food . I am a seafood lover . You sound like a seafood expert . I am watching a food show at a very famous seafood restaurant . Let me tell the lady what we would like to order in front of the seafood fridge first . Let's go to the seafood restaurant in our neighborhood .
# user :  OK . I will wait for you inside the restaurant
# res : That's a good idea ; I can wait here for a while.
#  gt :  Do you think we should try some deep fried oysters ?
# summarized : Where do you want to go ? I'm going to the hospital . Get in . I'll take you . About how much will it cost ? It will cost you $ 10 . You can see the time on the meter . I have radio time , you know . By the way , what's the time ?
# user :  It's a quarter to 12 . Could you please drive a little faster ?
# res : Oh, Of course. What is it you want to do with the money?
#  gt :  Certainly .
# summarized : Where was it from ? This is the very thing I've been dreaming of . You are right . Isn't it called ' the capital of porcelain ' ? This china tea set is unusual . It is the best quality porcelain-the famous egg-shell China . You're made a good choice . Jingdezhen ? It was made in Jingdezhen .
# user :  It must be most precious .
# res : Why do you choose to make porcelain here?
#  gt :  But it is really worth the price .
# summarized : Do you want it to be registered ? Sure . There are some pictures in it . It would be a great pity if they were lost . Oh , Would you do me a favor ? Hello , Miao Li , Where are you going ? Hello , I am going to the store to buy some fruit . Please mail this letter for me on your way to the store . Yes , I will be glad to mail your letter . Yes , I think so . Yes ?
# user :  Thanks .
# res : This letter is for your delivery.
#  gt :  you are welcome .
# summarized : Oh , yeah ? It really hurts . You know what I mean ? The accident was your fault . Alright . It doesn't work . Damn it ! I'm injured here . Don't worry . To hell with you . Well , you'll just have to wait . It looks like it's broken . I have a cell phone in my car . You should drive me there . It's better if we make a police report first . We could wait all day for the police . I'm not going to move my car until the police arrive . I'll go into one of those houses over there and use their phone . Yes , maybe it does.But if you're going to drive like you did just now , you will have to get used to a little physical pain . Now it's probably on the floor on the passenger side.Why don't you get it for me , and then I can call the police ? Then you can go to the hospital . I need to get to a hospital . You'll get to the hospital in time .
# user :  I'm afraid it wasn't . And when the police get here , you will also see that it wasn't . But enough of this bickering . I'm going to go find a phone.Don ' t move that arm while I'm gone . Alright ?
# res : I'm afraid I will lose my wallet. I know how hard it is. It hurts so bad. But I think you should get a good haircut and get a tattoo.
#  gt :  To hell with you .
# summarized : Hello . What's on this weekend ? Sure . It surely is . Vane Theater , at your service . It's to raise money for the homeless . It's a classic and children's favorite . And the cast is really the best . Good morning . It's a good thing that I have choices here . Wow , a story about the clever Monkey King . I'm thinking about watching a Chinese traditional opera with a foreign girl . Oh , it's a reserved opera named The Monkey Creates Havoc in Heaven . And also , there will be a solo concert by an opera star on Sunday night . Can you tell me about the one on Saturday ? What about the performance itself ? Well , there will be charity performance on Saturday night .
# user :  Wonderful ! How much is the ticket ?
# res :  $ 60.
#  gt :  The price varies according to the seats . 300 for the front , 200 for the middle , and 50 for the back .
# summarized : When can we start working on this ? I want to bring everybody back on this subject . All right . Well , we could probably get started with a preparatory meeting this afternoon at 2:00 . I tell you what , 2:00 is not available for me , but you can get started and I'll come by at around 3:00
# user :  That's fine with me . How much time are we going to have to work on this ?
# res : We have no funds for the presentation. What do you think about our conference?
#  gt :  Perhaps one year , I'm not sure .
# summarized : I beg your pardon ? What dressing would you like on the salad ? French dressing , please . Oh , French dressing .
# user :  Sorry , it's not available now.Anything else ?
# res : Yes, I'd like to have a single grilled sauerkraut or steak with a tomato sauce and cream cheese sauce.
#  gt :  We still prefer French dressing .
# summarized : Could I have some fish ? Certainly . Good . Thank you.sir . No , thanks . I ' Ve had enough . Oh , spinach , I think . Fine , And what about something to drink ? I'll have my bill , please . Just a beer , please . And what vegetables would you like ? Would you like to have some more beer ?
# user :  Of course . Please wait a moment . I'll go and get it .
# res : Would you like some tea or coffee?
#  gt :  Thank you .
# summarized : Hi , George . I know what you mean . Sure . It ’ s always easier to say something than to do it . You misunderstood me . You got it . For example , you should take care to appear well-groomed and modestly dressed . Could you give me some advice ? So the next day you will arrive early for the appointment . But I love wearing T-shirts and jeans . First of all , it ’ s very important for you not to be late . Yeah , that's very important . Avoid the extremes of a too elaborate or too casual style . So you ’ d better explore the place the day before and at the same time , look around to see what the employees are wearing . Only in this way can you gain the respect of the interviewer and his confidence in your judgement . I'm going to have a job interview next week . I advise you not to wear a too casual style when going to an interview . You need to create a good image in a limited time , usually about 30 to 45 minutes . It ’ s a pity that I cannot afford more expensive clothes . Clothes which are too colorful or too expensive suggest that you do not understand what behavior is appropriate for the job , or that you are snobbish or frivolous . Job interviewers usually don ’ t think very highly of a candidate who arrives ten minutes after the appointed time , only to explain that he could not find the place or that there was heavy traffic . This will put you on the same level as other applicants and make the interviewer consider more important qualifications . That ’ s right . Informal clothes as well as torn jeans and dirty shoes convey the impression that you are not serious about the job , or that you may be casual about your work as you are about your clothes . It ’ s not too difficult to make a good impression . I ’ ll try my best to make a good impression on the interviewer . I ought to wear right clothes at the right time .
# user :  It seems that ' clothes make the man ' .
# res : Really?
#  gt :  It may not be true , but the first and lasting impression of you is determined by your clothes and behavior .
# summarized : No idea . The boss announces the pay raise today , right ? How much do you think we'll get ? Your guess is as good as mine .
# user :  It better be more than last year .
# res : That's fine. I guess this time around I'll get a bonus.
#  gt :  Well , anything is better than nothing . Wait and see .
# summarized : What a pity ! I'm sorry , our appointment has to be changed .
# user :  If you don't mind , may we put it off to the next day ?
# res : Ok.
#  gt :  That's OK .
# summarized : Good day ! Welcome to Lincoln Bank , how may we assist you ? I need to find out if a Receipt of Proceeds has arrived . Hello . Thanks . Have you got the L / C number ? It's NX567822100007 . I'm from Felix Wasserman Associates . Hang on a tick and I'll check for you . I'm sorry ; we have no record of that arriving .
# user :  OK , thanks for checking . Could you give me a ring when it arrives , please ?
# res : This is $ 123.
#  gt :  No problem . I'll be in touch as soon as it comes in .
# summarized : I have to stay in your cry for just one day , can you suggest a short tour ? May I help you ? Are you interested in the natural landscape or the human landscape ? Yes .
# user :  I would prefer the first one .
# res : What is your favorite particular landscape?
#  gt :  Sure . We have a one-day trip along the river . It's quite beautiful .
# summarized : Hello , Sir . How can we help you today ? I would like an outline of responsibilities , both ours , yours and the beneficiary , please . OK , got it . OK , to start , the conditions are specified by the buyer and may include Insurance Forms , Way Bills , Bills of Lading , Customs forms , various certificates . I need to find out some more information for L / C . Is there anything else I need to know before we go ahead ?
# user :  Just that in effect , a basic Letter of Credit is a financial contract between the bank , the bank's customer , and the beneficiary , and this contract involves the transfer of goods or services against funds .
# res : If the transfer of goods or services is effected by a mistake, We will make the decision as soon as possible after receipt of the request from the customer. Then, I'll tell you when and how I will request a credit and when and how the credit will be charged.
#  gt :  That sounds fine , thanks for that . Let's go ahead !
# summarized : When was this break-in ? Where was the break-in ? 911 emergency . Was anything stolen ? I haven't checked yet . What is the problem ? Why do you think there was a break-in ? I would like to report a break-in . My front window was broken . It happened at my house . I believe it happened last night .
# user :  We'll send a squad car shortly .
# res : So, What happened yesterday?
#  gt :  I'd appreciate that .
# summarized : Actually , you can only have four . Excuse me . How much is the chocolate bar ? One dollar . So , I can have five for five dollars ?
# user :  Oh , yeah . I forgot tax . Give me four then , please .
# res : Oh, You know that you can only have one.
#  gt :  Okay . Thanks .
# summarized : That's all . Shall I do it now or later ? Have a nice stay here . Good evening , sir . I come to make the bed . House keeping.May I come in ? Well , since you have come , do it now please ? Come in please .
# user :  Thank you.Please get some soap for us .
# res : I don't have soap here in the last few days ; you will have to go to another bathroom.
#  gt :  Just a moment . I will do it right now .
# summarized : This is Richard Thomas . Ms . Montgomery ? I ’ m sorry to bother you at home , but I ’ Ve got a bit of a problem .
# user :  Oh ? What ’ s wrong ?
# res : I think I'm almost five.
#  gt :  My daughter ’ s just banged up her knee pretty badly and I ’ m going to have to take her to the hospital . I ’ ll be about two hours late .
# summarized : No . Excuse me . Thanks . I see . This is my advantage . Good . I'd like to start this interview with some questions . Have you got anything to ask me ? Have you got any other questions ? I have an appointment with Mr . Li at nine . I am Mr . Li . According to your advertisement , you want an experienced software engineer . In some regions , the hardware is completely replaced by software . My major was computer science when I was at college , and I am quite familiar with Visual C + + and Java language . You would be responsible for the development of software products . The developments in software are going ahead very quickly and more and more problems are resolved by software . Have you ever designed any programs concerning network ? May I come in ? Well , what do you think about the development in computers ? So I think the software industry has a great future . Then tell me something about your background . You must be My Liu , right ? I think my background meets the requirement of this position . Why do you think you are qualified for this position ? Yes , I have designed some programs for the network with Visual C + + and I have passed the test for programmers - MUSE . Yes , come in please . Yes , of course . Yes , can you tell me what's my responsibility in this position ? Yes , I am My Liu .
# user :  Ok , I will contact you in a week . See you .
# res : Thank you very much for your cooperation.
#  gt :  Thank you , bye-bye .
# summarized : Can you take he away from me ? She kept bothering me . I ’ m just coming for that . Tom , is Jenny crying ?
# user :  She ’ s your sister . What she asked was only duck soup for you . Why can ’ t you be good to her ?
# res : Because she's a fussy faggot.
#  gt :  But I am her brother , not her servant .
# summarized : That is a wonderful idea . Hello , where can I buy an inexpensive cashmere sweater ? Maybe you should look around for an outlet . Outlets have more reasonable prices .
# user :  Thank you for your help .
# res : This is expensive, What is the price tag?
#  gt :  No problem . Good luck
# summarized : What ? ! ! ! They're only used for worship . Don't go just yet . Wow ! Your fruit looks really fresh ! How about these pineapples ? You're crazy ! Wait ! Are they from Taiwan ? And you can't even eat them ? They're also good for your digestion ! These bananas are pretty cheap--only 35NT for this bunch . Bananas have lots of potassium , too ! They're 250NT each , but they're not edible . Hmm , 250NT is ... 8 dollars ? Let's see , 30NT is about ... almost a dollar US . How much are these apples ? The apples are 30NT each . Now that's more like it ! How many would you like ? Would you like some kiwis , too ?
# user :  They're imported from New Zealand . Four for 50NT . Nine for a hundred .
# res : Wow, Thank you very much.
#  gt :  OK . I'll take four kiwis .
# ...
# user :  I really hope it rains today .
# res : This is what you want. Let me know when you have time.
#  gt :  Yeah , me too .
# summarized : Yes , smoking or non-smoking ? Sorry , all the tables for three are reserved . Do you have a table for four , please ? Can we have a table for three , please ?
# user :  We'd like a non-smoking table , please .
# res : All of your table sizes are all the same.
#  gt :  Come with me , please .
# summarized : I'm a little rushed . Yeah , of course . You can take a taxi . How much will that run me ? Some are better than others . It depends on traffic and distance , but it is reasonable . But , you shouldn't have a problem . Is there any quicker way to get there ? Do the drivers speak English ?
# user :  Are they safe ?
# res :  They're not.
#  gt :  For the most part , yes . If you don't feel comfortable with it , then it is best not to take one at night .
# summarized : How about at 3:30 ? That sounds good . I'm on a weekly schedule . You're messing everything up . Sure . Hey Jimmy . Hey . I just played basketball earlier , so my legs are a little sore . What time do you want to go ? Let's go workout later today . Today we work on Legs and forearm . Let's work out on arms and stomach today .
# user :  C'mon . We're only switching two days . You can do legs on Friday .
# res : I'll do that later, Come on.
#  gt :  Aright . I'll meet you at the gym at 3:30 then .
# summarized : I have some great news ! Wonderful ! I knew everything would work out for you ! Do you already have your work schedule ? I was able to switch to the night shift ! We got along right from the start . I got to meet the night Anger today too . Do you know what you will be doing yet ? Not yet , I pick it up tomorrow .
# user :  Yes , I'll be managing the guys on the dock .
# res : All right. Now, How about today?
#  gt :  You're so good with people . I think they will like you !
# summarized : Next , please . What What features do they offer ? No , that won ’ t be necessary . Will you require overdraft protection ? Certainly , I can can help you with that . May I help you , sir ? There is an extra fee for that . I like to have easy access to my money . Alright , then , with this chequing account you ’ ll be issued a debit card and a cheque book . Hello , yes , I ’ d like to open a bank account . What type of account would you like to open ? Well , if you just take a look here , see , with our chequing account , you can have unlimited daily transactions for a small monthly fee , and our savings account has a higher interest rate , but you must carry a minimum balance of $ 10,000 dollars . I see , well , I think I ’ m more interested in a chequing account . A chequing or a savings account ?
# user :  In that case , I ’ ll get you to fill out this paperwork . I ’ ll need your social insurance number , and two pieces of government ID . If you could just sign here , and here , and here . we ’ ll be all set . Would you like to make a deposit today ?
# res :  Of course.
#  gt :  Yes , I ’ d like to deposit one billion dollars .
# summarized : When can you get it done ? It is knocking . Sure . Do you want to have the car washed ? Yes , please . Would you check the engine , please ?
# user :  You can pick it up in half an hour . By the way , how are you going to pay , cash or credit ?
# res : Thank you for your attention.
#  gt :  By credit .
# summarized : Wow , that sounds great ! I think I will start off in Paris . You ’ ll be able to do lots of shopping I expect . Oh that will be lovely . Yes . Oh yes and try lots of new food too . Then I ’ m going to take the train to Nice and then go on to Milan . I ’ m going to travel around Europe . Have you decided what you ’ re going to do during your holiday ? Where are you going ?
# user :  Great . Make sure you buy me a souvenir !
# res : For instance, I won't eat any at all! It is such a relief to travel by bus or car to these big cities.
#  gt :  Oh , don ’ t worry , I will !
# summarized : I think everyone has the right to love who they want . I am happy to be speaking to a presidential candidate . It ’ s nice meeting you . It ’ s nice to meet you , too . Many people won ’ t like that . Would you like to ask me anything ? Yes , I would . I ’ m sure they won ’ t , but that ’ s my view on gay marriage . What do you feel about gay marriage ? Would you legalize gay marriage ?
# user :  I really like you .
# res : Yes, But why should I ask you anything then?
#  gt :  I really appreciate that .
# summarized : I will be there . I ’ d like to know more about it . Can you come to my office this afternoon at 3 o ’ clock ? Hello ? This is Mr.White speaking . Hi . Yes . OK . This is John Smith.Can I speak to Mr.White , please ? I understand that you have a house for sale , haven ’ t you ?
# user :  Thank you for calling.Goodbye .
# res : Hello, Mr. Smith. What are you doing here?
#  gt :  Bye .
# summarized : Please fill in the arrival card and sign the register .
# user :  All right . Which room shall I have ?
# res : Well, Here you are.
#  gt :  Room 202 , but I'm afraid we have to ask for a deposit of $ 200 .
# summarized : Marketing manage office , can I help you ? No , thanks . Mr Green , please . What time you suspect back them ? I'll call back later . Sorry , he's out . Sorry , I am not sure , can I take a message ?
# user :  That's fine.please call again later .
# res : I'll call you back tomorrow afternoon.
#  gt :  Ok , thank you.Goodbye .
# summarized : He's the hot shot , the main guy who is the boss . It's too dangerous . They could be related to the organization , but more commonly , they are independent and non-biased . If there is only one person with absolute power in the organization , everyone knows that the power will go to their head . Then there's the CEO — the chief executive officer . You know , the stockholders are the people who own the company ... they're the financial control system . They all seems ot be the same group of people to me ...   No , there's a definite difference . The board is made up of people who are experts in the industry . That's the reason for a Board of Directors . So tell me , what's the difference between the Board of Directors , the CEO , and the stockholders ?
# user :  How many people are on the board of directors ?
# res :  About 10 people.
#  gt :  Usually not more than 15 , not less than 10 . They meet monthly , quarterly , or biannually to oversee an organization or company . They provide long term planing and vision , and also act as moral watchdogs rto keep the company in line .
# summarized : And you will receive two weeks paid vacation a year , as well . Does it suit you ? How much will my pay be , if you don ’ t mind my asking ? We don ’ t give bonus every month , but we offer a semi-annual bonus . We would like to start you off at 1,500 yuan a month , not including bonus and overtime pay .
# user :  Yes , thank you . May I ask for an apartment ?
# res : What are you doing there, Do you live there?
#  gt :  No problem . We'll supply you with an apartment of two bedrooms and a living room .
# summarized : You know the rules . Mum , can I finish my homework later ? Sorry . That ’ s out of the question . Please . Not a chance . But I want to watch TV now .
# user :  Not even for an hour ?
# res : I don't mind. It would be nice to go home and have some privacy.
#  gt :  Sorry , it ’ s impossible .
# summarized : What ’ s she doing ? Where ’ s Sally , Jack ? I beg your pardon ? Yes , he is . She ’ s in the garden , Jane . Tim is . Is Tim in the garden , too ? She ’ s sitting under the tree . He ’ s climbing the tree . Who ’ s climbing the tree .
# user :  What about the dog ?
# res :  Oh, We both know he is there.
#  gt :  The dog ’ s in the garden , too . It ’ s running across the grass . It ’ s running after a cat .
# summarized : I'm sorry to hear that . What's wrong with you ? I'll have to examine you . I have a sore throat and headache . Yes , my whole body feels weak . And I really feel terrible . Do you feel tired ?
# user :  Ok , go ahead .
# res : Are you sure?
#  gt :  Open your mouth and show me your tongue . Say ah ... You have a bad cold . So you must stay in bed for a week .
# summarized : Oh , right . Maybe you could join us later ? It ’ s my second wedding anniversary , and we ’ re supposed to be having a big dinner Susan would kill me if I missed it . Leo ! Unfortunately , I just can ’ t make it this time . I have to go straight home . You ’ re busy with that contract . We ’ Ve got to get the contract ready for Miss King . We ’ d love to see   What fun ! I wanted to tell you thanks for all your hard work on the budget . We ’ re having a get-together after work tonight at Carl ’ s Karaoke Club to celebrate having finished it . Normally I ’ d love to , but I ’ m afraid I have to work late tonight .
# user :  Happy anniversary ! Sorry you won ’ t be there . Maybe some other time ?
# res : Oh, I'm very sure you would. We will be over here today.
#  gt :  Yeah , maybe . Thanks , anyway . Hope you guys have a great time !
# summarized : Not at all . Do you mind if I try this on ? It's a little tight . Excuse me . Thanks . Sure . The changing rooms are just this way . That one is small , right ? Do you have any in a larger size ? I'll give you the next size up .
# user :  Yes . Also , I'm not so sure about the color .
# res : It's hard to tell if it's eye-catching or not.
#  gt :  Well.It doesn't go with your skirt . I think the color itself is fine though .
# summarized : Are you ? Are you going to vote ? Of course ! You should know that . Can you just tell me ? Are you serious ? I ’ m not kidding . It ’ s a good thing I asked you . That should ’ Ve been something you knew already . The election is this Tuesday . I plan to , but what day is the election ?
# user :  I couldn ’ t remember .
# res : It's only Tuesday night, Isn't it?
#  gt :  Whatever . Just make sure you go vote .
# summarized : What ? ? Zina , why are you whispering ? I've been talking to WebTracker . You'd defect to our archrival ! Keep your voice down . Are you serious ? Right now I need to see Vince . I'm thinking of jumping ship . We'll talk more later . Dave , there's something I want to talk to you about .
# user :  We definitely have to talk , Zina . And watch your back . Elvin is still mad about his nose .
# res : I'll see if I can communicate with him.
#  gt :  OK , but don't tell anyone what I said .
# summarized : You're not ? How is that ? That sounds nice . You can use it however many times you need to . Is that right ? I'm not going to buy one . Yup , and you can keep the money in your pocket . I think it's a waste of money . It actually costs less if you have a bus pass . You get your bus pass ?
# user :  You should go get yours .
# res : I really like my receipt.
#  gt :  Yeah , I think I will .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7ebdb9ef3721> in <cell line: 5>()
#       3 assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
#       4 manager = Manager(args, test_arr)
# ----> 5 manager.test()
#
# <ipython-input-9-67aebf3d1fb2> in test(self)
#     207                 token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)
#     208
# --> 209                 output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)
#     210
#     211                 # output_ids = self.model.generate(
#
# <ipython-input-9-67aebf3d1fb2> in nucleus_sampling(self, input_ids, token_type_ids, input_len)
#     102         output_ids = []
#     103         for pos in range(input_len, self.args.max_len):
# --> 104             output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
#     105             output = F.softmax(output, dim=-1)  # (1, V)
#     106
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1040         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1041
# -> 1042         transformer_outputs = self.transformer(
#    1043             input_ids,
#    1044             past_key_values=past_key_values,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     884                 )
#     885             else:
# --> 886                 outputs = block(
#     887                     hidden_states,
#     888                     layer_past=layer_past,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     393         residual = hidden_states
#     394         hidden_states = self.ln_1(hidden_states)
# --> 395         attn_outputs = self.attn(
#     396             hidden_states,
#     397             layer_past=layer_past,
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     334             attn_output, attn_weights = self._upcast_and_reordered_attn(query, key, value, attention_mask, head_mask)
#     335         else:
# --> 336             attn_output, attn_weights = self._attn(query, key, value, attention_mask, head_mask)
#     337
#     338         attn_output = self._merge_heads(attn_output, self.num_heads, self.head_dim)
#
# /usr/local/lib/python3.9/dist-packages/transformers/models/gpt2/modeling_gpt2.py in _attn(self, query, key, value, attention_mask, head_mask)
#     204             query_length, key_length = query.size(-2), key.size(-2)
#     205             causal_mask = self.bias[:, :, key_length - query_length : key_length, :key_length].bool()
# --> 206             attn_weights = torch.where(causal_mask, attn_weights, self.masked_bias.to(attn_weights.dtype))
#     207
#     208         if attention_mask is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## valid_utters로 테스트 요약모델은 bart-large...

# %%
from datasets import *
from tqdm import tqdm


# For all
space = 'Ġ'
pre_quote = '’'
end_marks = ['.', ',', '?', '!', '...']
quotes = ['"', '\'']
abbreviations = ['s', 'd', 't', 'm', 're', 'll', 've', 'S', 'D', 'T', 'M', 'Re', 'Ll', 'Ve']

# For empathetic dialogues
exclude_symbol = "_conv"
comma_symbol = "_comma_"

# For persona chat
persona_chat_url = "https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json"
silence_symbol = "__ SILENCE __"


def load_daily(tokenizer, train_frac):
    dataset = load_dataset('daily_dialog')
    train_dialogues = dataset['train']['dialog']
    valid_dialogues = dataset['validation']['dialog']
    test_dialogues = dataset['test']['dialog']
    
    total_dialogues = train_dialogues + valid_dialogues + test_dialogues
    
    for i, dialogue in enumerate(tqdm(total_dialogues)):
        new_dialogue = []
        for utter in dialogue:
            token_list = tokenizer.tokenize(utter.strip().replace(pre_quote, quotes[1]))
            token_list = process_token_list(token_list)
            text = tokenizer.convert_tokens_to_string(token_list)
            new_dialogue.append(text)
            
        total_dialogues[i] = new_dialogue
    
    train_utter_num = 0
    valid_utter_num = 0
    train_dialogues = total_dialogues[:int(len(total_dialogues)*train_frac)]
    valid_dialogues = total_dialogues[int(len(total_dialogues)*train_frac):]
    
    for dialogue in train_dialogues:
        train_utter_num += len(dialogue)
        
    for dialogue in valid_dialogues:
        valid_utter_num += len(dialogue)
    
    return train_dialogues, valid_dialogues, train_utter_num, valid_utter_num
    
    

def process_token_list(token_list):
    token_list[0] = token_list[0].capitalize()
    
    quote_count = 0
    for i, token in enumerate(token_list):
        if space in token:
            if token[1:] in end_marks or token[1:] in abbreviations:
                token_list[i] = token[1:]
                
            if token[1:] == quotes[1]:
                if i<len(token_list)-1:
                    if token_list[i+1] in abbreviations or (token_list[i+1][0] == space and token_list[i+1][1:] in abbreviations):
                        token_list[i] = token[1:]
                        
        if token[0] == space and token[1:] in quotes:
            if quote_count % 2 == 1:
                token_list[i] = token[1:]
                quote_count = 0
            else:
                if i<len(token_list)-1 and token_list[i+1][0] == space:
                    token_list[i+1] = token_list[i+1][1:]
                quote_count += 1
                
        if token in end_marks or token[1:] in end_marks:
            if i<len(token_list)-1:
                if token_list[i+1][0] != space:
                    token_list[i+1] = space + token_list[i+1].capitalize()
                else:
                    token_list[i+1] = space + token_list[i+1][1:].capitalize()
                
    new_token_list = [token for token in token_list if token != space and len(token)>0]
    if new_token_list[-1] not in end_marks:
        new_token_list.append(end_marks[0])
        
    return new_token_list

# %%
import difflib
from transformers import GPT2Tokenizer, GPT2LMHeadModel, get_polynomial_decay_schedule_with_warmup

from tqdm import tqdm
from torch.utils.data import DataLoader
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
from itertools import chain

import torch
import os, sys
import numpy as np
import argparse
import copy
import math
import random

class Arguments:
    def __init__(self):
        self.seed = 0 
        self.mode="test" 
        self.data_dir="data" 
        self.model_type="gpt2" 
        self.bos_token="<bos>" 
        self.sp1_token="<sp1>" 
        self.sp2_token="<sp2>" 
        self.gpu="0" 
        self.max_len=1024 
        self.max_turns=5 
        self.top_p=0.8 
        self.ckpt_dir="saved_models" 
        self.ckpt_name="best_ckpt_epoch=3_valid_loss=2.6631" 
        self.end_command="Abort!"

#원래 shell로 들어가는 파라미터를 정의합니다.

class Manager():
    def __init__(self, args):
        self.args = args
        
        if torch.cuda.is_available():
            self.args.device = torch.device(f"cuda:{self.args.gpu}")
        else:
            self.args.device = torch.device("cpu")
        
        # Tokenizer & Vocab
        print("Loading the tokenizer...")
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.args.model_type)
        special_tokens = {
            'bos_token': self.args.bos_token,
            'additional_special_tokens': [self.args.sp1_token, self.args.sp2_token]
        }
        self.args.eos_token = self.tokenizer.eos_token
        num_new_tokens = self.tokenizer.add_special_tokens(special_tokens)
        vocab = self.tokenizer.get_vocab()
        self.args.vocab_size = len(vocab)
        self.args.bos_id = vocab[self.args.bos_token]
        self.args.eos_id = vocab[self.args.eos_token]
        self.args.sp1_id = vocab[self.args.sp1_token]
        self.args.sp2_id = vocab[self.args.sp2_token]
        
        # Load model    
        print("Loading the model...")
        self.fix_seed(self.args.seed)
        self.model = GPT2LMHeadModel.from_pretrained(self.args.model_type).to(self.args.device)
        self.model.resize_token_embeddings(self.args.vocab_size)
        
        self.args.max_len = min(self.args.max_len, self.model.config.n_ctx)
            
        
        
        if self.args.ckpt_name is not None:
            ckpt_path = f"{self.args.ckpt_dir}/{self.args.ckpt_name}.ckpt"
            if os.path.exists(ckpt_path):
                print("Loading the trained checkpoint...")
                ckpt = torch.load(ckpt_path, map_location=self.args.device)
                self.model.load_state_dict(ckpt['model_state_dict'])
                
                if self.args.mode == 'train':
                    print(f"The training restarts with the specified checkpoint: {self.args.ckpt_name}.ckpt.")
                    self.optim.load_state_dict(ckpt['optim_state_dict'])
                    self.sched.load_state_dict(ckpt['sched_state_dict'])
                    self.best_loss = ckpt['loss']
                    self.last_epoch = ckpt['epoch']
                else:
                    print("The inference will start with the specified checkpoint.")
            else:
                print(f"Cannot fine the specified checkpoint {ckpt_path}.")
                if self.args.mode == 'train':
                    print("Training will start with the initialized model.")
                else:
                    print("Cannot inference.")
                    exit()
              
        print("Setting finished.")
        
    def nucleus_sampling(self, input_ids, token_type_ids, input_len):
        output_ids = []
        for pos in range(input_len, self.args.max_len):
            output = self.model(input_ids=input_ids, token_type_ids=token_type_ids)[0][:, pos-1]  # (1, V)
            output = F.softmax(output, dim=-1)  # (1, V)
            
            sorted_probs, sorted_idxs = torch.sort(output, descending=True)
            cumsum_probs = torch.cumsum(sorted_probs, dim=-1)  # (1, V)
            idx_remove = cumsum_probs > self.args.top_p
            idx_remove[:, 1:] = idx_remove[:, :-1].clone()
            idx_remove[:, 0] = False
            sorted_probs[idx_remove] = 0.0
            sorted_probs /= torch.sum(sorted_probs, dim=-1, keepdim=True)  # (1, V)
            
            probs = torch.zeros(output.shape, device=self.args.device).scatter_(-1, sorted_idxs, sorted_probs)  # (1, V)
            idx = torch.multinomial(probs, 1)  # (1, 1)
            
            idx_item = idx.squeeze(-1).squeeze(-1).item()
            output_ids.append(idx_item)
            
            if idx_item == self.args.eos_id:
                break
                
            input_ids = torch.cat((input_ids, idx), dim=-1)
            next_type_id = torch.LongTensor([[self.args.sp2_id]]).to(self.args.device)
            token_type_ids = torch.cat((token_type_ids, next_type_id), dim=-1)
            assert input_ids.shape == token_type_ids.shape
            
        return output_ids

    def fix_seed(self, seed):
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        random.seed(seed)  

    def test(self):
        print("Let's start!")
        self.model.eval()
        self.fix_seed(self.args.seed)
        
        import json
        if not os.path.isdir(args.data_dir):
            os.makedirs(args.data_dir)
        with open(f"{args.data_dir}/valid_utters.json") as f:
            json_obj = json.load(f)

        #valid set을 사용하겠습니다.

        summarized_utter = []
        user = []
        ground_truth = []
        for utters in json_obj:
            summarized_utter.append(utters[0]) #요약문장
            user.append(utters[1]) #user utter
            ground_truth.append(utters[2]) #ground truth 진짜 정답.

        
        with torch.no_grad():
            input_hists = []
            ex_cnt = -1
            similarity = 0
            while True:
                #utter = input("You: ")
                ex_cnt += 1
                if ex_cnt == len(json_obj):
                    break


                utter = user[ex_cnt]
                

                if utter == self.args.end_command:
                    print("Bot: Good bye.")
                    break
                
                ## summarized input ##
                input_hists = []
                sumrz_input = summarized_utter[ex_cnt]
                sumrz_input_ids = [self.args.sp1_id] + self.tokenizer.encode(sumrz_input) # sp1 sumar.. utter
                input_hists.append(sumrz_input_ids)
                ## sumarized utter를 하나씩 꺼냅니다. ##

                input_ids = [self.args.sp2_id] + self.tokenizer.encode(utter) # sp2 user utter
                input_hists.append(input_ids)
                
                #if len(input_hists) >= self.args.max_turns:
                    #num_exceeded = len(input_hists) - self.args.max_turns + 1
                    #input_hists = input_hists[num_exceeded:]
                # 역시 턴 개념은 사용하지 않습니다.
                    
                input_ids = [self.args.bos_id] + list(chain.from_iterable(input_hists)) + [self.args.sp1_id] # 2 -> 1
                #start_sp_id = input_hists[0][0]
                start_sp_id = self.args.sp1_id
                


                #next_sp_id = self.args.sp1_id if start_sp_id == self.args.sp2_id else self.args.sp2_id
                next_sp_id = self.args.sp2_id

                assert start_sp_id != next_sp_id
                token_type_ids = [[start_sp_id] * len(hist) if h % 2 == 0 else [next_sp_id] * len(hist) for h, hist in enumerate(input_hists)] 
                assert len(token_type_ids) == len(input_hists)
                token_type_ids = [start_sp_id] + list(chain.from_iterable(token_type_ids)) + [self.args.sp1_id] # 2 -> 1
                assert len(input_ids) == len(token_type_ids)
                input_len = len(input_ids)
                
                input_ids = torch.LongTensor(input_ids).unsqueeze(0).to(self.args.device)
                token_type_ids = torch.LongTensor(token_type_ids).unsqueeze(0).to(self.args.device)
                
                output_ids = self.nucleus_sampling(input_ids, token_type_ids, input_len)
           
                # output_ids = self.model.generate(
                #     input_ids=input_ids, token_type_ids=token_type_ids, pad_token_id=self.args.eos_id,
                #     do_sample=True, top_p=self.args.top_p, max_length=self.args.max_len,
                #     output_hidden_states=True, output_scores=True, return_dict_in_generate=True,
                # ).sequences
                # output_ids = output_ids[0].tolist()[input_len:]
                res = self.tokenizer.decode(output_ids, skip_special_tokens=True)

                similarity += compute_similarity(res, ground_truth[ex_cnt])

                print(f"summarized : {summarized_utter[ex_cnt]}")
                print(f"user : {user[ex_cnt]}")
                print(f"res : {res}\n gt : {ground_truth[ex_cnt]}")

                # 예측한 문장과 ground truth를 비교할 수 있습니다.
                # 아직 눈으로 밖에 비교할 방법이 없음.

                #print(f"Bot: {res}")
                #input_hists.append([self.args.sp2_id] + self.tokenizer.encode(res))
        print(f"문자열 간에 유사도 : {similarity / len(json_obj)}")


def compute_similarity(string1, string2):

    matcher = difflib.SequenceMatcher(None, string1, string2)
    return matcher.ratio()

# 두 문자열을 비교하는 함수이나...
# 큰 의미는 없는것 같다.

# %%
args = Arguments()
args.data_dir = f"{args.data_dir}/{args.model_type}"
args.ckpt_dir = f"{args.ckpt_dir}/{args.model_type}"
assert args.ckpt_name is not None, "Please specify the trained model checkpoint."
manager = Manager(args)
manager.test()
