# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/temp/gpt2-dialogue-generation-pytorch/
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/temp/gpt2-dialogue-generation-pytorch/'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# ## rubbish

# %%
from datasets import *
dataset = load_dataset('daily_dialog')
train_dialogues = dataset['train']['dialog']
valid_dialogues = dataset['validation']['dialog']
# Out:
# Downloading:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration default
# ...
# Downloading:   0%|          | 0.00/4.48M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset daily_dialog downloaded and prepared to /root/.cache/huggingface/datasets/daily_dialog/default/1.0.0/c03444008e9508b8b76f1f6793742d37d5e5f83364f8d573c2747bff435ea55c. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from pprint import pprint
pprint(valid_dialogues)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   ' No , I don ’ t . I get a bonus each month , depending on the value of the '
#   'contracts I sign with clients . ',
#   ' Do you have any breaks ? ',
#   ' We have an hour-long lunch break form 12 to 1 . we can take coffee breaks '
#   'during the day . My boss doesn ’ t mind , as long as we get out work done '
#   'on time . ',
#   ' My boss gets annoyed if we take coffee breaks . I suppose your job '
#   'involves a lot paperwork , doesn ’ t it ? ',
#   ' There ’ s some paperwork , but most of the time we put any information '
#   'onto computers . Then we can send information to each other by email or '
#   'across the network . Do you work in a cubicle ? ',
#   ' Yes , I do . I don ’ t like it very much . ',
#   ' I work in a cubicle too , but I I don ’ t mind it . '],
#  ['Hello ! My name is Sandals , I have a reservation . ',
#   ' May I see your identification , please , sir ? ',
#   ' Here you are . ',
# ...

# %%
# !pwd
import json
import itertools
new_arr = []
with open('custom/train_sum_2.json') as f:
    json_obj = json.load(f)

print(json_obj)
for subject in json_obj:
    for three in subject:
        new_arr.append(three)
total_dialogues = new_arr
print(total_dialogues)
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/temp/gpt2-dialogue-generation-pytorch
# ...

# %% [markdown]
# ## tokenizer unk test

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch/
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/gpt2-dialogue-generation-pytorch

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 87.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 23.9 MB/s eta 0:00:00
# ...

# %%
from transformers import GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
special_tokens = {
            'bos_token': "<bos>",
            'eos_token': "<eos>",
            'additional_special_tokens': ["<sp1>", "<sp2>"]
        }

num_new_tokens = tokenizer.add_special_tokens(special_tokens)
vocab = tokenizer.get_vocab()
vocab_size = len(vocab)
bos_id = vocab["<bos>"]
eos_id = vocab["<eos>"]
sp1_id = vocab["<sp1>"]
sp2_id = vocab["<sp2>"]

# %%
# !pwd
import json
new_arr = []
with open('custom/summarized_data.json') as f:
    json_obj = json.load(f)


for subject in json_obj:
    for three in subject:
        for utter in three:
            #print(utter)
            print(tokenizer.decode(tokenizer.encode(utter)))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Well, I've lost my wallet and my ID card.
# Oh, That's too bad! I am sorry to hear that!
# He's upset because he lost his wallet and his ID card, so he's looking for someone to help him find them. He looks upset to someone because he's lost both his wallets and his IDs, which makes him look upset.
# Oh, That's too bad! I am sorry to hear that!
# Forget it, There is no use crying over the spilled milk.
#
# Diana, Do you like the perfume I gave you?
# It's good. But to tell you the truth, I don't wear perfume.
# Diana doesn't like the perfume that she got from him. He asks her if she likes it. She doesn't know.    "Diana, do you like the fragrance I gave you?"   "Yes".   'No'.
# It's good. But to tell you the truth, I don't wear perfume.
# I'm sorry. I didn't know that.
# ...
